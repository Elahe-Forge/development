# %%
import pandas as pd
import string
from nltk.corpus import stopwords
from fuzzywuzzy import fuzz, process
import re
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics.pairwise import cosine_similarity
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
# df_mfm = pd.read_csv('MFM names to match(in).csv')
df_mfm = pd.read_csv('private_companies.csv')

df_forge_price = pd.read_csv('../data/forge_price_sample.csv')
df_funding_rounds = pd.read_csv('../data/funding-rounds.csv')
df_issuers = pd.read_csv('../data/issuers.csv')
df_trade_facts = pd.read_csv('../data/trade_facts.csv')


df_merged_result = df_issuers.merge(df_forge_price, on='ISSUER_SLUG', how='left') \
            .merge(df_funding_rounds, on='ISSUER_SLUG', how='left') \
            .merge(df_trade_facts, on='ISSUER_SLUG', how='left')
df_merged_result = df_merged_result.rename(columns={'ISSUER_SLUG': 'slug'})
df_merged_result
# Out:
#                  slug             NAME        LEGALENTITYNAME SEARCHALIASES  \
# 0           tradealgo        TradeAlgo        TA Fintech Inc.            []
# 1            latitude         Latitude       Oasis Tech, Inc.            []
# 2           revery-ai        Revery AI         Revery AI Inc.            []
# 3                soci             SOCi             SOCi, Inc.            []
# 4           colossyan        Colossyan         Colossyan Inc.            []
# ...               ...              ...                    ...           ...
# 5291          vetster          Vetster          Vetster, Inc.            []
# 5292          embrace          Embrace   Embrace Mobile, Inc.            []
# 5293  particle-health  Particle Health  Particle Health, Inc.            []
# 5294       leaf-trade       Leaf Trade        Leaf Trade Inc.            []
# 5295        empowerly        Empowerly         Empowerly, Inc            []
#
#                                             DESCRIPTION  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5291  Vetster is a telehealth company which offers o...
# 5292  Embrace is a mobile app monitoring company whi...
# 5293  Particle Health is a healthcare technology com...
# 5294  Leaf Trade is a technology company which offer...
# 5295  Empowerly is a technology company which offers...
#
#      STRUCTURED_DESCRIPTION LIFECYCLESTATUS BANNERMESSAGE  \
# 0                                       NaN           NaN
# 1                                       NaN           NaN
# 2                                       NaN           NaN
# 3                                       NaN           NaN
# 4                                       NaN           NaN
# ...                     ...             ...           ...
# 5291                                    NaN           NaN
# 5292                                    NaN           NaN
# 5293                                    NaN           NaN
# 5294                                    NaN           NaN
# 5295                                    NaN           NaN
#
#                       SUB_SECTOR                SECTOR  ...  \
# 0               Personal Finance               FinTech  ...
# 1                         Gaming  Consumer & Lifestyle  ...
# 2            E-commerce software  Consumer & Lifestyle  ...
# 3     Sales & Marketing / Adtech   Enterprise Software  ...
# 4                   Productivity   Enterprise Software  ...
# ...                          ...                   ...  ...
# 5291                        Pets  Consumer & Lifestyle  ...
# 5292     Data Management/Storage   Enterprise Software  ...
# 5293              Digital Health            Healthcare  ...
# 5294         Business Operations   Enterprise Software  ...
# 5295          Education software             Education  ...
#
#      FORGE_PRICE_ISSUER_TIER FORGE_PRICE  FORGE_IMPLIED_VALUATION  \
# 0                        NaN         NaN                      NaN
# 1                        NaN         NaN                      NaN
# 2                        NaN         NaN                      NaN
# 3                        NaN         NaN                      NaN
# 4                        NaN         NaN                      NaN
# ...                      ...         ...                      ...
# 5291                     NaN         NaN                      NaN
# 5292                     NaN         NaN                      NaN
# 5293                     NaN         NaN                      NaN
# 5294                     NaN         NaN                      NaN
# 5295                     NaN         NaN                      NaN
#
#      FORGE_PRICE_SOURCE_EXTERNAL HAS_IOIS ARRAY_AGG(FUNDING_DATE)  \
# 0                            NaN      NaN                     NaN
# 1                            NaN      NaN                     NaN
# 2                            NaN      NaN                     NaN
# 3                            NaN      NaN                     NaN
# 4                            NaN      NaN                     NaN
# ...                          ...      ...                     ...
# 5291                         NaN      NaN                     NaN
# 5292                         NaN      NaN                     NaN
# 5293                         NaN      NaN                     NaN
# 5294                         NaN      NaN                     NaN
# 5295                         NaN      NaN                     NaN
#
#      ARRAY_AGG(FR.SHARE_TYPE) NUM_TRADES  LAST_CLOSED_TRADE_DATE  \
# 0                         NaN        NaN                     NaN
# 1                         NaN        NaN                     NaN
# 2                         NaN        NaN                     NaN
# 3                         NaN        NaN                     NaN
# 4                         NaN        NaN                     NaN
# ...                       ...        ...                     ...
# 5291                      NaN        NaN                     NaN
# 5292                      NaN        NaN                     NaN
# 5293                      NaN        NaN                     NaN
# 5294                      NaN        NaN                     NaN
# 5295                      NaN        NaN                     NaN
#
#       LAST_PENDING_TRADE_DATE
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 5291                      NaN
# 5292                      NaN
# 5293                      NaN
# 5294                      NaN
# 5295                      NaN
#
# [5296 rows x 27 columns]

# %%
stop_words_normalized = [
        "healthcare",
        "technologies",
        "therapeutics",
        "financial",
        "software",
        "holdings",
        "transportation",
        "pharmaceuticals",
        "capital",
        "copper",
        "communications",
        "biotechnology",
        "biopharmaceuticals",
        "group",
        "technology",
        "media",
        "energy",
        "industries",
        "biotherapeutics",
        "solution",
        "bioscience",
        "industries",
        "corporation",
        "systems",
        "enterprises",
        "robotics",
        "bank",
        "inc",
        "llc",
        "pp",
        "series a",
        "series seed",
        "series b",
        "series c",
        "series d",
        "series e",
        "series f",
        "series g",
        "series h",
        "series i"
    ]

def normalize_name(name):
    name = name.lower() 
    for word in stop_words_normalized:
        name = name.replace(word, '')
    return name.strip()


stop_words = set(stopwords.words('english'))
def remove_stop_words(sentence):
    words = sentence.split()
    filtered_sentence = [w for w in words if not w.lower() in stop_words]
    return ' '.join(filtered_sentence)


def remove_punctuation(sentence):
    return sentence.translate(str.maketrans('', '', string.punctuation))


def clean_text(word_to_find):
    word_to_find_normalzed = normalize_name(word_to_find)

    word_to_find_no_stop_word = remove_stop_words(word_to_find_normalzed)

    word_to_find_no_punc = remove_punctuation(word_to_find_no_stop_word)

    return word_to_find_no_punc

# %%
# read the column nport_name from df_mfm_mappings where the column count is greater than or equal 1000
# df_mfm_mappings = df_mfm[df_mfm['count'] >= 1000][['nport_name']]
df_mfm_mappings = df_mfm[:1000]

# %%
words_to_find = df_mfm_mappings['nport_name']
word_list = df_merged_result['slug']
print(len(word_list), len(words_to_find))
# Out:
# 5296 1000

# %%
# Weight functions

from datetime import datetime

def weight_domicile_country_code(code):
    return 1 if code == 'US' else 0

def weight_domicile_state_code(code):
    return 1 if code == 'DE' else 0


funding_round_ranking = {
    'seed': 0,
    'series a': 1,
    'series b': 2,
    'series c': 3,
    'series d': 4,
    'series e': 5,
    'series f': 6,
    'series g': 7,
    'series h': 8,
    'series i': 9
}
def normalize_and_weight_series(series_types):  
    if pd.isna(series_types) or not series_types:  # Handle NaN or empty lists
        return 0  # Neutral weight for missing values or empty lists

    normalized_weights = []
    
    for series in series_types:
        series_lower = series.lower().strip()
        
        match = re.search(r'series [a-z]', series_lower)
        if match:
            normalized_type = match.group()
            weight = funding_round_ranking.get(normalized_type, 0)
            normalized_weights.append(weight)
        else:
            # Fallback for unrecognized series types (neutral)
            normalized_weights.append(0)  
    
    return max(normalized_weights)  # Return the highest weight in the list


def weight_recency(funding_dates_str):
    if pd.isna(funding_dates_str) or not funding_dates_str: # Handle NaN or empty lists
        return -99999  # Lowest weight for missing or empty values
    
    funding_dates_clean = re.findall(r'\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2}\.\d{3}', funding_dates_str)
    funding_dates = [datetime.strptime(date, '%Y-%m-%d %H:%M:%S.%f') for date in funding_dates_clean]
    most_recent_date = max(funding_dates)
    now = datetime.now()
    recency_weight = (now - most_recent_date).days
    return -recency_weight  # More recent = higher weight (less days, more weight)


def weight_price_source(price_source):
    if pd.isna(price_source):  # Handle NaN or missing values
        return -0.1  # Assign negative weight to missing values
    price_source_lower = price_source.lower().strip()
    
    if re.search(r'vwap', price_source_lower):
        return 1  
    elif re.search(r'iois', price_source_lower):
        return 0.5  
    elif re.search(r'primary', price_source_lower):
        return 0.2  
    else:
        return -0.1  # Negative weight for other or unrecognized types

def weight_price_issuer_tier(tier):
    if pd.isna(tier):  # Handle NaN or missing values
        return 0  # Neutral weight for missing
    tier_lower = tier.lower().strip()
    if tier_lower == 'tier_1':
        return 1  # Highest weight for TIER_1
    else:
        return 0.5  # Neutral or medium weight for other tiers


def weight_price(price):
    if pd.isna(price):  # Handle NaN or missing values
        return 0  # Neutral weight for missing values
    return price  # Higher value means higher weight

def weight_implied_valuation(valuation):
    if pd.isna(valuation):  # Handle NaN or missing values
        return 0  # Neutral weight for missing values
    return valuation  # Higher value means higher weight

#create weight functions for HAS_IOIS, if true less weight, if false more weight
def weight_has_iois(has_iois):
    return 0 if has_iois else 1

# create weight functions for NUM_TRADES, if more trades, higher weight
def weight_num_trades(num_trades):
    return num_trades if num_trades else 0

# create weight functions for LAST_CLOSED_TRADE_DATE, if more recent, higher weight
def weight_last_closed_trade_date(last_closed_trade_date):
    if pd.isna(last_closed_trade_date) or not last_closed_trade_date:  # Handle NaN or missing values
        return -99999  # Lowest weight for missing values
    last_closed_trade_date = datetime.strptime(last_closed_trade_date, '%m/%d/%y')
    now = datetime.now()
    recency_weight = (now - last_closed_trade_date).days
    return -recency_weight  # More recent = higher weight (less days, more weight)

# create weight functions for LAST_PENDING_TRADE_DATE, if more recent, higher weight
def weight_last_pending_trade_date(last_pending_trade_date):
    if pd.isna(last_pending_trade_date) or not last_pending_trade_date:  # Handle NaN or missing values
        return -99999  # Lowest weight for missing values
    last_pending_trade_date = datetime.strptime(last_pending_trade_date, '%m/%d/%y')
    now = datetime.now()
    recency_weight = (now - last_pending_trade_date).days
    return -recency_weight  # More recent = higher weight (less days, more weight)

# create weight functions for ARCHIVEDAT, if present, lower weight
def weight_archived_at(archived_at):
    return 0 if pd.isna(archived_at) else 1


# output_columns += [
#     'YEARFOUNDED',
#     'CITY'
# ]

# %%
def match_company(name, master_list, top_n=5):
    name = normalize_name(name)
    
    # Extract the top N matches along with their scores
    ranked_matches = process.extract(name, master_list, scorer=fuzz.token_set_ratio, limit=top_n)
    return ranked_matches if ranked_matches else []

# matched_companies = [match_company(c, word_list) for c in words_to_find]
# matched_companies

# %%
def match_company_with_weights(name, df_master, output_columns, column_weights, weighted_feature_columns, top_n=5):
    name = normalize_name(name)
    matches = []

    # Calculate max values for normalization
    max_feature_values = {col: df_master[col].max() for col in weighted_feature_columns}
    
    for index, row in df_master.iterrows():
        total_score = 0
        
        # Similarity scores for text columns
        for col in output_columns:
            col_value = str(row[col]) if pd.notnull(row[col]) else ''
            col_similarity = fuzz.token_set_ratio(name, normalize_name(col_value))
            weight = column_weights.get(col, 1.0)
            total_score += weight * col_similarity

        for col in weighted_feature_columns:
            feature_weight = row[col] if pd.notnull(row[col]) else 0

            # Normalize the feature weight
            max_value = max_feature_values[col] if max_feature_values[col] != 0 else 1
            scaled_feature_weight = feature_weight / max_value

            total_score += scaled_feature_weight

        matches.append((row['slug'], total_score, row))
    
    # Sort the matches based on total_score in descending order
    matches.sort(key=lambda x: x[1], reverse=True)
    
    # Get the top N matches
    top_matches = matches[:top_n]
    
    return top_matches

# %%
df_master = df_merged_result.copy()

df_master['DOMICILECOUNTRYCODE_WEIGHT'] = df_master['DOMICILECOUNTRYCODE'].apply(weight_domicile_country_code)
df_master['DOMICILESTATECODE_WEIGHT'] = df_master['DOMICILESTATECODE'].apply(weight_domicile_state_code)
df_master['SHARE_TYPE_WEIGHT'] = df_master['ARRAY_AGG(FR.SHARE_TYPE)'].apply(normalize_and_weight_series)
df_master['FUNDING_DATE_WEIGHT'] = df_master['ARRAY_AGG(FUNDING_DATE)'].apply(weight_recency)
df_master['FORGE_PRICE_SOURCE_WEIGHT'] = df_master['FORGE_PRICE_SOURCE_EXTERNAL'].apply(weight_price_source)
df_master['FORGE_PRICE_ISSUER_TIER_WEIGHT'] = df_master['FORGE_PRICE_ISSUER_TIER'].apply(weight_price_issuer_tier)
df_master['FORGE_PRICE_WEIGHT'] = df_master['FORGE_PRICE'].apply(weight_price)
df_master['FORGE_IMPLIED_VALUATION_WEIGHT'] = df_master['FORGE_IMPLIED_VALUATION'].apply(weight_implied_valuation)
df_master['HAS_IOIS_WEIGHT'] = df_master['HAS_IOIS'].apply(weight_has_iois)
df_master['NUM_TRADES_WEIGHT'] = df_master['NUM_TRADES'].apply(weight_num_trades)
df_master['LAST_CLOSED_TRADE_DATE_WEIGHT'] = df_master['LAST_CLOSED_TRADE_DATE'].apply(weight_last_closed_trade_date)
df_master['LAST_PENDING_TRADE_DATE_WEIGHT'] = df_master['LAST_PENDING_TRADE_DATE'].apply(weight_last_pending_trade_date)


output_columns = [
    'slug',
    'NAME',
    'LEGALENTITYNAME',
    'SEARCHALIASES',
    'DESCRIPTION',
    'STRUCTURED_DESCRIPTION',
    'LIFECYCLESTATUS',
    'BANNERMESSAGE',
    'SUB_SECTOR',
    'SECTOR',
    'WEBSITE',
    'CRUNCHBASEURL'
]

# Define weights for each output column
column_weights = {
    'slug': 1.0,
    'NAME': 2.0,
    'LEGALENTITYNAME': 2.0,
    'WEBSITE': 1.5,
    'SEARCHALIASES': 1.5,
    'DESCRIPTION': 1.0,
    'STRUCTURED_DESCRIPTION': 1.0,
    'LIFECYCLESTATUS': 1.0,
    'BANNERMESSAGE': 1.0,
    'SUB_SECTOR': 1.0,
    'SECTOR': 1.0,
    'CRUNCHBASEURL': 1.0
}

weighted_feature_columns = [
    'DOMICILECOUNTRYCODE_WEIGHT',
    'DOMICILESTATECODE_WEIGHT',
    'SHARE_TYPE_WEIGHT',
    'FUNDING_DATE_WEIGHT',
    'FORGE_PRICE_SOURCE_WEIGHT',
    'FORGE_PRICE_ISSUER_TIER_WEIGHT',
    'FORGE_PRICE_WEIGHT',
    'FORGE_IMPLIED_VALUATION_WEIGHT',
    'HAS_IOIS_WEIGHT',
    'NUM_TRADES_WEIGHT',
    'LAST_CLOSED_TRADE_DATE_WEIGHT',
    'LAST_PENDING_TRADE_DATE_WEIGHT'
]

# %%
result = []
# for c in words_to_find:
#     # print(c)
#     res = match_company(c, word_list)
#     first_match = res[0][0] if res else None
#     if res:
#         result.append((c, first_match, res))

# result

for c in words_to_find:
    top_matches = match_company_with_weights(
        name=c,
        df_master=df_master,
        output_columns=output_columns,
        column_weights=column_weights,
        weighted_feature_columns=weighted_feature_columns,
        top_n=5
    )
    if top_matches:
        first_match = top_matches[0][0]  # Get the slug of the first match
        # Extract slugs and scores for all top matches
        top_slugs_with_scores = [(slug, score) for slug, score, _ in top_matches]
        result.append((c, first_match, top_slugs_with_scores))
    else:
        first_match = None
        result.append((c, first_match, []))

result
# Out:
# [('FNMA GTD MTG PASS THRU CTF',
#   'pat-mcgrath-labs',
#   [('pat-mcgrath-labs', 9026.411344537815),
#    ('the-players-tribune', 9010.911344537815),
#    ('magisto', 8997.911344537815),
#    ('the-virtual-reality-company', 8994.411344537815),
#    ('smartsheet-com', 8992.411748396169)]),
#  ('Freddie Mac',
#   'stay-alfred',
#   [('stay-alfred', 9074.411344537815),
#    ('freeline-therapeutics', 9072.411344537815),
#    ('kreditech', 9070.411344537815),
#    ('freetrade', 9068.411344537815),
#    ('fieldwirelabs', 9035.911344537815)]),
#  ('UGCard',
#   'popsugar',
#   [('popsugar', 9074.911344537815),
#    ('autogrid', 9047.411344537815),
#    ('garuda-therapeutics', 9031.911344537815),
#    ('scalyr', 9021.911344537815),
#    ('tango-card', 9020.411344537815)]),
#  ('Government National Mortgage Association',
#   'valon-mortgage',
#   [('valon-mortgage', 9177.911344537815),
#    ('generation-bio', 9119.911360910452),
#    ('convergent-dental', 9092.411344537815),
#    ('real-time-translation', 9089.411344537815),
#    ('turnkey-vacation-rentals', 9069.411344537815)]),
#  ('Upstart Network, Inc.',
#   'kyber-network',
#   [('kyber-network', 9256.911344537815),
#    ('pocket-network', 9218.911344537815),
#    ('loom-network', 9215.411344537815),
#    ('tvu-networks', 9200.911344537815),
#    ('anoma-network', 9164.911344537815)]),
#  ('United States Treasury',
#   'states-title',
#   [('states-title', 9150.911344537815),
#    ('smartrent', 9110.411344537815),
#    ('threat-stack', 9101.411344537815),
#    ('aeternity', 9072.911344537815),
#    ('turnkey-vacation-rentals', 9070.911344537815)]),
#  ('FED HOME LOAN MTG CORP - GOLD',
#   'noon-home',
#   [('noon-home', 9209.411344537815),
#    ('cool-planet-energy-systems', 9058.911344537815),
#    ('parachute-home', 9046.911344537815),
#    ('lola-com', 9034.411344537815),
#    ('belong-3', 9034.411344537815)]),
#  ('GNMA GUARANTEED PASS THRU CERT',
#   'smartsheet-com',
#   [('smartsheet-com', 9061.411748396169),
#    ('pat-mcgrath-labs', 9051.411344537815),
#    ('turnkey-vacation-rentals', 9043.911344537815),
#    ('the-virtual-reality-company', 9023.911344537815),
#    ('the-players-tribune', 9022.411344537815)]),
#  ('Forward Foreign Currency Contract',
#   'concord',
#   [('concord', 9062.411344537815),
#    ('turnkey-vacation-rentals', 9034.411344537815),
#    ('cortera', 9034.411344537815),
#    ('contentsquare', 9033.411344537815),
#    ('fin-exploration-company', 9022.411344537815)]),
#  ('Fannie Mae Pool',
#   'poolside-ai',
#   [('poolside-ai', 9076.911344537815),
#    ('nto-ire-polus', 9065.411344537815),
#    ('annexon-biosciences', 9063.41139562044),
#    ('funnel', 9047.911344537815),
#    ('fanduel', 9041.911344537815)]),
#  ('HSBC Bank PLC',
#   'place',
#   [('place', 9049.411344537815),
#    ('spice-vc', 9016.911344537815),
#    ('scalyr', 8973.911344537815),
#    ('lyric-hospitality', 8972.911344537815),
#    ('haplox', 8970.411344537815)]),
#  ('FNMA',
#   'fdna',
#   [('fdna', 9156.411344537815),
#    ('nomad', 9082.411344537815),
#    ('mya-systems', 9054.411344537815),
#    ('finom', 9033.911344537815),
#    ('numa', 9019.911344537815)]),
#  ('GNMA',
#   'gamma',
#   [('gamma', 9114.411344537815),
#    ('mya-systems', 9055.411344537815),
#    ('nomad', 9054.411344537815),
#    ('numa', 9019.911344537815),
#    ('ringdna', 9004.911344537815)]),
#  ('Freedom Financial Asset Management LLC',
#   'digital-asset',
#   [('digital-asset', 9116.411344537815),
#    ('sms-assist', 9093.411344537815),
#    ('element-ai', 9084.911344537815),
#    ('smartrent', 9056.911344537815),
#    ('smartsheet-com', 9053.911748396169)]),
#  ('Government National Mortgage A',
#   'valon-mortgage',
#   [('valon-mortgage', 9202.911344537815),
#    ('generation-bio', 9112.411360910452),
#    ('convergent-dental', 9105.411344537815),
#    ('aurora-innovation', 9089.411344537815),
#    ('real-time-translation', 9086.411344537815)]),
#  ('Options Clearing Corp.',
#   'crimson-education',
#   [('crimson-education', 9131.411344537815),
#    ('clearco', 9125.911344537815),
#    ('eargo', 9105.911344537815),
#    ('conversionpoint-technologies', 9102.911344537815),
#    ('revolution-medicines', 9092.911704735807)]),
#  ('U.S. DOLLARS',
#   'solarflare',
#   [('solarflare', 9039.911344537815),
#    ('4d-molecular-therapeutics-4dmt', 9034.411408063643),
#    ('collibra', 9034.411344537815),
#    ('the-players-tribune', 9033.411344537815),
#    ('caribou-biosciences', 9018.911357635925)]),
#  ('Federal National Mortgage Association, Inc.',
#   'valon-mortgage',
#   [('valon-mortgage', 9189.911344537815),
#    ('real-time-translation', 9083.911344537815),
#    ('generation-bio', 9074.911360910452),
#    ('tempo-automation', 9058.411344537815),
#    ('c3-international', 9054.911344537815)]),
#  ('GNMA II GTD PASS THRU CTF MULTIPLE ISSUER',
#   'thrive-earlier-detection',
#   [('thrive-earlier-detection', 9012.911344537815),
#    ('the-players-tribune', 9006.411344537815),
#    ('moviepass', 9002.911344537815),
#    ('smartsheet-com', 8992.911748396169),
#    ('ziprecruiter', 8988.411413521188)]),
#  ('United States of America',
#   'states-title',
#   [('states-title', 9157.411344537815),
#    ('electrify-america', 9129.411344537815),
#    ('smartrent', 9104.911344537815),
#    ('ecosense', 9093.411344537815),
#    ('the-players-tribune', 9082.411344537815)]),
#  ('Federal Home Loan Mortgage Corporation',
#   'valon-mortgage',
#   [('valon-mortgage', 9210.911344537815),
#    ('noon-home', 9170.911344537815),
#    ('drone-racing-league', 9083.411344537815),
#    ('tamara-mellon', 9066.911344537815),
#    ('belong-3', 9062.411344537815)]),
#  ('Prosper Funding LLC',
#   'funding-circle',
#   [('funding-circle', 9371.411344537815),
#    ('property-finder', 9130.411344537815),
#    ('prowler-io', 9122.911344537815),
#    ('power-ledger', 9084.911344537815),
#    ('funnel', 9079.911344537815)]),
#  ('United States Treasury Note/Bond',
#   'states-title',
#   [('states-title', 9152.911344537815),
#    ('smartrent', 9072.911344537815),
#    ('onestream', 9059.9115515607),
#    ('turnkey-vacation-rentals', 9056.411344537815),
#    ('contentsquare', 9053.911344537815)]),
#  ('LendingClub Corp. - LCX PM',
#   'funding-circle',
#   [('funding-circle', 9144.911344537815),
#    ('collective-medical', 9039.911344537815),
#    ('elixir-medical', 9027.411344537815),
#    ('inari-medical', 9012.911640191238),
#    ('bold-penguin', 9009.911344537815)]),
#  ('UST NOTES',
#   'onetrust',
#   [('onetrust', 9140.411344537815),
#    ('hytrust', 9100.911344537815),
#    ('igneous-systems', 9086.911344537815),
#    ('intent-media', 9081.411344537815),
#    ('onestream', 9054.9115515607)]),
#  ('Freddie Mac Gold Pool',
#   'nto-ire-polus',
#   [('nto-ire-polus', 9031.911344537815),
#    ('power-ledger', 9001.911344537815),
#    ('yieldmo', 9001.411344537815),
#    ('revolution-medicines', 8997.911704735807),
#    ('fieldwirelabs', 8996.411344537815)]),
#  ('Fannie Mae - CAS',
#   'cashfree',
#   [('cashfree', 9075.911344537815),
#    ('carsaver', 9072.411344537815),
#    ('marine-layer', 9068.911344537815),
#    ('pie-insurance', 9061.911344537815),
#    ('cafex-communications', 9050.911344537815)]),
#  ('LCH Limited',
#   'hired',
#   [('hired', 9106.911344537815),
#    ('limeade', 9100.911344537815),
#    ('lightspeed-pos', 9090.911460528845),
#    ('freetrade', 9074.411344537815),
#    ('unified', 9074.411344537815)]),
#  ('UNITED STATES TREASURY',
#   'states-title',
#   [('states-title', 9150.911344537815),
#    ('smartrent', 9110.411344537815),
#    ('threat-stack', 9101.411344537815),
#    ('aeternity', 9072.911344537815),
#    ('turnkey-vacation-rentals', 9070.911344537815)]),
#  ('Chicago Mercantile Exchange',
#   'stack-exchange',
#   [('stack-exchange', 9255.411344537815),
#    ('science-exchange', 9129.911344537815),
#    ('generation-bio', 9122.911360910452),
#    ('royalty-exchange', 9119.911344537815),
#    ('element-ai', 9092.411344537815)]),
#  ('Freddie Mac - STACR',
#   'stay-alfred',
#   [('stay-alfred', 9134.911344537815),
#    ('stark-future', 9077.411344537815),
#    ('stack-exchange', 9030.911344537815),
#    ('select-star', 9029.411344537815),
#    ('freetrade', 9026.911344537815)]),
#  ('Goldman Sachs International',
#   'c3-international',
#   [('c3-international', 9323.411344537815),
#    ('branch-international', 9234.411344537815),
#    ('internet-of-services-foundation', 9112.911344537815),
#    ('radius', 9109.411344537815),
#    ('fin-exploration-company', 9099.911344537815)]),
#  ('Ginnie Mae II Pool',
#   'nto-ire-polus',
#   [('nto-ire-polus', 9045.411344537815),
#    ('inari-medical', 9044.911640191238),
#    ('pie-insurance', 9042.911344537815),
#    ('wooo-social-games', 9029.911344537815),
#    ('inozyme-pharma', 9002.91138041208)]),
#  ('FHLMC Multifamily Structured Pass Through Certs.',
#   'turnkey-vacation-rentals',
#   [('turnkey-vacation-rentals', 9025.411344537815),
#    ('the-players-tribune', 8993.411344537815),
#    ('terawatt-infrastructure', 8980.411344537815),
#    ('smartrent', 8978.411344537815),
#    ('ironnet-cybersecurity', 8974.911344537815)]),
#  ('BANK OF AMERICA CORPORATION',
#   'electrify-america',
#   [('electrify-america', 9389.411344537815),
#    ('medrio', 9180.911344537815),
#    ('aperia-technologies', 9157.911344537815),
#    ('numerify', 9147.411344537815),
#    ('icon-aircraft', 9134.911344537815)]),
#  ('T-MOBILE USA INC',
#   'yello-mobile',
#   [('yello-mobile', 9341.411344537815),
#    ('perfecto-mobile', 9173.911344537815),
#    ('movius', 9141.411344537815),
#    ('kobalt-music', 9120.911344537815),
#    ('bite-squad', 9102.411344537815)]),
#  ('Chicago Board of Trade',
#   'leaf-trade',
#   [('leaf-trade', 9184.411344537815),
#    ('squaretrade', 9096.911344537815),
#    ('accolade', 9075.911372698749),
#    ('acadiasoft', 9068.411344537815),
#    ('omni-orthopaedics', 9060.411344537815)]),
#  ('State of California',
#   'stay-alfred',
#   [('stay-alfred', 9155.411344537815),
#    ('finite-state', 9101.911344537815),
#    ('girnarsoft', 9080.411344537815),
#    ('acadiasoft', 9077.411344537815),
#    ('instart', 9073.411344537815)]),
#  ('HSBC HOLDINGS PLC',
#   'place',
#   [('place', 9049.411344537815),
#    ('spice-vc', 9016.911344537815),
#    ('scalyr', 8973.911344537815),
#    ('lyric-hospitality', 8972.911344537815),
#    ('haplox', 8970.411344537815)]),
#  ('Fidelity Revere Street Trust',
#   'high-fidelity',
#   [('high-fidelity', 9281.911344537815),
#    ('the-players-tribune', 9063.911344537815),
#    ('main-street-hub', 9055.911344537815),
#    ('deliverr', 9050.411344537815),
#    ('elevate-services', 9047.411344537815)]),
#  ('Barclays Bank PLC',
#   'backlotcars',
#   [('backlotcars', 9100.411344537815),
#    ('aras', 9080.911344537815),
#    ('balance-therapeutics', 9079.411344537815),
#    ('icon-aircraft', 9069.411344537815),
#    ('d1-brands', 9043.411344537815)]),
#  ('UBS AG',
#   'adm-labs',
#   [('adm-labs', 9013.911344537815),
#    ('augur', 9008.411344537815),
#    ('genius', 9006.911344537815),
#    ('igneous-systems', 9005.911344537815),
#    ('augur-0', 8985.411344537815)]),
#  ('JPMorgan Chase Bank, National Association',
#   'tempo-automation',
#   [('tempo-automation', 9079.911344537815),
#    ('real-time-translation', 9072.411344537815),
#    ('c3-international', 9069.911344537815),
#    ('generation-bio', 9068.411360910452),
#    ('fin-exploration-company', 9055.411344537815)]),
#  ('CHARTER COMM OPT LLC/CAP',
#   'chartbeat',
#   [('chartbeat', 9088.411344537815),
#    ('darktrace', 9060.411344537815),
#    ('character-ai', 9059.911344537815),
#    ('care-of', 9053.911344537815),
#    ('achates-power', 9052.411344537815)]),
#  ('COMM Mortgage Trust',
#   'valon-mortgage',
#   [('valon-mortgage', 9203.411344537815),
#    ('onetrust', 9172.911344537815),
#    ('cortera', 9115.911344537815),
#    ('monday-com', 9105.913401013659),
#    ('trust-me-vodka', 9105.411344537815)]),
#  ('BNP PARIBAS',
#   'aras',
#   [('aras', 9076.411344537815),
#    ('predibase', 9061.911344537815),
#    ('armis', 9061.911344537815),
#    ('caribou-biosciences', 9055.911357635925),
#    ('nkarta-therapeutics', 9054.911371534474)]),
#  ('HOME DEPOT INC',
#   'noon-home',
#   [('noon-home', 9270.911344537815),
#    ('parachute-home', 9150.411344537815),
#    ('homie', 9146.911344537815),
#    ('belong-3', 9115.411344537815),
#    ('adicet-bio', 9112.911354725233)]),
#  ('UNITED STATES TREASURY BOND',
#   'states-title',
#   [('states-title', 9151.911344537815),
#    ('smartrent', 9103.911344537815),
#    ('onestream', 9086.4115515607),
#    ('turnkey-vacation-rentals', 9082.411344537815),
#    ('threat-stack', 9071.911344537815)]),
#  ('Morgan Stanley & Co. International PLC',
#   'c3-international',
#   [('c3-international', 9306.411344537815),
#    ('branch-international', 9215.411344537815),
#    ('envoy-global', 9093.911344537815),
#    ('contentsquare', 9083.411344537815),
#    ('generation-bio', 9082.411360910452)]),
#  ('GS Mortgage Securities Trust',
#   'valon-mortgage',
#   [('valon-mortgage', 9158.411344537815),
#    ('securitize', 9095.411344537815),
#    ('transmit-security', 9084.911344537815),
#    ('orca-security', 9068.411344537815),
#    ('ziprecruiter', 9056.911413521188)]),
#  ('Citibank, National Association',
#   'c3-international',
#   [('c3-international', 9115.411344537815),
#    ('real-time-translation', 9105.911344537815),
#    ('crimson-education', 9103.911344537815),
#    ('generation-bio', 9100.411360910452),
#    ('tempo-automation', 9086.911344537815)]),
#  ('State Street Bank and Trust Company',
#   'the-virtual-reality-company',
#   [('the-virtual-reality-company', 9159.411344537815),
#    ('states-title', 9136.411344537815),
#    ('main-street-hub', 9127.411344537815),
#    ('onetrust', 9119.911344537815),
#    ('smartsheet-com', 9114.911748396169)]),
#  ('US TREASURY N/B',
#   'surkus',
#   [('surkus', 9084.911344537815),
#    ('tory-burch', 9050.411344537815),
#    ('onestream', 9047.4115515607),
#    ('onetrust', 9046.911344537815),
#    ('contentsquare', 9041.911344537815)]),
#  ('AMAZON.COM INC',
#   'monday-com',
#   [('monday-com', 9312.913401013659),
#    ('artcom', 9191.911344537815),
#    ('pro-com', 9160.911344537815),
#    ('way-com', 9156.411344537815),
#    ('tempo-automation', 9100.911344537815)]),
#  ('UMBS, TBA',
#   'bumble',
#   [('bumble', 9096.411392345912),
#    ('bombas', 9050.411344537815),
#    ('blu-homes', 9018.911344537815),
#    ('kobalt-music', 9017.411344537815),
#    ('adm-labs', 9014.911344537815)]),
#  ('Morgan Stanley & Co. LLC',
#   'monday-com',
#   [('monday-com', 9168.913401013659),
#    ('scale-computing', 9128.911344537815),
#    ('stay-alfred', 9104.411344537815),
#    ('congatec', 9101.411344537815),
#    ('mystery-tackle-box', 9100.411344537815)]),
#  ('GENERAL MOTORS FINL CO',
#   'local-motors',
#   [('local-motors', 9224.911344537815),
#    ('via-motors', 9206.411344537815),
#    ('lucid-motors', 9195.911344537815),
#    ('generation-bio', 9185.911360910452),
#    ('general-assembly', 9124.911344537815)]),
#  ('New York State Dormitory Authority',
#   'finite-state',
#   [('finite-state', 9059.411344537815),
#    ('turnkey-vacation-rentals', 9041.911344537815),
#    ('tempo-automation', 9034.911344537815),
#    ('voyage-auto', 9031.911344537815),
#    ('stay-alfred', 9024.411344537815)]),
#  ('FX Forwards',
#   'portworx',
#   [('portworx', 9073.911344537815),
#    ('dayforward', 9063.911344537815),
#    ('d1-brands', 9054.411344537815),
#    ('infoworks', 9043.411344537815),
#    ('orchard-platform', 9029.911344537815)]),
#  ('JP Morgan Mortgage Trust',
#   'valon-mortgage',
#   [('valon-mortgage', 9162.411344537815),
#    ('onetrust', 9103.411344537815),
#    ('omni-orthopaedics', 9057.411344537815),
#    ('paymentus', 9048.911498440593),
#    ('renewable-trust', 9040.911344537815)]),
#  ('Government National Mortgage Association 2',
#   'valon-mortgage',
#   [('valon-mortgage', 9170.911344537815),
#    ('generation-bio', 9103.911360910452),
#    ('convergent-dental', 9075.411344537815),
#    ('real-time-translation', 9074.911344537815),
#    ('turnkey-vacation-rentals', 9060.911344537815)]),
#  ('Freddie Mac Pool',
#   'nto-ire-polus',
#   [('nto-ire-polus', 9036.411344537815),
#    ('freeline-therapeutics', 9034.911344537815),
#    ('kreditech', 9031.411344537815),
#    ('potrero-medical', 9022.411344537815),
#    ('stay-alfred', 9019.411344537815)]),
#  ('HSBC Holdings PLC',
#   'place',
#   [('place', 9049.411344537815),
#    ('spice-vc', 9016.911344537815),
#    ('scalyr', 8973.911344537815),
#    ('lyric-hospitality', 8972.911344537815),
#    ('haplox', 8970.411344537815)]),
#  ('Currency Forward Contract',
#   'concord',
#   [('concord', 9122.411344537815),
#    ('cortera', 9079.411344537815),
#    ('contentsquare', 9062.911344537815),
#    ('turnkey-vacation-rentals', 9053.911344537815),
#    ('intact-vascular', 9052.911344537815)]),
#  ('PACIFIC GAS & ELECTRIC',
#   'specific-media',
#   [('specific-media', 9110.411344537815),
#    ('electrify-america', 9078.911344537815),
#    ('go-electra', 9061.411344537815),
#    ('haifa-chemicals', 9060.411344537815),
#    ('ultrahaptics', 9037.411344537815)]),
#  ('BNP Paribas SA',
#   'passage-bio',
#   [('passage-bio', 9124.411348831085),
#    ('caribou-biosciences', 9077.911357635925),
#    ('aras', 9052.411344537815),
#    ('capriza', 9014.911344537815),
#    ('host-analytics', 9013.911344537815)]),
#  ('BRISTOL-MYERS SQUIBB CO',
#   'blu-homes',
#   [('blu-homes', 9061.411344537815),
#    ('bite-squad', 9052.411344537815),
#    ('bigcommerce', 9043.411385360254),
#    ('sqz-biotech', 9040.411344537815),
#    ('generation-bio', 9037.411360910452)]),
#  ('MORGAN STANLEY & CO. LLC',
#   'monday-com',
#   [('monday-com', 9168.913401013659),
#    ('scale-computing', 9128.911344537815),
#    ('stay-alfred', 9104.411344537815),
#    ('congatec', 9101.411344537815),
#    ('mystery-tackle-box', 9100.411344537815)]),
#  ('Credit Suisse Mortgage Trust',
#   'valon-mortgage',
#   [('valon-mortgage', 9161.911344537815),
#    ('real-time-translation', 9058.411344537815),
#    ('onetrust', 9048.411344537815),
#    ('magisto', 9040.411344537815),
#    ('omni-orthopaedics', 9035.911344537815)]),
#  ('Ginnie Mae I Pool',
#   'nto-ire-polus',
#   [('nto-ire-polus', 9059.411344537815),
#    ('pie-insurance', 9055.411344537815),
#    ('inari-medical', 9047.411640191238),
#    ('wooo-social-games', 9039.911344537815),
#    ('improbable', 9013.411344537815)]),
#  ('Treasury, United States Department of',
#   'states-title',
#   [('states-title', 9130.911344537815),
#    ('turnkey-vacation-rentals', 9072.911344537815),
#    ('the-players-tribune', 9060.911344537815),
#    ('smartrent', 9052.411344537815),
#    ('darktrace', 9047.911344537815)]),
#  ('GOVERNMENT NATIONAL MORTGAGE A',
#   'valon-mortgage',
#   [('valon-mortgage', 9202.911344537815),
#    ('generation-bio', 9112.411360910452),
#    ('convergent-dental', 9105.411344537815),
#    ('aurora-innovation', 9089.411344537815),
#    ('real-time-translation', 9086.411344537815)]),
#  ('Amazon.com Inc',
#   'monday-com',
#   [('monday-com', 9312.913401013659),
#    ('artcom', 9191.911344537815),
#    ('pro-com', 9160.911344537815),
#    ('way-com', 9156.411344537815),
#    ('tempo-automation', 9100.911344537815)]),
#  ('HCA INC',
#   'can-capital',
#   [('can-capital', 9117.411344537815),
#    ('hotchalk', 9039.411344537815),
#    ('hart', 9024.411344537815),
#    ('hazel-technologies', 9007.411344537815),
#    ('checkmate-pharmaceuticals', 8989.411344537815)]),
#  ('FORD MOTOR CREDIT CO LLC',
#   'lucid-motors',
#   [('lucid-motors', 9140.911344537815),
#    ('orderco', 9072.411344537815),
#    ('concord', 9070.911344537815),
#    ('redbooth', 9065.911344537815),
#    ('virgin-orbit', 9061.411344537815)]),
#  ('Deutsche Bank AG',
#   'doubledutch',
#   [('doubledutch', 9078.911344537815),
#    ('athletic-greens', 9066.911344537815),
#    ('dosh', 9058.911344537815),
#    ('the-agency', 9036.411344537815),
#    ('squarespace', 9035.911682832859)]),
#  ('SOUTHERN CAL EDISON',
#   'crimson-education',
#   [('crimson-education', 9114.911344537815),
#    ('acadiasoft', 9107.911344537815),
#    ('stay-alfred', 9081.411344537815),
#    ('souche', 9080.911344537815),
#    ('revolution-medicines', 9076.911704735807)]),
#  ('Citibank NA',
#   'iovation',
#   [('iovation', 9130.911344537815),
#    ('instana', 9124.411344537815),
#    ('act-on', 9108.411344537815),
#    ('trilumina', 9069.911344537815),
#    ('fictiv', 9066.411344537815)]),
#  ('BARCLAYS PLC',
#   'backlotcars',
#   [('backlotcars', 9100.411344537815),
#    ('aras', 9080.911344537815),
#    ('balance-therapeutics', 9079.411344537815),
#    ('icon-aircraft', 9069.411344537815),
#    ('d1-brands', 9043.411344537815)]),
#  ('State Street Bank & Trust Co.',
#   'smartsheet-com',
#   [('smartsheet-com', 9152.911748396169),
#    ('smartrent', 9148.911344537815),
#    ('onetrust', 9139.411344537815),
#    ('states-title', 9119.411344537815),
#    ('main-street-hub', 9109.911344537815)]),
#  ('Citibank N.A.',
#   'act-on',
#   [('act-on', 9210.911344537815),
#    ('iovation', 9115.911344537815),
#    ('afiniti', 9104.411344537815),
#    ('tact-ai', 9099.911344537815),
#    ('icon-aircraft', 9078.411344537815)]),
#  ('AERCAP IRELAND CAP/GLOBA',
#   'icon-aircraft',
#   [('icon-aircraft', 9063.411344537815),
#    ('accolade', 9049.411372698749),
#    ('lola-com', 9041.411344537815),
#    ('articulate', 9038.911344537815),
#    ('envoy-global', 9032.411344537815)]),
#  ('Metropolitan Transportation Authority',
#   'monolith-materials',
#   [('monolith-materials', 9109.911344537815),
#    ('threatmetrix', 9089.411344537815),
#    ('algorithmia', 9082.411344537815),
#    ('virgin-orbit', 9076.911344537815),
#    ('tempo-automation', 9062.411344537815)]),
#  ('BANK OF NY MELLON CORP',
#   'tamara-mellon',
#   [('tamara-mellon', 9247.911344537815),
#    ('monday-com', 9130.913401013659),
#    ('noon-home', 9090.411344537815),
#    ('meow-wolf', 9080.411344537815),
#    ('peloton-technology', 9053.911344537815)]),
#  ('AstraZeneca PLC',
#   'astra-space',
#   [('astra-space', 9109.911344537815),
#    ('zenreach', 9108.911344537815),
#    ('abstract', 9100.411344537815),
#    ('pie-insurance', 9085.911344537815),
#    ('smartrent', 9053.911344537815)]),
#  ('ROYAL BANK OF CANADA',
#   'acadiasoft',
#   [('acadiasoft', 9065.911344537815),
#    ('royole', 9063.911344537815),
#    ('lola-com', 9055.411344537815),
#    ('care-of', 9051.411344537815),
#    ('camunda-services', 9050.411344537815)]),
#  ("LOWE'S COS INC",
#   'ecosense',
#   [('ecosense', 9111.911344537815),
#    ('life-biosciences', 9088.411344537815),
#    ('lola-com', 9085.911344537815),
#    ('styleseat', 9058.911344537815),
#    ('pro-com', 9057.911344537815)]),
#  ('Federal Home Loan Mortgage Corp.',
#   'valon-mortgage',
#   [('valon-mortgage', 9204.411344537815),
#    ('noon-home', 9187.911344537815),
#    ('drone-racing-league', 9068.411344537815),
#    ('parachute-home', 9062.911344537815),
#    ('the-virtual-reality-company', 9059.911344537815)]),
#  ('State of Illinois',
#   'finite-state',
#   [('finite-state', 9118.411344537815),
#    ('stratos-genomics', 9091.911344537815),
#    ('instart', 9090.411344537815),
#    ('stay-alfred', 9071.911344537815),
#    ('host-analytics', 9053.911344537815)]),
#  ('MITSUBISHI UFJ FIN GRP',
#   'bonfire-studios',
#   [('bonfire-studios', 9017.411344537815),
#    ('afiniti', 9000.411344537815),
#    ('flipdish', 8995.411344537815),
#    ('finagraph', 8992.411344537815),
#    ('intuition-robotics', 8989.411344537815)]),
#  ('UBS GROUP AG',
#   'adm-labs',
#   [('adm-labs', 9013.911344537815),
#    ('augur', 9008.411344537815),
#    ('genius', 9006.911344537815),
#    ('igneous-systems', 9005.911344537815),
#    ('augur-0', 8985.411344537815)]),
#  ('FREDDIE MAC',
#   'stay-alfred',
#   [('stay-alfred', 9074.411344537815),
#    ('freeline-therapeutics', 9072.411344537815),
#    ('kreditech', 9070.411344537815),
#    ('freetrade', 9068.411344537815),
#    ('fieldwirelabs', 9035.911344537815)]),
#  ('Barclays PLC',
#   'backlotcars',
#   [('backlotcars', 9100.411344537815),
#    ('aras', 9080.911344537815),
#    ('balance-therapeutics', 9079.411344537815),
#    ('icon-aircraft', 9069.411344537815),
#    ('d1-brands', 9043.411344537815)]),
#  ("McDonald's Corp",
#   'monday-com',
#   [('monday-com', 9144.913401013659),
#    ('icon-aircraft', 9066.911344537815),
#    ('offerpad', 9061.911365130953),
#    ('ctrl-labs', 9053.911344537815),
#    ('comau', 9046.911344537815)]),
#  ('CDS',
#   'dosh',
#   [('dosh', 9114.411344537815),
#    ('ceros', 8995.411344537815),
#    ('dose', 8963.911344537815),
#    ('lytics', 8954.411344537815),
#    ('vacasa', 8954.411344537815)]),
#  ('CCO HLDGS LLC/CAP CORP',
#   'accolade',
#   [('accolade', 9081.411372698749),
#    ('colorchip', 9058.411344537815),
#    ('concord', 9051.911344537815),
#    ('ctrl-labs', 9042.411344537815),
#    ('orderco', 9034.911344537815)]),
#  ('PETROLEOS MEXICANOS',
#   'potrero-medical',
#   [('potrero-medical', 9155.411344537815),
#    ('revolution-medicines', 9143.911704735807),
#    ('prowler-io', 9115.911344537815),
#    ('kronos-bio', 9100.911351669009),
#    ('paperless-post', 9100.911344537815)]),
#  ('Goldman Sachs Group Inc/The',
#   'parachute-home',
#   [('parachute-home', 9110.411344537815),
#    ('vector-launch', 9094.411344537815),
#    ('the-wing', 9086.411344537815),
#    ('rancher', 9082.911344537815),
#    ('smartsheet-com', 9081.411748396169)]),
#  ('ENTERPRISE PRODUCTS OPER',
#   'osom-products',
#   [('osom-products', 9162.411344537815),
#    ('conversionpoint-technologies', 9107.411344537815),
#    ('movius', 9101.911344537815),
#    ('nto-ire-polus', 9098.411344537815),
#    ('radius', 9092.911344537815)]),
#  ('Merck & Co Inc',
#   'bigcommerce',
#   [('bigcommerce', 9156.411385360254),
#    ('countertack', 9127.411344537815),
#    ('orderco', 9111.911344537815),
#    ('mercor', 9107.911344537815),
#    ('makeblock', 9098.911344537815)]),
#  ('GOLDMAN SACHS & CO. LLC',
#   'monday-com',
#   [('monday-com', 9070.913401013659),
#    ('cool-planet-energy-systems', 9063.411344537815),
#    ('lola-com', 9053.411344537815),
#    ('solana', 9047.911344537815),
#    ('comau', 9040.911344537815)]),
#  ('TOYOTA MOTOR CREDIT CORP',
#   'the-virtual-reality-company',
#   [('the-virtual-reality-company', 9087.911344537815),
#    ('nikola-motor-company', 9077.411344537815),
#    ('ironnet-cybersecurity', 9063.411344537815),
#    ('lucid-motors', 9060.411344537815),
#    ('root-insurance', 9044.911668352172)]),
#  ('BX Trust',
#   'onetrust',
#   [('onetrust', 9266.411344537815),
#    ('trust-me-vodka', 9228.911344537815),
#    ('renewable-trust', 9225.911344537815),
#    ('hytrust', 9219.911344537815),
#    ('birst', 9093.411344537815)]),
#  ('Towd Point Mortgage Trust',
#   'valon-mortgage',
#   [('valon-mortgage', 9166.411344537815),
#    ('onetrust', 9070.411344537815),
#    ('nto-ire-polus', 9067.911344537815),
#    ('trust-me-vodka', 9045.911344537815),
#    ('quinto-andar', 9032.411344537815)]),
#  ('SUMITOMO MITSUI FINL GRP',
#   'bonfire-studios',
#   [('bonfire-studios', 9017.911344537815),
#    ('afiniti', 9008.411344537815),
#    ('algorithmia', 9002.911344537815),
#    ('intuition-robotics', 9000.411344537815),
#    ('transmit-security', 8995.911344537815)]),
#  ('Fnma Pass-Thru I',
#   'moviepass',
#   [('moviepass', 9087.911344537815),
#    ('the-players-tribune', 9056.911344537815),
#    ('passport', 9053.911344537815),
#    ('patronus-ai', 9049.411344537815),
#    ('finastra', 9044.911344537815)]),
#  ('FEDERAL HOME LN MTG CORP MULTICLASS MTG PARTN CTF GTD',
#   'noon-home',
#   [('noon-home', 9147.411344537815),
#    ('parachute-home', 9027.911344537815),
#    ('real-time-translation', 9024.411344537815),
#    ('home-chef', 9009.911344537815),
#    ('computer-simulation-technology', 9003.411344537815)]),
#  ('CSC HOLDINGS LLC',
#   'ceros',
#   [('ceros', 9024.911344537815),
#    ('easic', 9015.411344537815),
#    ('scalyr', 8983.911344537815),
#    ('cibus', 8973.911344537815),
#    ('erasca', 8972.911363166237)]),
#  ('MORGAN STANLEY & COMPANY LLC',
#   'monday-com',
#   [('monday-com', 9198.913401013659),
#    ('the-virtual-reality-company', 9174.411344537815),
#    ('stay-alfred', 9153.911344537815),
#    ('scale-computing', 9146.411344537815),
#    ('fin-exploration-company', 9143.911344537815)]),
#  ('City of New York NY',
#   'cityblock-capital',
#   [('cityblock-capital', 9139.411344537815),
#    ('jam-city', 9096.911344537815),
#    ('schrodinger', 9091.911344537815),
#    ('kyber-network', 9086.911344537815),
#    ('cumulus-networks', 9071.911344537815)]),
#  ('ELEVANCE HEALTH INC',
#   'elevance-renewable-sciences',
#   [('elevance-renewable-sciences', 9349.911344537815),
#    ('xp-health', 9243.911344537815),
#    ('cala-health', 9234.911344537815),
#    ('oshi-health', 9188.411344537815),
#    ('scene-health', 9184.411344537815)]),
#  ('New Residential Mortgage Loan Trust',
#   'valon-mortgage',
#   [('valon-mortgage', 9220.411344537815),
#    ('convergent-dental', 9067.411344537815),
#    ('elevance-renewable-sciences', 9054.911344537815),
#    ('omni-orthopaedics', 9049.411344537815),
#    ('renewable-trust', 9037.411344537815)]),
#  ('HCA Inc',
#   'can-capital',
#   [('can-capital', 9117.411344537815),
#    ('hotchalk', 9039.411344537815),
#    ('hart', 9024.411344537815),
#    ('hazel-technologies', 9007.411344537815),
#    ('checkmate-pharmaceuticals', 8989.411344537815)]),
#  ('JPMORGAN CHASE and CO',
#   'vector-launch',
#   [('vector-launch', 9100.911344537815),
#    ('achates-power', 9091.411344537815),
#    ('monday-com', 9056.913401013659),
#    ('icon-aircraft', 9056.411344537815),
#    ('langchain', 9054.411344537815)]),
#  ('CIGNA CORP',
#   'ncino',
#   [('ncino', 9108.411588017105),
#    ('coinsquare', 9077.911344537815),
#    ('clearco', 9067.911344537815),
#    ('igneous-systems', 9064.411344537815),
#    ('graphcore', 9055.911344537815)]),
#  ('BROWN BROTHERS HARRIMAN & CO.',
#   'benson-hill-biosystems',
#   [('benson-hill-biosystems', 9079.911344537815),
#    ('kronos-bio', 9047.411351669009),
#    ('primal-kitchen', 9045.411344537815),
#    ('inozyme-pharma', 9041.41138041208),
#    ('bag-borrow-or-steal', 9039.411344537815)]),
#  ('BAT CAPITAL CORP',
#   'act-on',
#   [('act-on', 9117.911344537815),
#    ('artcom', 9109.411344537815),
#    ('backlotcars', 9091.911344537815),
#    ('blackthorn-therapeutics', 9088.911344537815),
#    ('avidbots-corp', 9080.911344537815)]),
#  ('Wells Fargo Commercial Mortgage Trust',
#   'valon-mortgage',
#   [('valon-mortgage', 9180.411344537815),
#    ('bigcommerce', 9054.911385360254),
#    ('bag-borrow-or-steal', 9046.411344537815),
#    ('the-players-tribune', 9042.411344537815),
#    ('parachute-home', 9042.411344537815)]),
#  ('FHLMC',
#   'mofilm',
#   [('mofilm', 9007.411344537815),
#    ('humacyte', 8977.411344537815),
#    ('hims', 8964.911344537815),
#    ('freshly', 8952.411344537815),
#    ('nomics', 8924.411344537815)]),
#  ('JP Morgan Chase Commercial Mortgage Sec Trust',
#   'valon-mortgage',
#   [('valon-mortgage', 9146.411344537815),
#    ('smartsheet-com', 9036.911748396169),
#    ('parachute-home', 9033.911344537815),
#    ('trust-me-vodka', 9029.911344537815),
#    ('omni-orthopaedics', 9024.411344537815)]),
#  ('CITIGROUP INC.',
#   'fictiv',
#   [('fictiv', 9151.411344537815),
#    ('litify', 9126.411344537815),
#    ('securitize', 9101.911344537815),
#    ('vlocity', 9076.411344537815),
#    ('iovation', 9074.911344537815)]),
#  ('New York City Transitional Finance Authority Future Tax Secured Revenue',
#   'stark-future',
#   [('stark-future', 9132.911344537815),
#    ('faraday-future', 9112.911344537815),
#    ('jam-city', 9045.411344537815),
#    ('parallel-finance', 9035.411344537815),
#    ('turnkey-vacation-rentals', 9013.411344537815)]),
#  ('PHILIP MORRIS INTL INC',
#   'nto-ire-polus',
#   [('nto-ire-polus', 9044.411344537815),
#    ('inmobi', 9040.411344537815),
#    ('linden-lab', 9039.411344537815),
#    ('infoworks', 9032.911344537815),
#    ('instart', 9025.411344537815)]),
#  ('Morgan Stanley Capital Services LLC',
#   'elevate-services',
#   [('elevate-services', 9290.411344537815),
#    ('internet-of-services-foundation', 9171.411344537815),
#    ('camunda-services', 9149.411344537815),
#    ('stay-alfred', 9099.411344537815),
#    ('orca-security', 9092.911344537815)]),
#  ('Petroleos Mexicanos',
#   'potrero-medical',
#   [('potrero-medical', 9155.411344537815),
#    ('revolution-medicines', 9143.911704735807),
#    ('prowler-io', 9115.911344537815),
#    ('kronos-bio', 9100.911351669009),
#    ('paperless-post', 9100.911344537815)]),
#  ('LLOYDS BANKING GROUP PLC',
#   'inozyme-pharma',
#   [('inozyme-pharma', 9015.41138041208),
#    ('nto-ire-polus', 9008.911344537815),
#    ('prowler-io', 9006.911344537815),
#    ('biosplice-therapeutics', 8988.911344537815),
#    ('lightspeed-pos', 8981.911460528845)]),
#  ('BNP Paribas',
#   'aras',
#   [('aras', 9076.411344537815),
#    ('predibase', 9061.911344537815),
#    ('armis', 9061.911344537815),
#    ('caribou-biosciences', 9055.911357635925),
#    ('nkarta-therapeutics', 9054.911371534474)]),
#  ('ALTRIA GROUP INC',
#   'kaltura',
#   [('kaltura', 9251.911353633725),
#    ('katerra', 9162.411344537815),
#    ('datrium', 9154.411344537815),
#    ('alltrails', 9151.911344537815),
#    ('capriza', 9146.411344537815)]),
#  ('LendingClub Corp.',
#   'funding-circle',
#   [('funding-circle', 9203.411344537815),
#    ('scale-computing', 9070.411344537815),
#    ('soundcloud', 9061.911344537815),
#    ('inari-medical', 9061.411640191238),
#    ('elixir-medical', 9056.911344537815)]),
#  ('Eurex Deutschland',
#   'biscayne-neurotherapeutics',
#   [('biscayne-neurotherapeutics', 9069.411344537815),
#    ('unravel-data', 9067.411344537815),
#    ('codecademy', 9059.411344537815),
#    ('dreamscape-immersive', 9053.411344537815),
#    ('scaleflux', 9048.411344537815)]),
#  ('JOHN DEERE CAPITAL CORP',
#   'orderco',
#   [('orderco', 9107.411344537815),
#    ('generation-bio', 9094.911360910452),
#    ('monday-com', 9075.913401013659),
#    ('coverhound', 9064.911344537815),
#    ('ecosense', 9063.911344537815)]),
#  ('Gilead Sciences Inc',
#   'sight-sciences',
#   [('sight-sciences', 9379.411384923651),
#    ('elevance-renewable-sciences', 9295.911344537815),
#    ('caris-life-sciences', 9227.411344537815),
#    ('easic', 9132.911344537815),
#    ('elevate-services', 9125.411344537815)]),
#  ('JPMorgan Chase Bank N.A.',
#   'achates-power',
#   [('achates-power', 9112.411344537815),
#    ('fin-exploration-company', 9062.411344537815),
#    ('vacasa', 9057.911344537815),
#    ('act-on', 9051.911344537815),
#    ('alphasense', 9037.411344537815)]),
#  ('DEUTSCHE BANK NY',
#   'codecademy',
#   [('codecademy', 9070.911344537815),
#    ('doubledutch', 9070.911344537815),
#    ('ensighten', 9064.911344537815),
#    ('aeternity', 9026.911344537815),
#    ('deskera', 9026.911344537815)]),
#  ('TRANSDIGM INC',
#   'rani-therapeutics',
#   [('rani-therapeutics', 9120.411361347054),
#    ('tango', 9087.411344537815),
#    ('paradigm', 9077.911344537815),
#    ('d1-brands', 9076.911344537815),
#    ('tangome', 9071.911344537815)]),
#  ('20 Year Standalone Fixed 2nd',
#   'stay-alfred',
#   [('stay-alfred', 9036.911344537815),
#    ('bonfire-studios', 9011.411344537815),
#    ('quinto-andar', 9006.411344537815),
#    ('flycleaners', 8996.411344537815),
#    ('styleseat', 8992.911344537815)]),
#  ('Bank of America, National Association',
#   'electrify-america',
#   [('electrify-america', 9118.411344537815),
#    ('wooo-social-games', 9085.911344537815),
#    ('crimson-education', 9077.411344537815),
#    ('c3-international', 9070.911344537815),
#    ('aurora-innovation', 9064.411344537815)]),
#  ('BPCE SA',
#   'kbp-biosciences',
#   [('kbp-biosciences', 9097.411344537815),
#    ('persado', 9094.411344537815),
#    ('et-solar', 9059.411344537815),
#    ('bite-squad', 9057.411344537815),
#    ('placester', 9054.911344537815)]),
#  ('NEXTERA ENERGY CAPITAL',
#   'nextcapital',
#   [('nextcapital', 9257.911344537815),
#    ('nexenta-systems', 9233.411344537815),
#    ('nextnav', 9186.411344537815),
#    ('tigera', 9172.911344537815),
#    ('onestream', 9169.9115515607)]),
#  ('New Jersey Transportation Trust Fund Authority',
#   'the-players-tribune',
#   [('the-players-tribune', 9043.911344537815),
#    ('onetrust', 9038.411344537815),
#    ('sentry-ai', 9037.411344537815),
#    ('cumulus-networks', 9022.911344537815),
#    ('renewable-trust', 9020.411344537815)]),
#  ('JPMorgan Chase & Co.',
#   'achates-power',
#   [('achates-power', 9080.911344537815),
#    ('monday-com', 9078.913401013659),
#    ('noon-home', 9066.911344537815),
#    ('checkmate-pharmaceuticals', 9066.911344537815),
#    ('act-on', 9065.911344537815)]),
#  ('BANCO SANTANDER SA',
#   'sonder-3',
#   [('sonder-3', 9117.911344537815),
#    ('bancor', 9099.411344537815),
#    ('squaretrade', 9087.911344537815),
#    ('backlotcars', 9087.411344537815),
#    ('sonder', 9085.411344537815)]),
#  ('BP CAP MARKETS AMERICA',
#   'electrify-america',
#   [('electrify-america', 9117.411344537815),
#    ('back-market', 9064.411344537815),
#    ('marketing-evolution', 9056.911344537815),
#    ('marine-layer', 9055.411344537815),
#    ('pat-mcgrath-labs', 9039.411344537815)]),
#  ('BENCHMARK Mortgage Trust',
#   'valon-mortgage',
#   [('valon-mortgage', 9188.911344537815),
#    ('onetrust', 9093.911344537815),
#    ('backlotcars', 9080.411344537815),
#    ('darktrace', 9079.411344537815),
#    ('stack-exchange', 9066.411344537815)]),
#  ('NATWEST GROUP PLC',
#   'twistlock',
#   [('twistlock', 9108.411344537815),
#    ('congatec', 9070.911344537815),
#    ('intent-media', 9046.411344537815),
#    ('astra-space', 9041.911344537815),
#    ('squarespace', 9036.911682832859)]),
#  ('Lloyds Banking Group PLC',
#   'inozyme-pharma',
#   [('inozyme-pharma', 9015.41138041208),
#    ('nto-ire-polus', 9008.911344537815),
#    ('prowler-io', 9006.911344537815),
#    ('biosplice-therapeutics', 8988.911344537815),
#    ('lightspeed-pos', 8981.911460528845)]),
#  ('EXXON MOBIL CORPORATION',
#   'inmobi',
#   [('inmobi', 9078.411344537815),
#    ('annexon-biosciences', 9066.91139562044),
#    ('benson-hill-biosystems', 9063.911344537815),
#    ('mofilm', 9060.911344537815),
#    ('exonics-therapeutics', 9058.911344537815)]),
#  ('IBM CORP',
#   'nikola-motor-company',
#   [('nikola-motor-company', 9050.411344537815),
#    ('ctrl-labs', 9048.911344537815),
#    ('monday-com', 9043.913401013659),
#    ('oric-pharmaceuticals', 9041.411344537815),
#    ('virgin-orbit', 9041.411344537815)]),
#  ('TORONTO-DOMINION BANK',
#   'kronos-bio',
#   [('kronos-bio', 9127.911351669009),
#    ('omni-orthopaedics', 9116.911344537815),
#    ('noon-home', 9096.411344537815),
#    ('root-insurance', 9091.411668352172),
#    ('revolution-medicines', 9081.911704735807)]),
#  ('ANHEUSER-BUSCH INBEV WOR',
#   'vector-launch',
#   [('vector-launch', 9075.911344537815),
#    ('cumulus-networks', 9071.911344537815),
#    ('xcor-aerospace', 9060.911344537815),
#    ('wooo-social-games', 9058.411344537815),
#    ('neuehouse', 9042.411344537815)]),
#  ('CHARLES SCHWAB CORP',
#   'sharespost-3',
#   [('sharespost-3', 9097.911344537815),
#    ('harvest-power', 9067.911344537815),
#    ('chai-research', 9059.911344537815),
#    ('paperless-post', 9055.911344537815),
#    ('scalefactor', 9055.911344537815)]),
#  ('UBS Group AG',
#   'adm-labs',
#   [('adm-labs', 9013.911344537815),
#    ('augur', 9008.411344537815),
#    ('genius', 9006.911344537815),
#    ('igneous-systems', 9005.911344537815),
#    ('augur-0', 8985.411344537815)]),
#  ('Bristol-Myers Squibb Co',
#   'blu-homes',
#   [('blu-homes', 9061.411344537815),
#    ('bite-squad', 9052.411344537815),
#    ('bigcommerce', 9043.411385360254),
#    ('sqz-biotech', 9040.411344537815),
#    ('generation-bio', 9037.411360910452)]),
#  ('Deutsche Bank Aktiengesellschaft',
#   'researchgate',
#   [('researchgate', 9032.411344537815),
#    ('icon-aircraft', 9009.911344537815),
#    ('the-agency', 9004.411344537815),
#    ('greenhouse', 9002.911344537815),
#    ('vector-launch', 9001.411344537815)]),
#  ('WILLIAMS COMPANIES INC',
#   'lola-com',
#   [('lola-com', 9115.411344537815),
#    ('conversica', 9107.911344537815),
#    ('wildlife-studios', 9089.411344537815),
#    ('litmus-automation', 9076.911344537815),
#    ('envoy-global', 9073.911344537815)]),
#  ('HYUNDAI CAPITAL AMERICA',
#   'electrify-america',
#   [('electrify-america', 9212.411344537815),
#    ('haifa-chemicals', 9090.411344537815),
#    ('zunum-aero', 9071.911344537815),
#    ('coverhound', 9068.411344537815),
#    ('kaminario', 9057.411344537815)]),
#  ('Bank of America Corporation',
#   'electrify-america',
#   [('electrify-america', 9389.411344537815),
#    ('medrio', 9180.911344537815),
#    ('aperia-technologies', 9157.911344537815),
#    ('numerify', 9147.411344537815),
#    ('icon-aircraft', 9134.911344537815)]),
#  ('WALT DISNEY COMPANY/THE',
#   'the-virtual-reality-company',
#   [('the-virtual-reality-company', 9283.411344537815),
#    ('the-bouqs', 9175.411344537815),
#    ('the-players-tribune', 9167.411344537815),
#    ('accompany-health', 9147.411344537815),
#    ('computer-simulation-technology', 9137.411344537815)]),
#  ('Altria Group Inc',
#   'kaltura',
#   [('kaltura', 9251.911353633725),
#    ('katerra', 9162.411344537815),
#    ('datrium', 9154.411344537815),
#    ('alltrails', 9151.911344537815),
#    ('capriza', 9146.411344537815)]),
#  ('ONEMAIN FINANCE CORP',
#   'pie-insurance',
#   [('pie-insurance', 9139.911344537815),
#    ('kin-insurance', 9125.411344537815),
#    ('parallel-finance', 9116.911344537815),
#    ('binance', 9102.411344537815),
#    ('spruce-finance', 9099.911344537815)]),
#  ('Home Depot Inc/The',
#   'noon-home',
#   [('noon-home', 9248.911344537815),
#    ('parachute-home', 9165.911344537815),
#    ('home-chef', 9140.911344537815),
#    ('omisego', 9096.411344537815),
#    ('blu-homes', 9093.911344537815)]),
#  ('SOCIETE GENERALE',
#   'elevance-renewable-sciences',
#   [('elevance-renewable-sciences', 9140.911344537815),
#    ('elevate-services', 9100.911344537815),
#    ('kenna-security', 9099.911344537815),
#    ('prescient', 9098.411344537815),
#    ('pie-insurance', 9082.911344537815)]),
#  ('CHICAGO MERCANTILE EXCHANGE',
#   'stack-exchange',
#   [('stack-exchange', 9255.411344537815),
#    ('science-exchange', 9129.911344537815),
#    ('generation-bio', 9122.911360910452),
#    ('royalty-exchange', 9119.911344537815),
#    ('element-ai', 9092.411344537815)]),
#  ('BANK OF NOVA SCOTIA',
#   'bossa-nova-robotics',
#   [('bossa-nova-robotics', 9194.411344537815),
#    ('affectiva', 9087.911344537815),
#    ('stay-alfred', 9084.911344537815),
#    ('ovation-tv', 9063.411344537815),
#    ('fictiv', 9047.911344537815)]),
#  ('Roche Holding AG',
#   'athletic-greens',
#   [('athletic-greens', 9108.411344537815),
#    ('schrodinger', 9068.911344537815),
#    ('kreditech', 9066.411344537815),
#    ('linden-lab', 9047.911344537815),
#    ('stockwell-ai', 9039.911344537815)]),
#  ('CON EDISON CO OF NY INC',
#   'monday-com',
#   [('monday-com', 9131.913401013659),
#    ('crimson-education', 9104.411344537815),
#    ('conversionpoint-technologies', 9083.411344537815),
#    ('generation-bio', 9074.911360910452),
#    ('moneylion', 9071.911344537815)]),
#  ('Morgan Stanley Capital I Trust',
#   'onetrust',
#   [('onetrust', 9135.911344537815),
#    ('host-analytics', 9097.911344537815),
#    ('renewable-trust', 9097.411344537815),
#    ('instart', 9063.911344537815),
#    ('turnkey-vacation-rentals', 9055.911344537815)]),
#  ('JPMORGAN CHASE & CO.',
#   'achates-power',
#   [('achates-power', 9080.911344537815),
#    ('monday-com', 9078.913401013659),
#    ('noon-home', 9066.911344537815),
#    ('checkmate-pharmaceuticals', 9066.911344537815),
#    ('act-on', 9065.911344537815)]),
#  ('Morgan Stanley BAML Trust',
#   'onetrust',
#   [('onetrust', 9105.411344537815),
#    ('stay-alfred', 9080.911344537815),
#    ('host-analytics', 9075.411344537815),
#    ('backlotcars', 9066.411344537815),
#    ('renewable-trust', 9065.911344537815)]),
#  ('ALTICE FRANCE SA',
#   'stay-alfred',
#   [('stay-alfred', 9155.911344537815),
#    ('altierre', 9155.411344537815),
#    ('vacasa', 9116.411344537815),
#    ('rancher', 9105.411344537815),
#    ('pie-insurance', 9104.911344537815)]),
#  ('NRG ENERGY INC',
#   'ring',
#   [('ring', 9090.411344537815),
#    ('cyngn', 8987.411371097869),
#    ('vungle', 8973.411344537815),
#    ('sonder', 8972.411344537815),
#    ('dianrong', 8966.411344537815)]),
#  ('BURLINGTN NORTH SANTA FE',
#   'bag-borrow-or-steal',
#   [('bag-borrow-or-steal', 9057.911344537815),
#    ('lightspeed-pos', 9046.411460528845),
#    ('brightfarms', 9042.411344537815),
#    ('igneous-systems', 9028.911344537815),
#    ('generation-bio', 9025.411360910452)]),
#  ('Verus Securitization Trust',
#   'securitize',
#   [('securitize', 9119.411344537815),
#    ('transmit-security', 9074.911344537815),
#    ('ironnet-cybersecurity', 9074.911344537815),
#    ('onetrust', 9070.411344537815),
#    ('ziprecruiter', 9063.911413521188)]),
#  ('30 Year Standalone Fixed 2nd',
#   'stay-alfred',
#   [('stay-alfred', 9035.911344537815),
#    ('bonfire-studios', 9011.411344537815),
#    ('quinto-andar', 8995.411344537815),
#    ('styleseat', 8990.911344537815),
#    ('flycleaners', 8985.411344537815)]),
#  ('Dominion Energy Inc',
#   'omniox',
#   [('omniox', 9174.411344537815),
#    ('domio', 9168.411344537815),
#    ('iovation', 9143.911344537815),
#    ('intuition-robotics', 9132.911344537815),
#    ('moneylion', 9127.911344537815)]),
#  ('Vodafone Group PLC',
#   'peloton-technology',
#   [('peloton-technology', 9086.911344537815),
#    ('livesafe', 9054.411344537815),
#    ('monday-com', 9043.913401013659),
#    ('codecademy', 9041.411344537815),
#    ('blue-danube-systems', 9035.911344537815)]),
#  ('Royal Bank of Canada',
#   'acadiasoft',
#   [('acadiasoft', 9065.911344537815),
#    ('royole', 9063.911344537815),
#    ('lola-com', 9055.411344537815),
#    ('care-of', 9051.411344537815),
#    ('camunda-services', 9050.411344537815)]),
#  ('WESTPAC BANKING CORP',
#   'scale-computing',
#   [('scale-computing', 9119.411344537815),
#    ('stack-exchange', 9104.411344537815),
#    ('onestream', 9097.9115515607),
#    ('congatec', 9097.911344537815),
#    ('corvus', 9095.911344537815)]),
#  ('COMCAST CORPORATION',
#   'comau',
#   [('comau', 9204.411344537815),
#    ('jobcase', 9153.911344537815),
#    ('nomics', 9147.411344537815),
#    ('compass-therapeutics', 9116.411357126553),
#    ('congatec', 9107.911344537815)]),
#  ('NEW YORK STOCK EXCHANGE',
#   'stack-exchange',
#   [('stack-exchange', 9247.411344537815),
#    ('science-exchange', 9121.411344537815),
#    ('royalty-exchange', 9113.911344537815),
#    ('kyber-network', 9069.411344537815),
#    ('schrodinger', 9040.411344537815)]),
#  ('MIZUHO FINANCIAL GROUP',
#   'vizio',
#   [('vizio', 9099.911426473762),
#    ('jumio-9', 9024.411344537815),
#    ('medrio', 9009.911344537815),
#    ('omniox', 8999.911344537815),
#    ('domio', 8992.411344537815)]),
#  ('DIAMONDBACK ENERGY INC',
#   'anaconda',
#   [('anaconda', 9054.411344537815),
#    ('oanda', 9047.911344537815),
#    ('monday-com', 9043.913401013659),
#    ('ownbackup', 9040.911344537815),
#    ('diamanti', 9027.411344537815)]),
#  ('ASML Holding NV',
#   'schrodinger',
#   [('schrodinger', 9063.411344537815),
#    ('applovin', 9059.912398498967),
#    ('mashgin-1', 9033.411344537815),
#    ('loopring', 9031.411344537815),
#    ('linden-lab', 9025.411344537815)]),
#  ('Bank of America N.A.',
#   'electrify-america',
#   [('electrify-america', 9273.911344537815),
#    ('inari-medical', 9168.411640191238),
#    ('medrio', 9108.911344537815),
#    ('numerify', 9087.411344537815),
#    ('icon-aircraft', 9086.911344537815)]),
#  ('DISCOVERY COMMUNICATIONS',
#   'tetra',
#   [('tetra', 9164.911344537815),
#    ('edgewise-therapeutics', 9136.911344537815),
#    ('doubleverify', 9117.911466495761),
#    ('deliverr', 9106.411344537815),
#    ('dstillery', 9100.411344537815)]),
#  ('Constellation Brands Inc',
#   'd1-brands',
#   [('d1-brands', 9338.911344537815),
#    ('branch-international', 9142.411344537815),
#    ('generation-bio', 9134.911360910452),
#    ('crimson-education', 9130.911344537815),
#    ('forum-brands', 9117.911344537815)]),
#  ('Procter & Gamble Co/The',
#   'parachute-home',
#   [('parachute-home', 9151.411344537815),
#    ('the-wing', 9122.411344537815),
#    ('pro-com', 9121.911344537815),
#    ('computer-simulation-technology', 9107.411344537815),
#    ('bigcommerce', 9099.911385360254)]),
#  ('State of Connecticut',
#   'vestiaire-collective',
#   [('vestiaire-collective', 9112.411344537815),
#    ('finite-state', 9106.911344537815),
#    ('onetrust', 9098.411344537815),
#    ('contentsquare', 9088.411344537815),
#    ('host-analytics', 9071.411344537815)]),
#  ('WELLS FARGO and CO',
#   'stockwell-ai',
#   [('stockwell-ai', 9078.911344537815),
#    ('eargo', 9063.911344537815),
#    ('allen-control-systems', 9054.411344537815),
#    ('argo-ai', 9050.911344537815),
#    ('backlotcars', 9044.911344537815)]),
#  ('SIRIUS XM RADIO INC',
#   'datrium',
#   [('datrium', 9054.411344537815),
#    ('radius', 9050.411344537815),
#    ('zimperium', 9028.911344537815),
#    ('brandless', 9027.911344537815),
#    ('duo-security', 9026.411344537815)]),
#  ('United States Treasury Notes',
#   'states-title',
#   [('states-title', 9154.911344537815),
#    ('smartrent', 9110.911344537815),
#    ('the-players-tribune', 9074.911344537815),
#    ('turnkey-vacation-rentals', 9074.411344537815),
#    ('threat-stack', 9064.911344537815)]),
#  ('SHELL INTERNATIONAL FIN',
#   'c3-international',
#   [('c3-international', 9337.411344537815),
#    ('branch-international', 9246.911344537815),
#    ('fin-exploration-company', 9128.411344537815),
#    ('generation-bio', 9121.411360910452),
#    ('integrate', 9117.911344537815)]),
#  ('Freddie Mac - SCRT',
#   'stay-alfred',
#   [('stay-alfred', 9077.411344537815),
#    ('kreditech', 9031.411344537815),
#    ('fieldwirelabs', 9029.911344537815),
#    ('freetrade', 9029.411344537815),
# ...
#  ('DEUTSCHE BANK AG',
#   'doubledutch',
#   [('doubledutch', 9078.911344537815),
#    ('athletic-greens', 9066.911344537815),
#    ('dosh', 9058.911344537815),
#    ('the-agency', 9036.411344537815),
#    ('squarespace', 9035.911682832859)]),
#  ('SOLD EUR/BOUGHT USD',
#   'bite-squad',
#   [('bite-squad', 9031.911344537815),
#    ('nto-ire-polus', 9016.411344537815),
#    ('lightspeed-pos', 9012.911460528845),
#    ('powerschool-group', 9012.411344537815),
#    ('kronos-bio', 9008.911351669009)]),
#  ('Epiroc AB',
#   'avero',
#   [('avero', 9138.411344537815),
#    ('applepie-capital', 9082.911344537815),
#    ('bluerock-therapeutics', 9081.411344537815),
#    ('protect-ai', 9063.411344537815),
#    ('esperanto-technologies', 9052.411344537815)]),
#  ('Skyworks Solutions Inc',
#   'cumulus-networks',
#   [('cumulus-networks', 9103.911344537815),
#    ('kumu-networks', 9086.911344537815),
#    ('workrise', 9081.911344537815),
#    ('upwork-4', 9079.911420288545),
#    ('skupos', 9072.911344537815)]),
#  ('ELASTIC NV',
#   'lastline',
#   [('lastline', 9183.411344537815),
#    ('easic', 9170.911344537815),
#    ('abstract', 9100.411344537815),
#    ('esilicon', 9076.411344537815),
#    ('act-on', 9062.411344537815)]),
#  ('Mexico Government International Bond',
#   'c3-international',
#   [('c3-international', 9293.911344537815),
#    ('branch-international', 9232.911344537815),
#    ('generation-bio', 9138.411360910452),
#    ('convergent-dental', 9091.411344537815),
#    ('turnkey-vacation-rentals', 9067.911344537815)]),
#  ('WPP PLC',
#   'winc',
#   [('winc', 9402.911344537815),
#    ('place', 9084.411344537815),
#    ('way-com', 8997.411344537815),
#    ('plex', 8976.911344537815),
#    ('plex-systems', 8966.411344537815)]),
#  ('SSE PLC',
#   'place',
#   [('place', 9160.411344537815),
#    ('placester', 9124.911344537815),
#    ('plex-systems', 9085.411344537815),
#    ('plex', 9069.911344537815),
#    ('alphasense', 9051.911344537815)]),
#  ('California Health Facilities Financing Authority',
#   'xp-health',
#   [('xp-health', 9149.411344537815),
#    ('binx-health', 9145.911344537815),
#    ('cala-health', 9139.911344537815),
#    ('babylon-health', 9113.911344537815),
#    ('oshi-health', 9109.411344537815)]),
#  ('CBOE GLOBAL MARKETS INC',
#   'envoy-global',
#   [('envoy-global', 9239.911344537815),
#    ('hmd-global', 9139.911344537815),
#    ('axiom-global', 9133.411344537815),
#    ('cityblock-capital', 9113.911344537815),
#    ('marketing-evolution', 9107.411344537815)]),
#  ('WASTE CONNECTIONS INC',
#   'crimson-education',
#   [('crimson-education', 9149.411344537815),
#    ('ovation-tv', 9118.411344537815),
#    ('ecosense', 9117.911344537815),
#    ('whistle-sports', 9116.411344537815),
#    ('contentsquare', 9114.411344537815)]),
#  ('PFIZER INC.',
#   'appfire',
#   [('appfire', 9089.411344537815),
#    ('pear-therapeutics', 9084.411344537815),
#    ('fiteq', 9080.911344537815),
#    ('pipedrive', 9060.411344537815),
#    ('tigera', 9058.911344537815)]),
#  ('Chesapeake Energy Corp',
#   'scalefactor',
#   [('scalefactor', 9122.411344537815),
#    ('xcor-aerospace', 9116.411344537815),
#    ('chefsteps', 9098.411344537815),
#    ('lightspeed-pos', 9077.411460528845),
#    ('esperanto-technologies', 9074.911344537815)]),
#  ('Henkel AG & Co KGaA',
#   'generation-bio',
#   [('generation-bio', 9034.911360910452),
#    ('congatec', 9034.411344537815),
#    ('ecosense', 9031.411344537815),
#    ('athletic-greens', 9028.411344537815),
#    ('the-agency', 9024.411344537815)]),
#  ('Hertz Vehicle Financing LLC',
#   'pie-insurance',
#   [('pie-insurance', 9106.411344537815),
#    ('inari-medical', 9073.911640191238),
#    ('vector-launch', 9060.411344537815),
#    ('binance', 9059.911344537815),
#    ('insightec', 9059.911344537815)]),
#  ('Burlington Stores Inc',
#   'tory-burch',
#   [('tory-burch', 9101.911344537815),
#    ('lightspeed-pos', 9086.911460528845),
#    ('bonfire-studios', 9078.911344537815),
#    ('onestream', 9070.4115515607),
#    ('blockstream', 9067.911344537815)]),
#  ('McCormick & Co Inc/MD',
#   'monday-com',
#   [('monday-com', 9068.913401013659),
#    ('concord', 9055.411344537815),
#    ('colorchip', 9047.911344537815),
#    ('orderco', 9040.411344537815),
#    ('oric-pharmaceuticals', 9027.411344537815)]),
#  ('Amadeus IT Group SA',
#   'sms-assist',
#   [('sms-assist', 9077.911344537815),
#    ('vacasa', 9056.411344537815),
#    ('99designs', 9050.911344537815),
#    ('madaket', 9050.911344537815),
#    ('appharvest', 9037.411344537815)]),
#  ('NOVELIS CORP',
#   'moneylion',
#   [('moneylion', 9092.911344537815),
#    ('conversica', 9088.411344537815),
#    ('nikola-motor-company', 9084.411344537815),
#    ('lola-com', 9082.411344537815),
#    ('nto-ire-polus', 9081.911344537815)]),
#  ('Aker BP ASA',
#   'erasca',
#   [('erasca', 9129.411363166237),
#    ('aras', 9108.911344537815),
#    ('teamsnap', 9079.411344537815),
#    ('wasabi-technologies', 9070.411344537815),
#    ('vacasa', 9070.411344537815)]),
#  ('DR HORTON INC',
#   'horizon-robotics',
#   [('horizon-robotics', 9132.411344537815),
#    ('formation', 9094.911344537815),
#    ('peloton-technology', 9072.911344537815),
#    ('droom', 9061.911344537815),
#    ('endotronix', 9053.911344537815)]),
#  ('HOWARD HUGHES CORP',
#   'orderco',
#   [('orderco', 9084.911344537815),
#    ('parachute-home', 9059.911344537815),
#    ('coverhound', 9044.411344537815),
#    ('clarabridge', 9043.911344537815),
#    ('graphcore', 9038.911344537815)]),
#  ('AP Moller - Maersk A/S',
#   'back-market',
#   [('back-market', 9070.411344537815),
#    ('paperless-post', 9059.911344537815),
#    ('prowler-io', 9053.911344537815),
#    ('spin-memory', 9047.911344537815),
#    ('dreamscape-immersive', 9040.411344537815)]),
#  ('Cenovus Energy Inc',
#   'ceros',
#   [('ceros', 9178.411344537815),
#    ('genius', 9146.411344537815),
#    ('igneous-systems', 9113.911344537815),
#    ('greenhouse-software', 9108.911344537815),
#    ('renova-therapeutics', 9106.411344537815)]),
#  ('GSAA Home Equity Trust',
#   'noon-home',
#   [('noon-home', 9143.411344537815),
#    ('sentry-ai', 9092.411344537815),
#    ('onetrust', 9086.411344537815),
#    ('blu-homes', 9076.411344537815),
#    ('parachute-home', 9066.911344537815)]),
#  ('MAGALLANES INC',
#   'magnet',
#   [('magnet', 9098.411344537815),
#    ('balance-therapeutics', 9090.411344537815),
#    ('emailage', 9079.411344537815),
#    ('metaplane', 9074.911344537815),
#    ('alltrails', 9069.911344537815)]),
#  ('BAIDU INC',
#   'blade',
#   [('blade', 9053.911344537815),
#    ('brainly', 9030.911344537815),
#    ('wanderu', 9015.911344537815),
#    ('datrium', 9007.911344537815),
#    ('ai-therapeutics', 9007.911344537815)]),
#  ('LYB INT FINANCE III',
#   'parallel-finance',
#   [('parallel-finance', 9113.411344537815),
#    ('pie-insurance', 9109.911344537815),
#    ('kin-insurance', 9085.911344537815),
#    ('binance', 9085.411344537815),
#    ('root-insurance', 9051.911668352172)]),
#  ('Palmer Square CLO Ltd',
#   'cloudpassage',
#   [('cloudpassage', 9148.911344537815),
#    ('contentsquare', 9148.411344537815),
#    ('squaretrade', 9133.411344537815),
#    ('coinsquare', 9101.911344537815),
#    ('solarflare', 9093.911344537815)]),
#  ('United Rentals Inc',
#   'turnkey-vacation-rentals',
#   [('turnkey-vacation-rentals', 9335.411344537815),
#    ('unified', 9123.911344537815),
#    ('ensighten', 9101.911344537815),
#    ('prevalent', 9095.911344537815),
#    ('arundo-analytics', 9093.911344537815)]),
#  ('PIONEER NATURAL RESOURCES CO',
#   'jetti-resources',
#   [('jetti-resources', 9275.911344537815),
#    ('ironsource', 9107.911344537815),
#    ('mirror', 9092.411344537815),
#    ('contentsquare', 9088.911344537815),
#    ('corvus', 9085.411344537815)]),
#  ('BUNDESREPUB. DEUTSCHLAND',
#   'doubledutch',
#   [('doubledutch', 9060.411344537815),
#    ('blue-danube-systems', 9017.411344537815),
#    ('borderx-lab', 9013.911344537815),
#    ('investcloud', 9012.911344537815),
#    ('brandless', 9008.411344537815)]),
#  ('Vonovia SE',
#   'renova-therapeutics',
#   [('renova-therapeutics', 9120.911344537815),
#    ('securonix', 9071.911344537815),
#    ('moovit', 9070.411344537815),
#    ('hedonova', 9059.411344537815),
#    ('ubeam', 9053.911344537815)]),
#  ('UBS Commercial Mortgage Trust',
#   'valon-mortgage',
#   [('valon-mortgage', 9183.411344537815),
#    ('bigcommerce', 9089.911385360254),
#    ('local-motors', 9057.411344537815),
#    ('monolith-materials', 9056.411344537815),
#    ('onetrust', 9054.411344537815)]),
#  ('Republic of Ghana',
#   'rubicon-global',
#   [('rubicon-global', 9083.411344537815),
#    ('unravel-data', 9031.911344537815),
#    ('host-analytics', 9030.911344537815),
#    ('camunda-services', 9009.911344537815),
#    ('omni-orthopaedics', 9002.911344537815)]),
#  ('Arthur J Gallagher & Co',
#   'arthur',
#   [('arthur', 9287.411344537815),
#    ('arthur-ai', 9089.411344537815),
#    ('voyage-auto', 9036.911344537815),
#    ('curalate', 9033.411344537815),
#    ('accolade', 9031.411372698749)]),
#  ('JPMorgan Chase and Co.',
#   'vector-launch',
#   [('vector-launch', 9100.911344537815),
#    ('achates-power', 9091.411344537815),
#    ('monday-com', 9056.913401013659),
#    ('icon-aircraft', 9056.411344537815),
#    ('langchain', 9054.411344537815)]),
#  ('MASSACHUSETTS ST DEV FIN AGY',
#   '908-devices',
#   [('908-devices', 9022.41136869655),
#    ('fin-exploration-company', 9002.411344537815),
#    ('adicet-bio', 9000.411354725233),
#    ('sms-assist', 8999.411344537815),
#    ('pie-insurance', 8997.911344537815)]),
#  ('COINBASE GLOBAL INC',
#   'envoy-global',
#   [('envoy-global', 9288.411344537815),
#    ('rubicon-global', 9209.411344537815),
#    ('hmd-global', 9175.911344537815),
#    ('axiom-global', 9165.911344537815),
#    ('skyloom-global', 9106.911344537815)]),
#  ('GUARDANT HEALTH INC',
#   'cala-health',
#   [('cala-health', 9244.911344537815),
#    ('artemis-health', 9237.911344537815),
#    ('xp-health', 9233.911344537815),
#    ('health-catalyst', 9202.911344537815),
#    ('oshi-health', 9179.911344537815)]),
#  ('Unilever Capital Corp',
#   'clever',
#   [('clever', 9177.411344537815),
#    ('doubleverify', 9134.411466495761),
#    ('unified', 9114.911344537815),
#    ('ziprecruiter', 9102.411413521188),
#    ('sonder', 9098.911344537815)]),
#  ('Estados Unidos Mexicanos',
#   'cheetah-medical',
#   [('cheetah-medical', 9057.411344537815),
#    ('beta-bionics', 9055.911344537815),
#    ('revolution-medicines', 9052.411704735807),
#    ('ecosense', 9041.911344537815),
#    ('stratos-genomics', 9039.911344537815)]),
#  ('LEIDOS INC',
#   'dosh',
#   [('dosh', 9118.911344537815),
#    ('rideos', 9114.411344537815),
#    ('pliops', 9107.411344537815),
#    ('leif', 9104.411344537815),
#    ('appliedapps', 9082.411344537815)]),
#  ('Fanniemae Strip',
#   'sentry-ai',
#   [('sentry-ai', 9075.911344537815),
#    ('element-ai', 9070.911344537815),
#    ('stripe-digital', 9064.411344537815),
#    ('noname-security', 9053.911344537815),
#    ('annexon-biosciences', 9052.91139562044)]),
#  ('Rexford Industrial Realty Inc',
#   'rubicon-global',
#   [('rubicon-global', 9080.411344537815),
#    ('the-virtual-reality-company', 9078.911344537815),
#    ('instart', 9071.911344537815),
#    ('scalefactor', 9064.411344537815),
#    ('icon-aircraft', 9059.911344537815)]),
#  ('EQM MIDSTREAM PARTNERS LP',
#   'better-life-partners',
#   [('better-life-partners', 9090.411344537815),
#    ('globalization-partners', 9089.411344537815),
#    ('smartnews', 9077.911344537815),
#    ('onestream', 9066.4115515607),
#    ('smartrent', 9048.911344537815)]),
#  ('NATIONWIDE BLDG SOCIETY',
#   'noname-security',
#   [('noname-security', 9078.411344537815),
#    ('vlocity', 9062.411344537815),
#    ('duo-security', 9056.911344537815),
#    ('generation-bio', 9053.911360910452),
#    ('twistlock', 9050.411344537815)]),
#  ('CHEVRON USA INC',
#   'ceros',
#   [('ceros', 9165.911344537815),
#    ('renco-usa', 9122.911344537815),
#    ('profusa', 9103.411344537815),
#    ('acronis', 9087.411344537815),
#    ('clever', 9079.411344537815)]),
#  ('MITSUBISHI UFJ FINANCIAL GROUP INC',
#   'intuition-robotics',
#   [('intuition-robotics', 9032.411344537815),
#    ('issuu', 9009.411344537815),
#    ('wildlife-studios', 9004.911344537815),
#    ('mashgin-1', 8999.911344537815),
#    ('haifa-chemicals', 8991.911344537815)]),
#  ('MORGAN STANLEY CAPITAL SERVICES LLC',
#   'elevate-services',
#   [('elevate-services', 9290.411344537815),
#    ('internet-of-services-foundation', 9171.411344537815),
#    ('camunda-services', 9149.411344537815),
#    ('stay-alfred', 9099.411344537815),
#    ('orca-security', 9092.911344537815)]),
#  ('CNH Industrial NV',
#   'instana',
#   [('instana', 9119.411344537815),
#    ('magnusmetal', 9113.911344537815),
#    ('haifa-chemicals', 9113.411344537815),
#    ('schrodinger', 9098.911344537815),
#    ('decisiv', 9082.411344537815)]),
#  ('Ascendis Pharma A/S',
#   'inozyme-pharma',
#   [('inozyme-pharma', 9212.91138041208),
#    ('pmv-pharma', 9209.411355525674),
#    ('circle-pharma', 9145.411344537815),
#    ('anaconda', 9073.911344537815),
#    ('pharmapacks', 9073.411344537815)]),
#  ('NOTA DO TESOURO NACIONAL',
#   'potrero-medical',
#   [('potrero-medical', 9067.411344537815),
#    ('local-motors', 9059.911344537815),
#    ('omni-orthopaedics', 9056.411344537815),
#    ('curalate', 9055.911344537815),
#    ('axial', 9051.411344537815)]),
#  ('LAMAR MEDIA CORP',
#   'monday-com',
#   [('monday-com', 9119.913401013659),
#    ('trilumina', 9109.911344537815),
#    ('tamara-mellon', 9107.911344537815),
#    ('solarflare', 9102.911344537815),
#    ('complexa', 9096.911344537815)]),
#  ('Mizuho Financial Group Inc',
#   'vizio',
#   [('vizio', 9099.911426473762),
#    ('jumio-9', 9024.411344537815),
#    ('medrio', 9009.911344537815),
#    ('omniox', 8999.911344537815),
#    ('domio', 8992.411344537815)]),
#  ('BANK OF AMERICA, NATIONAL ASSOCIATION',
#   'electrify-america',
#   [('electrify-america', 9118.411344537815),
#    ('wooo-social-games', 9085.911344537815),
#    ('crimson-education', 9077.411344537815),
#    ('c3-international', 9070.911344537815),
#    ('aurora-innovation', 9064.411344537815)]),
#  ('Bombardier Inc',
#   'borderx-lab',
#   [('borderx-lab', 9116.411344537815),
#    ('bombas', 9104.911344537815),
#    ('bumble', 9097.911392345912),
#    ('bombora', 9094.911344537815),
#    ('metacrine', 9082.411344537815)]),
#  ('LABORATORY CORP OF AMER',
#   'nikola-motor-company',
#   [('nikola-motor-company', 9060.911344537815),
#    ('icon-aircraft', 9057.411344537815),
#    ('wooo-social-games', 9055.411344537815),
#    ('tory-burch', 9050.411344537815),
#    ('monday-com', 9049.913401013659)]),
#  ('AKER BP ASA',
#   'erasca',
#   [('erasca', 9129.411363166237),
#    ('aras', 9108.911344537815),
#    ('teamsnap', 9079.411344537815),
#    ('wasabi-technologies', 9070.411344537815),
#    ('vacasa', 9070.411344537815)]),
#  ('Partners Group Holding AG',
#   'globalization-partners',
#   [('globalization-partners', 9202.911344537815),
#    ('athletic-greens', 9128.411344537815),
#    ('better-life-partners', 9102.911344537815),
#    ('schrodinger', 9089.911344537815),
#    ('marketing-evolution', 9067.411344537815)]),
#  ('ABN AMRO Bank NV',
#   'argo-ai',
#   [('argo-ai', 9076.911344537815),
#    ('anaconda', 9057.911344537815),
#    ('kaminario', 9050.911344537815),
#    ('act-on', 9050.911344537815),
#    ('zunum-aero', 9046.911344537815)]),
#  ('Trade Desk Inc/The',
#   'leaf-trade',
#   [('leaf-trade', 9221.411344537815),
#    ('deskera', 9220.411344537815),
#    ('the-players-tribune', 9177.911344537815),
#    ('darktrace', 9155.411344537815),
#    ('squaretrade', 9153.911344537815)]),
#  ('DSV A/S',
#   'sms-assist',
#   [('sms-assist', 9076.411344537815),
#    ('brandless', 9042.911344537815),
#    ('adc-therapeutics', 9036.411344537815),
#    ('adm-labs', 9035.911344537815),
#    ('cashstar', 9029.911344537815)]),
#  ('Ferguson PLC',
#   'practice-fusion-9',
#   [('practice-fusion-9', 9077.911344537815),
#    ('recursion-pharmaceuticals', 9050.411389507988),
#    ('eargo', 9043.411344537815),
#    ('fullcontact', 9035.411344537815),
#    ('benson-hill-biosystems', 9026.911344537815)]),
#  ('CNH INDUSTRIAL CAP LLC',
#   'haifa-chemicals',
#   [('haifa-chemicals', 9119.411344537815),
#    ('magnusmetal', 9115.411344537815),
#    ('vector-launch', 9098.911344537815),
#    ('schrodinger', 9094.911344537815),
#    ('lanister', 9094.411344537815)]),
#  ('UNIVISION COMMUNICATIONS',
#   'iovation',
#   [('iovation', 9185.411344537815),
#    ('linevision', 9140.411344537815),
#    ('vizio', 9132.411426473762),
#    ('anyvision', 9105.911344537815),
#    ('visier', 9096.411344537815)])]

# %%
len(result)
# Out:
# 1

# %%
df_result = pd.DataFrame(result, columns=['nport_name', 'first_matched_company', 'all_matches'])
# df_result.to_csv('fuzzy_matched.csv', index=False)
df_result.to_csv('weighted_fuzzy_matched.csv', index=False)

# %%
matched_companies_full_record = [(c, word_to_find) for c, word_to_find in zip(matched_companies, words_to_find)]
matched_companies_full_record
# Out:
# [([('portalone', 63, 635),
#    ('lotame', 62, 2066),
#    ('notable', 59, 920),
#    ('oportun', 59, 3583),
#    ('incorta', 59, 4650)],
#   'nport_name')]

# %%
# Ranked matchings
exact_matches = 0
partial_matches = 0
total_items = len(word_list)
matched = []
partial_matched = []
not_matched = []

for ranked_match_list, expected in zip(matched_companies_full_record, word_list):
    if ranked_match_list:
        first_match = ranked_match_list[0][0][0]  # Get the first-ranked match
        nport_issuer_name = ranked_match_list[1]
        

        # Exact match
        if first_match == expected:
            exact_matches += 1
            matched.append((nport_issuer_name, expected, first_match))
            
        # Partial match (i.e., the expected company appears anywhere else in the ranked list)
        elif any(match[0] == expected for match in ranked_match_list[0]):
            partial_matches += 1
            partial_matched.append((nport_issuer_name, expected, ranked_match_list[0]))
            
        else:
            not_matched.append((nport_issuer_name, expected, ranked_match_list[0]))


exact_match_accuracy = exact_matches / total_items if total_items > 0 else 0
overall_match_accuracy = (exact_matches + partial_matches) / total_items if total_items > 0 else 0


print(f"Total items: {total_items}")
print(f"Number of exact matches: {exact_matches}")
print(f"Number of partial matches: {partial_matches}")
print(f"Exact Match Accuracy: {exact_match_accuracy:.2%}")
print(f"Overall Accuracy (including partial matches): {overall_match_accuracy:.2%}")

# %%
print("Partial matched items:")
for item in partial_matched:
    print(item)

partial_matched_df = pd.DataFrame(partial_matched, columns=['nport_issuer_name', 'slug', 'rankings'])
partial_matched_df['method'] = 'fuzzy_matched'
partial_matched_df.to_csv('data/partial_matched_fuzzy.csv', index=False)
# Out:
# Partial matched items:

# %%
# Function to filter duplicates while keeping the highest score for each unique name
def filter_unique_matches(ranked_matches):
    unique_ranked_matches = {}
    for match in ranked_matches:
        if match[0] not in unique_ranked_matches or unique_ranked_matches[match[0]][1] < match[1]:
            unique_ranked_matches[match[0]] = match
    return list(unique_ranked_matches.values())

# # Apply the filtering to create a new column with filtered matches in partial_matched
# filtered_partial_matches = [
#     (nport_issuer_name, expected, ranked_list, filter_unique_matches(ranked_list))
#     for nport_issuer_name, expected, ranked_list in partial_matched
# ]

# # Create DataFrame with both original and filtered matches
# partial_matched_df = pd.DataFrame(filtered_partial_matches, columns=['nport_issuer_name', 'slug', 'rankings', 'filtered_rankings'])
# partial_matched_df['method'] = 'fuzzy_matched'
# partial_matched_df.to_csv('data/partial_matched_fuzzy.csv', index=False)

# %%
# apply filter_unique_matches to df_result
df_result['filtered_rankings'] = df_result['matched_companies'].apply(filter_unique_matches)
df_result.to_csv('MFM names/fuzzy_matched.csv', index=False)

# %%
print(f"Number of not matches: {len(not_matched)}")
print("Not matched items:")
# for item in not_matched:
#     print(item)

# %%
not_matched_slugs = not_matched + partial_matched

# %%
# Perfect matching 
def find_matches(phrase, word_list, exact_match_weight=3):
    cleaned_words = clean_text(phrase).split()
    
    # A dictionary to keep track of match scores
    match_scores = {w: 0 for w in word_list}
    
    for word in cleaned_words:
        regex_pattern = re.escape(word)
        print(regex_pattern)
        compiled_pattern = re.compile(regex_pattern, re.IGNORECASE)
        print(compiled_pattern)
        
        # Iterate through the word list and conut matches
        for list_item in word_list:
            if compiled_pattern.search(clean_text(list_item)):
                match_scores[list_item] += 1

    # Add exact match weight if the whole phrase is found
    for list_item in word_list:
        if re.search(re.escape(clean_text(phrase)), clean_text(list_item)):
            match_scores[list_item] += exact_match_weight
    
    # Rank the results based on the number of matches
    ranked_results = sorted(match_scores.items(), key=lambda x: x[1], reverse=True)
    
    return ranked_results

# %%
# match with weights on first word

def find_matches_with_weights(phrase, word_list, exact_match_weight=3, first_word_weight=2, other_word_weight=1):
    cleaned_words = clean_text(phrase).split()
    match_scores = {w: 0 for w in word_list}
    
    # Handle the first word with a higher weight
    if cleaned_words:
        first_word = cleaned_words[0]
        first_word_regex = re.escape(first_word)
        # print(first_word_regex)
        compiled_first_word_pattern = re.compile(first_word_regex, re.IGNORECASE)
        # print(compiled_first_word_pattern)
        
        # Add higher weight for first word matches
        for list_item in word_list:
            if compiled_first_word_pattern.search(clean_text(list_item)):
                match_scores[list_item] += first_word_weight
    
    # Handle other words with a standard weight
    for word in cleaned_words[1:]:  
        regex_pattern = re.escape(word)
        # print(regex_pattern)
        compiled_pattern = re.compile(regex_pattern, re.IGNORECASE)       
        # print(compiled_pattern)
        
        for list_item in word_list:
            if compiled_pattern.search(clean_text(list_item)):
                match_scores[list_item] += other_word_weight

    # Add exact match weight if the whole phrase is found
    for list_item in word_list:
        if re.search(re.escape(clean_text(phrase)), clean_text(list_item)):
            match_scores[list_item] += exact_match_weight
    
    # Rank the results based on the number of matches
    ranked_results = sorted(match_scores.items(), key=lambda x: x[1], reverse=True)
    
    return ranked_results

# %%
all_matches = []
for t in words_to_find:
    matches = find_matches_with_weights(t, word_list)
    ranked_matches = [match for match in matches if match[1] > 0]
    ranked_matches_str = ' '.join([str(match) for match in ranked_matches[:5]])
    first_match = ranked_matches[0][0] if ranked_matches else None
    all_matches.append((t, first_match, ranked_matches_str))
all_matches
# Out:
# [('Fannie Mae', 'zunum-aero', "('zunum-aero', 1) ('panorama-education', 1)"),
#  ('FNMA GTD MTG PASS THRU CTF',
#   'cloudpassage',
#   "('cloudpassage', 1) ('moviepass', 1) ('imperfect-foods', 1) ('compass', 1) ('passport', 1)"),
#  ('Block, Inc.',
#   'blockfi',
#   "('blockfi', 2) ('blockstream', 2) ('blockchain-capital', 2) ('autoblocks-ai', 2) ('cityblock-health', 2)"),
#  ('Freddie Mac',
#   'chromacode',
#   "('chromacode', 1) ('humacyte', 1) ('alto-pharmacy', 1) ('thought-machine', 1) ('karmacheck', 1)"),
#  ('UGCard', None, ''),
#  ('Government National Mortgage Association',
#   'better-mortgage',
#   "('better-mortgage', 1) ('c3-international', 1) ('zipline-international', 1) ('valon-mortgage', 1) ('branch-international', 1)"),
#  ('Upstart Network, Inc.',
#   'upstart-network',
#   "('upstart-network', 3) ('cumulus-networks', 1) ('eagle-eye-networks', 1) ('broadview-networks', 1) ('illusive-networks', 1)"),
#  ('United States Treasury',
#   'unitedmasters',
#   "('unitedmasters', 2) ('kitchen-united', 2) ('modern-treasury', 1) ('statespace', 1) ('treasury-prime', 1)"),
#  ('FED HOME LOAN MTG CORP - GOLD',
#   'federated-media',
#   "('federated-media', 2) ('federato-ai', 2) ('federated-wireless', 2) ('flyhomes', 1) ('divvy-homes', 1)"),
#  ('GNMA GUARANTEED PASS THRU CERT',
#   'icertis',
#   "('icertis', 1) ('cloudpassage', 1) ('moviepass', 1) ('concertai', 1) ('compass', 1)"),
#  ('Forward Foreign Currency Contract',
#   'goforward',
#   "('goforward', 2) ('forward-networks', 2) ('dayforward', 2) ('digital-currency-group', 1) ('recurrency', 1)"),
#  ('Federal National Mortgage Association',
#   'better-mortgage',
#   "('better-mortgage', 1) ('c3-international', 1) ('zipline-international', 1) ('valon-mortgage', 1) ('branch-international', 1)"),
#  ('Fannie Mae Pool',
#   'poolside-ai',
#   "('poolside-ai', 1) ('zunum-aero', 1) ('panorama-education', 1)"),
#  ('HSBC Bank PLC', None, ''),
#  ('FNMA', None, ''),
#  ('GNMA', None, ''),
#  ('Freedom Financial Asset Management LLC',
#   'digital-asset',
#   "('digital-asset', 1) ('mynd-property-management', 1) ('smartasset', 1)"),
#  ('Government National Mortgage A',
#   'better-mortgage',
#   "('better-mortgage', 1) ('c3-international', 1) ('zipline-international', 1) ('valon-mortgage', 1) ('branch-international', 1)"),
#  ('Options Clearing Corp.',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('Morgan Stanley', None, ''),
#  ('U.S. DOLLARS',
#   'cumulus-networks',
#   "('cumulus-networks', 2) ('customer-io', 2) ('attralus', 2) ('itrustcapital', 2) ('rhombus-systems', 2)"),
#  ('Federal National Mortgage Association, Inc.',
#   'better-mortgage',
#   "('better-mortgage', 1) ('c3-international', 1) ('zipline-international', 1) ('valon-mortgage', 1) ('branch-international', 1)"),
#  ('GNMA II GTD PASS THRU CTF MULTIPLE ISSUER',
#   'hawaiian-bros',
#   "('hawaiian-bros', 1) ('cloudpassage', 1) ('moviepass', 1) ('brii-biosciences', 1) ('imperfect-foods', 1)"),
#  ('MORGAN STANLEY', None, ''),
#  ('United States of America',
#   'unitedmasters',
#   "('unitedmasters', 2) ('kitchen-united', 2) ('electrify-america', 1) ('renovate-america', 1) ('statespace', 1)"),
#  ('Federal Home Loan Mortgage Corporation',
#   'flyhomes',
#   "('flyhomes', 1) ('divvy-homes', 1) ('unison-home-ownership-investors', 1) ('lendinghome', 1) ('ribbon-home', 1)"),
#  ('Prosper Funding LLC', 'prosper', "('prosper', 2) ('funding-circle', 1)"),
#  ('United States Treasury Note/Bond',
#   'unitedmasters',
#   "('unitedmasters', 2) ('kitchen-united', 2) ('modern-treasury', 1) ('statespace', 1) ('treasury-prime', 1)"),
#  ('LendingClub Corp. - LCX PM',
#   'lendingclub',
#   "('lendingclub', 2) ('shipmonk', 1) ('shopmonkey', 1) ('leap-motion', 1) ('hashicorp', 1)"),
#  ('UST NOTES',
#   'customer-io',
#   "('customer-io', 2) ('itrustcapital', 2) ('gusto', 2) ('dust-identity', 2) ('braintrust', 2)"),
#  ('BANK OF AMERICA CORP',
#   'electrify-america',
#   "('electrify-america', 2) ('renovate-america', 2) ('american-well', 2) ('american-gene-technologies-international', 2) ('hashicorp', 1)"),
#  ('FEDERAL NATIONAL MORTGAGE ASSOCIATION',
#   'better-mortgage',
#   "('better-mortgage', 1) ('c3-international', 1) ('zipline-international', 1) ('valon-mortgage', 1) ('branch-international', 1)"),
#  ('GOLDMAN SACHS GROUP INC', None, ''),
#  ('FANNIE MAE', 'zunum-aero', "('zunum-aero', 1) ('panorama-education', 1)"),
#  ('Freddie Mac Gold Pool',
#   'poolside-ai',
#   "('poolside-ai', 1) ('chromacode', 1) ('humacyte', 1) ('golden', 1) ('alto-pharmacy', 1)"),
#  ('JPMORGAN CHASE & CO',
#   'colossyan',
#   "('colossyan', 1) ('cognata', 1) ('orderco', 1) ('cotopaxi', 1) ('pyxis-oncology', 1)"),
#  ('WELLS FARGO & COMPANY',
#   'wellsaid-labs',
#   "('wellsaid-labs', 2) ('the-browser-company', 1) ('companycam', 1) ('accompany-health', 1) ('nikola-motor-company', 1)"),
#  ('Bank of America Corp',
#   'electrify-america',
#   "('electrify-america', 2) ('renovate-america', 2) ('american-well', 2) ('american-gene-technologies-international', 2) ('hashicorp', 1)"),
#  ('JPMorgan Chase & Co',
#   'colossyan',
#   "('colossyan', 1) ('cognata', 1) ('orderco', 1) ('cotopaxi', 1) ('pyxis-oncology', 1)"),
#  ('Fannie Mae - CAS',
#   'farcaster',
#   "('farcaster', 1) ('zunum-aero', 1) ('pacaso', 1) ('panorama-education', 1) ('chipper-cash', 1)"),
#  ('LCH Limited',
#   'alchemy',
#   "('alchemy', 2) ('zilch', 2) ('digital-chocolate', 2) ('arqit-limited', 1)"),
#  ('CITIGROUP INC', 'citizen', "('citizen', 5)"),
#  ('BOEING CO',
#   'colossyan',
#   "('colossyan', 1) ('cognata', 1) ('orderco', 1) ('cotopaxi', 1) ('pyxis-oncology', 1)"),
#  ('UNITED STATES TREASURY',
#   'unitedmasters',
#   "('unitedmasters', 2) ('kitchen-united', 2) ('modern-treasury', 1) ('statespace', 1) ('treasury-prime', 1)"),
#  ('Citigroup Inc', 'citizen', "('citizen', 5)"),
#  ('Chicago Mercantile Exchange',
#   'stack-exchange',
#   "('stack-exchange', 1) ('royalty-exchange', 1) ('science-exchange', 1) ('openexchange', 1)"),
#  ('Freddie Mac - STACR',
#   'chromacode',
#   "('chromacode', 1) ('humacyte', 1) ('alto-pharmacy', 1) ('thought-machine', 1) ('karmacheck', 1)"),
#  ('ENERGY TRANSFER LP',
#   'transferwise',
#   "('transferwise', 2) ('transfermate', 2) ('trialpay', 1) ('delphinus-medical-technologies', 1) ('yelp', 1)"),
#  ('UNITEDHEALTH GROUP INC', None, ''),
#  ('Goldman Sachs International',
#   'c3-international',
#   "('c3-international', 1) ('zipline-international', 1) ('branch-international', 1) ('american-gene-technologies-international', 1)"),
#  ('Comcast Corp',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('Ginnie Mae II Pool',
#   'poolside-ai',
#   "('poolside-ai', 1) ('hawaiian-bros', 1) ('zunum-aero', 1) ('panorama-education', 1) ('brii-biosciences', 1)"),
#  ('FHLMC Multifamily Structured Pass Through Certs.',
#   'cloudpassage',
#   "('cloudpassage', 1) ('moviepass', 1) ('compass', 1) ('passport', 1) ('gympass', 1)"),
#  ('BANK OF AMERICA CORPORATION',
#   'electrify-america',
#   "('electrify-america', 5) ('renovate-america', 5) ('american-well', 5) ('american-gene-technologies-international', 5)"),
#  ('T-MOBILE USA INC',
#   'nusano',
#   "('nusano', 1) ('profusa', 1) ('equitusai', 1) ('usa-rare-earth', 1) ('abacus-ai', 1)"),
#  ('Chicago Board of Trade',
#   'tradealgo',
#   "('tradealgo', 1) ('tradeshift', 1) ('trade-republic', 1) ('auditboard', 1) ('clipboard-health', 1)"),
#  ('State of California',
#   'finite-state',
#   "('finite-state', 2) ('statespace', 2) ('states-title', 2)"),
#  ('HSBC HOLDINGS PLC', None, ''),
#  ('Intercontinental Exchange, Inc.',
#   'stack-exchange',
#   "('stack-exchange', 1) ('royalty-exchange', 1) ('science-exchange', 1) ('openexchange', 1)"),
#  ('Fidelity Revere Street Trust',
#   'high-fidelity',
#   "('high-fidelity', 2) ('peerstreet', 1) ('itrustcapital', 1) ('main-street-hub', 1) ('braintrust', 1)"),
#  ('BROADCOM INC', None, ''),
#  ('Barclays Bank PLC', None, ''),
#  ('APPLE INC',
#   'sense-talent-labs',
#   "('sense-talent-labs', 5) ('emalex-biosciences', 5) ('cytovale', 5) ('planetscale', 5) ('telltale-games', 5)"),
#  ('UBS AG',
#   'hubspot',
#   "('hubspot', 2) ('substack', 2) ('voyage-ai', 1) ('moengage', 1) ('halo-diagnostics', 1)"),
#  ('JPMorgan Chase Bank, National Association',
#   'capchase',
#   "('capchase', 1) ('c3-international', 1) ('zipline-international', 1) ('branch-international', 1) ('american-gene-technologies-international', 1)"),
#  ('UnitedHealth Group Inc', None, ''),
#  ('Apple Inc',
#   'sense-talent-labs',
#   "('sense-talent-labs', 5) ('emalex-biosciences', 5) ('cytovale', 5) ('planetscale', 5) ('telltale-games', 5)"),
#  ('CHARTER COMM OPT LLC/CAP',
#   'commonbond',
#   "('commonbond', 1) ('capriza', 1) ('pingcap', 1) ('commercetools', 1) ('capchase', 1)"),
#  ('COMM Mortgage Trust',
#   'commonbond',
#   "('commonbond', 2) ('commercetools', 2) ('commsor', 2) ('comma-ai', 2) ('commonwealth-fusion', 2)"),
#  ('JPMorgan', None, ''),
#  ('BNP PARIBAS', None, ''),
#  ('HOME DEPOT INC',
#   'flyhomes',
#   "('flyhomes', 2) ('divvy-homes', 2) ('unison-home-ownership-investors', 2) ('lendinghome', 2) ('ribbon-home', 2)"),
#  ('UNITED STATES TREASURY BOND',
#   'unitedmasters',
#   "('unitedmasters', 2) ('kitchen-united', 2) ('modern-treasury', 1) ('commonbond', 1) ('statespace', 1)"),
#  ('Morgan Stanley & Co. International PLC',
#   'colossyan',
#   "('colossyan', 1) ('cognata', 1) ('orderco', 1) ('cotopaxi', 1) ('pyxis-oncology', 1)"),
#  ('AT&T Inc',
#   'attralus',
#   "('attralus', 5) ('automattic', 5) ('basic-attention-token', 5) ('attentive', 5) ('matterport', 5)"),
#  ('AMERICAN TOWER CORP',
#   'american-well',
#   "('american-well', 2) ('american-gene-technologies-international', 2) ('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1)"),
#  ('GS Mortgage Securities Trust',
#   'dagster-labs',
#   "('dagster-labs', 2) ('angstrom', 2) ('gigster', 2) ('good-eggs', 2) ('big-switch-networks', 2)"),
#  ('Citibank, National Association',
#   'citizen',
#   "('citizen', 2) ('c3-international', 1) ('zipline-international', 1) ('branch-international', 1) ('american-gene-technologies-international', 1)"),
#  ('State Street Bank and Trust Company',
#   'finite-state',
#   "('finite-state', 2) ('statespace', 2) ('states-title', 2) ('peerstreet', 1) ('itrustcapital', 1)"),
#  ('US TREASURY N/B',
#   'zenbusiness',
#   "('zenbusiness', 3) ('cumulus-networks', 2) ('customer-io', 2) ('attralus', 2) ('itrustcapital', 2)"),
#  ('Oracle Corp',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('ABBVIE INC', None, ''),
#  ('MPLX LP',
#   'qomplx',
#   "('qomplx', 2) ('trialpay', 1) ('delphinus-medical-technologies', 1) ('yelp', 1) ('cool-planet-energy-systems', 1)"),
#  ('AMAZON.COM INC', None, ''),
#  ('UMBS, TBA',
#   'owlet-baby-care',
#   "('owlet-baby-care', 1) ('benefitbay', 1) ('onefootball', 1) ('toca-football', 1) ('at-bay', 1)"),
#  ('Morgan Stanley & Co. LLC',
#   'colossyan',
#   "('colossyan', 1) ('cognata', 1) ('orderco', 1) ('cotopaxi', 1) ('pyxis-oncology', 1)"),
#  ('GENERAL MOTORS FINL CO',
#   'generally-intelligent',
#   "('generally-intelligent', 2) ('general-assembly', 2) ('colossyan', 1) ('cognata', 1) ('orderco', 1)"),
#  ('AMGEN INC', None, ''),
#  ('New York State Dormitory Authority',
#   'renew-financial',
#   "('renew-financial', 2) ('new-relic', 2) ('new-age-eats', 2) ('knewton', 2) ('newlight-technologies', 2)"),
#  ('Microsoft Corp',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('AT&T INC',
#   'attralus',
#   "('attralus', 5) ('automattic', 5) ('basic-attention-token', 5) ('attentive', 5) ('matterport', 5)"),
#  ('FX Forwards', 'signalfx', "('signalfx', 2)"),
#  ('JP Morgan Mortgage Trust',
#   'itrustcapital',
#   "('itrustcapital', 1) ('braintrust', 1) ('trust-will', 1) ('safetrust', 1) ('trustarc', 1)"),
#  ('Government National Mortgage Association 2',
#   'simplivity-2',
#   "('simplivity-2', 1) ('g2-com', 1) ('280-earth', 1) ('c2fo', 1) ('42floors', 1)"),
#  ('COMCAST CORP',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('CVS HEALTH CORP',
#   'happy-health',
#   "('happy-health', 1) ('flo-health', 1) ('iris-telehealth', 1) ('vida-health', 1) ('cala-health', 1)"),
#  ('Freddie Mac Pool',
#   'poolside-ai',
#   "('poolside-ai', 1) ('chromacode', 1) ('humacyte', 1) ('alto-pharmacy', 1) ('thought-machine', 1)"),
#  ('HSBC Holdings PLC', None, ''),
#  ('Currency Forward Contract',
#   'digital-currency-group',
#   "('digital-currency-group', 2) ('recurrency', 2) ('goforward', 1) ('forward-networks', 1) ('dayforward', 1)"),
#  ('PACIFIC GAS & ELECTRIC',
#   'highland-electric-transportation',
#   "('highland-electric-transportation', 1) ('endogastric-solutions', 1) ('electric-ai', 1) ('infinitum-electric', 1) ('electric-hydrogen', 1)"),
#  ('BNP Paribas SA',
#   'sahara-ai',
#   "('sahara-ai', 1) ('wasabi-technologies', 1) ('trisalus-life-sciences', 1) ('messari', 1) ('recursal-ai', 1)"),
#  ('BRISTOL-MYERS SQUIBB CO',
#   'colossyan',
#   "('colossyan', 1) ('cognata', 1) ('orderco', 1) ('cotopaxi', 1) ('pyxis-oncology', 1)"),
#  ('MORGAN STANLEY & CO. LLC',
#   'colossyan',
#   "('colossyan', 1) ('cognata', 1) ('orderco', 1) ('cotopaxi', 1) ('pyxis-oncology', 1)"),
#  ('ORACLE CORP',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('Credit Suisse Mortgage Trust',
#   'nova-credit',
#   "('nova-credit', 2) ('credit-sesame', 2) ('credit-karma', 2) ('tomocredit', 2) ('biz2credit', 2)"),
#  ('CVS Health Corp',
#   'happy-health',
#   "('happy-health', 1) ('flo-health', 1) ('iris-telehealth', 1) ('vida-health', 1) ('cala-health', 1)"),
#  ('Ginnie Mae I Pool',
#   'poolside-ai',
#   "('poolside-ai', 1) ('zunum-aero', 1) ('panorama-education', 1)"),
#  ('Johnson & Johnson', None, ''),
#  ('Treasury, United States Department of',
#   'modern-treasury',
#   "('modern-treasury', 2) ('treasury-prime', 2) ('unitedmasters', 1) ('statespace', 1) ('kitchen-united', 1)"),
#  ('GOVERNMENT NATIONAL MORTGAGE A',
#   'better-mortgage',
#   "('better-mortgage', 1) ('c3-international', 1) ('zipline-international', 1) ('valon-mortgage', 1) ('branch-international', 1)"),
#  ('OCCIDENTAL PETROLEUM COR',
#   'mercor',
#   "('mercor', 1) ('zettacore', 1) ('hashicorp', 1) ('dalcor-pharmaceuticals', 1) ('clearscore', 1)"),
#  ('Amazon.com Inc', None, ''),
#  ('MICROSOFT CORP',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('HCA INC', 'health-catalyst', "('health-catalyst', 5)"),
#  ('INTEL CORP',
#   'generally-intelligent',
#   "('generally-intelligent', 2) ('intelycare', 2) ('intelepeer', 2) ('canoe-intelligence', 2) ('qylur-intelligent-systems', 2)"),
#  ('FORD MOTOR CREDIT CO LLC',
#   'nikola-motor-company',
#   "('nikola-motor-company', 2) ('colossyan', 1) ('cognata', 1) ('orderco', 1) ('cotopaxi', 1)"),
#  ('Deutsche Bank AG',
#   'voyage-ai',
#   "('voyage-ai', 1) ('moengage', 1) ('halo-diagnostics', 1) ('digital-diagnostics', 1) ('agility-robotics', 1)"),
#  ('SOUTHERN CAL EDISON',
#   'elixir-medical',
#   "('elixir-medical', 1) ('radiaction-medical', 1) ('greenlight-analytical', 1) ('mechanical-orchard', 1) ('scalapay', 1)"),
#  ('AbbVie Inc', None, ''),
#  ('Citibank NA',
#   'citizen',
#   "('citizen', 2) ('cognata', 1) ('greenlight-analytical', 1) ('tonal-systems', 1) ('automation-anywhere', 1)"),
#  ('BARCLAYS PLC', None, ''),
#  ('ALPHABET INC', None, ''),
#  ('State Street Bank & Trust Co.',
#   'finite-state',
#   "('finite-state', 2) ('statespace', 2) ('states-title', 2) ('colossyan', 1) ('cognata', 1)"),
#  ('Alphabet Inc', None, ''),
#  ('Citibank N.A.',
#   'citizen',
#   "('citizen', 2) ('cognata', 1) ('greenlight-analytical', 1) ('tonal-systems', 1) ('automation-anywhere', 1)"),
#  ('CENTENE CORP',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('AERCAP IRELAND CAP/GLOBA', None, ''),
#  ('Metropolitan Transportation Authority', None, ''),
#  ('UNION PACIFIC CORP',
#   'krafton-game-union',
#   "('krafton-game-union', 2) ('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1)"),
#  ('BANK OF NY MELLON CORP',
#   'automation-anywhere',
#   "('automation-anywhere', 2) ('anyword', 2) ('snyk', 2) ('the-browser-company', 2) ('nydig', 2)"),
#  ('AstraZeneca PLC', None, ''),
#  ('ROYAL BANK OF CANADA',
#   'royalty-exchange',
#   "('royalty-exchange', 2) ('royal-markets', 2)"),
#  ("LOWE'S COS INC",
#   'theracos',
#   "('theracos', 1) ('arccos-golf', 1) ('mark-cuban-cost-plus-drug-company', 1) ('sarcos-robotics', 1) ('ecosense', 1)"),
#  ('Federal Home Loan Mortgage Corp.',
#   'flyhomes',
#   "('flyhomes', 1) ('divvy-homes', 1) ('unison-home-ownership-investors', 1) ('hashicorp', 1) ('lendinghome', 1)"),
#  ('State of Illinois',
#   'finite-state',
#   "('finite-state', 2) ('statespace', 2) ('states-title', 2)"),
#  ('MITSUBISHI UFJ FIN GRP',
#   'infinite-reality',
#   "('infinite-reality', 1) ('finite-state', 1) ('infinidat', 1) ('property-finder', 1) ('finagraph', 1)"),
#  ('UBS GROUP AG',
#   'hubspot',
#   "('hubspot', 2) ('substack', 2) ('voyage-ai', 1) ('moengage', 1) ('halo-diagnostics', 1)"),
#  ('FREDDIE MAC',
#   'chromacode',
#   "('chromacode', 1) ('humacyte', 1) ('alto-pharmacy', 1) ('thought-machine', 1) ('karmacheck', 1)"),
#  ('Union Pacific Corp',
#   'krafton-game-union',
#   "('krafton-game-union', 2) ('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1)"),
#  ('GLOBAL PAYMENTS INC',
#   'utility-global',
#   "('utility-global', 2) ('envoy-global', 2) ('rubicon-global', 2) ('thrive-global', 2) ('forge-global', 2)"),
#  ('Barclays PLC', None, ''),
#  ('Pfizer Inc', None, ''),
#  ("McDonald's Corp",
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('CDS', None, ''),
#  ('CCO HLDGS LLC/CAP CORP',
#   'accolade',
#   "('accolade', 2) ('arccos-golf', 2) ('accompany-health', 2) ('public-com', 2) ('trueaccord', 2)"),
#  ('PETROLEOS MEXICANOS', None, ''),
#  ('Goldman Sachs Group Inc/The',
#   'the-players-tribune',
#   "('the-players-tribune', 1) ('theracos', 1) ('synthesis-ai', 1) ('synthesized', 1) ('theatro', 1)"),
#  ('ENTERPRISE PRODUCTS OPER',
#   'property-finder',
#   "('property-finder', 1) ('osom-products', 1) ('mynd-property-management', 1) ('moda-operandi', 1) ('moda-operandi-inc', 1)"),
#  ('Merck & Co Inc',
#   'colossyan',
#   "('colossyan', 1) ('cognata', 1) ('orderco', 1) ('cotopaxi', 1) ('pyxis-oncology', 1)"),
#  ('PEPSICO INC', None, ''),
#  ('GOLDMAN SACHS & CO. LLC',
#   'colossyan',
#   "('colossyan', 1) ('cognata', 1) ('orderco', 1) ('cotopaxi', 1) ('pyxis-oncology', 1)"),
#  ('TOYOTA MOTOR CREDIT CORP',
#   'aptera-motors',
#   "('aptera-motors', 1) ('hashicorp', 1) ('nikola-motor-company', 1) ('nova-credit', 1) ('local-motors', 1)"),
#  ('TRUIST FINANCIAL CORP',
#   'altruist',
#   "('altruist', 2) ('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1)"),
#  ('BX Trust',
#   'mbx-biosciences',
#   "('mbx-biosciences', 2) ('mbx-memebox', 2) ('itrustcapital', 1) ('braintrust', 1) ('trust-will', 1)"),
#  ('Towd Point Mortgage Trust',
#   'itrustcapital',
#   "('itrustcapital', 1) ('braintrust', 1) ('glasspoint', 1) ('greatpoint-energy-1', 1) ('trust-will', 1)"),
#  ('SUMITOMO MITSUI FINL GRP', 'finless-foods', "('finless-foods', 1)"),
#  ('American Tower Corp',
#   'american-well',
#   "('american-well', 2) ('american-gene-technologies-international', 2) ('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1)"),
#  ('FEDERAL HOME LOAN MORTGAGE CORP',
#   'flyhomes',
#   "('flyhomes', 1) ('divvy-homes', 1) ('unison-home-ownership-investors', 1) ('hashicorp', 1) ('lendinghome', 1)"),
#  ('Fnma Pass-Thru I', None, ''),
#  ('FEDERAL HOME LN MTG CORP MULTICLASS MTG PARTN CTF GTD',
#   'fiscalnote',
#   "('fiscalnote', 1) ('flyhomes', 1) ('l-nutra', 1) ('divvy-homes', 1) ('unison-home-ownership-investors', 1)"),
#  ('CSC HOLDINGS LLC',
#   'epic-sciences',
#   "('epic-sciences', 5) ('csc-generation', 5)"),
#  ('MORGAN STANLEY & COMPANY LLC',
#   'the-browser-company',
#   "('the-browser-company', 1) ('companycam', 1) ('accompany-health', 1) ('nikola-motor-company', 1) ('mark-cuban-cost-plus-drug-company', 1)"),
#  ('City of New York NY',
#   'witricity',
#   "('witricity', 2) ('vlocity', 2) ('solarcity', 2) ('velocity-technology-solutions', 2) ('experticity', 2)"),
#  ('EQUINIX INC', None, ''),
#  ('ELEVANCE HEALTH INC',
#   'elevance-renewable-sciences',
#   "('elevance-renewable-sciences', 2) ('happy-health', 1) ('flo-health', 1) ('iris-telehealth', 1) ('vida-health', 1)"),
#  ('New Residential Mortgage Loan Trust',
#   'renewable-trust',
#   "('renewable-trust', 3) ('renew-financial', 2) ('new-relic', 2) ('new-age-eats', 2) ('knewton', 2)"),
#  ('Amgen Inc', None, ''),
#  ('CROWN CASTLE INC', None, ''),
#  ('CAPITAL ONE FINANCIAL CO',
#   'one-concern-1',
#   "('one-concern-1', 3) ('one-concern', 3) ('aliphcom-jawbone', 3) ('the-honest-company', 3) ('honeycomb', 3)"),
#  ('Abbott Laboratories',
#   'colossal-laboratories-biosciences',
#   "('colossal-laboratories-biosciences', 1)"),
#  ('Visa Inc', None, ''),
#  ('HCA Inc', 'health-catalyst', "('health-catalyst', 5)"),
#  ('TENET HEALTHCARE CORP',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('HUMANA INC', None, ''),
#  ('JPMORGAN CHASE and CO',
#   'colossyan',
#   "('colossyan', 1) ('cognata', 1) ('orderco', 1) ('cotopaxi', 1) ('pyxis-oncology', 1)"),
#  ('CIGNA CORP',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('BROWN BROTHERS HARRIMAN & CO.',
#   'colossyan',
#   "('colossyan', 1) ('cognata', 1) ('orderco', 1) ('cotopaxi', 1) ('pyxis-oncology', 1)"),
#  ('BAT CAPITAL CORP',
#   'zanbato',
#   "('zanbato', 2) ('samba-tv', 2) ('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1)"),
#  ('Wells Fargo Commercial Mortgage Trust',
#   'wellsaid-labs',
#   "('wellsaid-labs', 2) ('itrustcapital', 1) ('braintrust', 1) ('trust-will', 1) ('safetrust', 1)"),
#  ('AMERICAN EXPRESS CO',
#   'american-well',
#   "('american-well', 2) ('american-gene-technologies-international', 2) ('colossyan', 1) ('cognata', 1) ('orderco', 1)"),
#  ('FHLMC', None, ''),
#  ('JP Morgan Chase Commercial Mortgage Sec Trust',
#   'securiti-ai',
#   "('securiti-ai', 1) ('itrustcapital', 1) ('menlo-security', 1) ('secureframe', 1) ('second-dinner-studios', 1)"),
#  ('CITIGROUP INC.', 'citizen', "('citizen', 2)"),
#  ('New York City Transitional Finance Authority Future Tax Secured Revenue',
#   'renew-financial',
#   "('renew-financial', 2) ('new-relic', 2) ('new-age-eats', 2) ('knewton', 2) ('newlight-technologies', 2)"),
#  ('PepsiCo Inc', None, ''),
#  ('PHILIP MORRIS INTL INC', None, ''),
#  ('Morgan Stanley Capital Services LLC',
#   'camunda-services',
#   "('camunda-services', 1) ('elevate-services', 1) ('xenex-disinfection-services', 1) ('internet-of-services-foundation', 1)"),
#  ('Petroleos Mexicanos', None, ''),
#  ('LLOYDS BANKING GROUP PLC',
#   'wave-computing',
#   "('wave-computing', 1) ('chainguard', 1) ('helsing', 1) ('atom-computing', 1) ('singular', 1)"),
#  ('Intel Corp',
#   'generally-intelligent',
#   "('generally-intelligent', 2) ('intelycare', 2) ('intelepeer', 2) ('canoe-intelligence', 2) ('qylur-intelligent-systems', 2)"),
#  ('BNP Paribas', None, ''),
#  ('ALTRIA GROUP INC', None, ''),
#  ('Citi', 'citizen', "('citizen', 5)"),
#  ('LendingClub Corp.',
#   'lendingclub',
#   "('lendingclub', 2) ('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1)"),
#  ('Walmart Inc', None, ''),
#  ('Bank',
#   'tradealgo',
#   "('tradealgo', 3) ('latitude', 3) ('revery-ai', 3) ('soci', 3) ('colossyan', 3)"),
#  ('Eurex Deutschland', None, ''),
#  ('JOHN DEERE CAPITAL CORP',
#   'johnnie-o',
#   "('johnnie-o', 2) ('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1)"),
#  ('General Motors Co',
#   'generally-intelligent',
#   "('generally-intelligent', 2) ('general-assembly', 2) ('colossyan', 1) ('cognata', 1) ('orderco', 1)"),
#  ('Gilead Sciences Inc',
#   'trisalus-life-sciences',
#   "('trisalus-life-sciences', 1) ('epic-sciences', 1) ('caris-life-sciences', 1) ('elevance-renewable-sciences', 1) ('truvian-sciences', 1)"),
#  ('JPMorgan Chase Bank N.A.',
#   'cognata',
#   "('cognata', 1) ('greenlight-analytical', 1) ('tonal-systems', 1) ('automation-anywhere', 1) ('natron', 1)"),
#  ('DEUTSCHE BANK NY',
#   'automation-anywhere',
#   "('automation-anywhere', 1) ('anyword', 1) ('snyk', 1) ('the-browser-company', 1) ('nydig', 1)"),
#  ('TRANSDIGM INC', None, ''),
#  ('AIR LEASE CORP',
#   'nuvaira',
#   "('nuvaira', 2) ('airbase', 2) ('fair', 2) ('airwallex', 2) ('fairmatic', 2)"),
#  ('20 Year Standalone Fixed 2nd',
#   'myyearbook',
#   "('myyearbook', 1) ('freshbooks-2ndsite', 1) ('lightyear', 1)"),
#  ('Bank of America, National Association',
#   'american-gene-technologies-international',
#   "('american-gene-technologies-international', 3) ('electrify-america', 2) ('renovate-america', 2) ('american-well', 2) ('c3-international', 1)"),
#  ('BPCE SA',
#   'sahara-ai',
#   "('sahara-ai', 1) ('wasabi-technologies', 1) ('trisalus-life-sciences', 1) ('messari', 1) ('recursal-ai', 1)"),
#  ('NEXTERA ENERGY CAPITAL', None, ''),
#  ('New Jersey Transportation Trust Fund Authority',
#   'renewable-trust',
#   "('renewable-trust', 3) ('renew-financial', 2) ('new-relic', 2) ('new-age-eats', 2) ('knewton', 2)"),
#  ('NVIDIA CORP',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('JPMorgan Chase & Co.',
#   'colossyan',
#   "('colossyan', 1) ('cognata', 1) ('orderco', 1) ('cotopaxi', 1) ('pyxis-oncology', 1)"),
#  ('Wells Fargo & Co',
#   'wellsaid-labs',
#   "('wellsaid-labs', 2) ('colossyan', 1) ('cognata', 1) ('orderco', 1) ('cotopaxi', 1)"),
#  ('BANCO SANTANDER SA',
#   'mark-cuban-cost-plus-drug-company',
#   "('mark-cuban-cost-plus-drug-company', 2) ('bancor', 2) ('parkway-bancorp', 2) ('sahara-ai', 1) ('wasabi-technologies', 1)"),
#  ('BP CAP MARKETS AMERICA',
#   'abpro',
#   "('abpro', 2) ('kbp-biosciences', 2) ('thumbplay', 2) ('capriza', 1) ('electrify-america', 1)"),
#  ('BENCHMARK Mortgage Trust',
#   'itrustcapital',
#   "('itrustcapital', 1) ('braintrust', 1) ('trust-will', 1) ('safetrust', 1) ('trustarc', 1)"),
#  ('NATWEST GROUP PLC', None, ''),
#  ('FISERV INC', None, ''),
#  ('CSX Corp',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('Lloyds Banking Group PLC',
#   'wave-computing',
#   "('wave-computing', 1) ('chainguard', 1) ('helsing', 1) ('atom-computing', 1) ('singular', 1)"),
#  ('PARAMOUNT GLOBAL',
#   'utility-global',
#   "('utility-global', 1) ('envoy-global', 1) ('rubicon-global', 1) ('thrive-global', 1) ('forge-global', 1)"),
#  ('EXXON MOBIL CORPORATION',
#   'yoshi-mobility',
#   "('yoshi-mobility', 1) ('mobileiron', 1) ('mobilecoin', 1) ('may-mobility', 1) ('hyla-mobile', 1)"),
#  ('Mastercard Inc', None, ''),
#  ('IBM CORP',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('Broadcom Inc', None, ''),
#  ('Verizon Communications Inc', None, ''),
#  ('TORONTO-DOMINION BANK', None, ''),
#  ('MASTERCARD INC', None, ''),
#  ('NETFLIX INC', None, ''),
#  ('STATE STREET CORP',
#   'finite-state',
#   "('finite-state', 2) ('statespace', 2) ('states-title', 2) ('peerstreet', 1) ('main-street-hub', 1)"),
#  ('ANHEUSER-BUSCH INBEV WOR',
#   'world-labs',
#   "('world-labs', 1) ('cumulus-networks', 1) ('better-world', 1) ('hopsworks-ai', 1) ('anyword', 1)"),
#  ('CHARLES SCHWAB CORP',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('UBS Group AG',
#   'hubspot',
#   "('hubspot', 2) ('substack', 2) ('voyage-ai', 1) ('moengage', 1) ('halo-diagnostics', 1)"),
#  ('Bristol-Myers Squibb Co',
#   'colossyan',
#   "('colossyan', 1) ('cognata', 1) ('orderco', 1) ('cotopaxi', 1) ('pyxis-oncology', 1)"),
#  ('Deutsche Bank Aktiengesellschaft', None, ''),
#  ('MetLife Inc', None, ''),
#  ('CARNIVAL CORP',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('WILLIAMS COMPANIES INC', None, ''),
#  ('HYUNDAI CAPITAL AMERICA',
#   'electrify-america',
#   "('electrify-america', 1) ('renovate-america', 1) ('american-well', 1) ('american-gene-technologies-international', 1)"),
#  ('WALMART INC', None, ''),
#  ('ONEOK INC', None, ''),
#  ('Bank of America Corporation',
#   'electrify-america',
#   "('electrify-america', 5) ('renovate-america', 5) ('american-well', 5) ('american-gene-technologies-international', 5)"),
#  ('WALT DISNEY COMPANY/THE',
#   'waltonchain-foundation',
#   "('waltonchain-foundation', 2)"),
#  ('American Express Co',
#   'american-well',
#   "('american-well', 2) ('american-gene-technologies-international', 2) ('colossyan', 1) ('cognata', 1) ('orderco', 1)"),
#  ('Netflix Inc', None, ''),
#  ('Altria Group Inc', None, ''),
#  ('ONEMAIN FINANCE CORP',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('parallel-finance', 1) ('possible-finance', 1) ('point-digital-finance', 1)"),
#  ('Home Depot Inc/The',
#   'flyhomes',
#   "('flyhomes', 2) ('divvy-homes', 2) ('unison-home-ownership-investors', 2) ('lendinghome', 2) ('ribbon-home', 2)"),
#  ('SOCIETE GENERALE', None, ''),
#  ('CHICAGO MERCANTILE EXCHANGE',
#   'stack-exchange',
#   "('stack-exchange', 1) ('royalty-exchange', 1) ('science-exchange', 1) ('openexchange', 1)"),
#  ('QUALCOMM Inc', None, ''),
#  ('US Bancorp',
#   'cumulus-networks',
#   "('cumulus-networks', 2) ('customer-io', 2) ('attralus', 2) ('itrustcapital', 2) ('rhombus-systems', 2)"),
#  ('BANK OF NOVA SCOTIA',
#   'nova-labs',
#   "('nova-labs', 2) ('tela-innovations', 2) ('renovate-america', 2) ('nova-credit', 2) ('wind-talker-innovations', 2)"),
#  ('Prudential Financial Inc', None, ''),
#  ('VISA INC', None, ''),
#  ('Roche Holding AG',
#   'voyage-ai',
#   "('voyage-ai', 1) ('moengage', 1) ('halo-diagnostics', 1) ('digital-diagnostics', 1) ('agility-robotics', 1)"),
#  ('CON EDISON CO OF NY INC',
#   'conviva',
#   "('conviva', 3) ('conduktor', 3) ('second-dinner-studios', 3) ('one-concern-1', 3) ('associated-content', 3)"),
#  ('Morgan Stanley Capital I Trust',
#   'itrustcapital',
#   "('itrustcapital', 1) ('braintrust', 1) ('trust-will', 1) ('safetrust', 1) ('trustarc', 1)"),
#  ('MICRON TECHNOLOGY INC', None, ''),
#  ('KEURIG DR PEPPER INC',
#   'dream-games',
#   "('dream-games', 1) ('smartdrive-systems', 1) ('peerstreet', 1) ('hydrow', 1) ('idrx', 1)"),
#  ('JPMORGAN CHASE & CO.',
#   'colossyan',
#   "('colossyan', 1) ('cognata', 1) ('orderco', 1) ('cotopaxi', 1) ('pyxis-oncology', 1)"),
#  ('Morgan Stanley BAML Trust',
#   'itrustcapital',
#   "('itrustcapital', 1) ('braintrust', 1) ('trust-will', 1) ('safetrust', 1) ('trustarc', 1)"),
#  ('ALTICE FRANCE SA',
#   'sahara-ai',
#   "('sahara-ai', 1) ('wasabi-technologies', 1) ('trisalus-life-sciences', 1) ('messari', 1) ('recursal-ai', 1)"),
#  ('NRG ENERGY INC', None, ''),
#  ('ROYALTY PHARMA PLC',
#   'royalty-exchange',
#   "('royalty-exchange', 2) ('circle-pharma', 1) ('ansun-biopharma', 1) ('arrivent-biopharma', 1) ('pmv-pharma', 1)"),
#  ('BURLINGTN NORTH SANTA FE',
#   'feast',
#   "('feast', 1) ('inferless', 1) ('1life-healthcare', 1) ('trisalus-life-sciences', 1) ('federated-media', 1)"),
#  ('ENBRIDGE INC', 'seven-bridges', "('seven-bridges', 5)"),
#  ('FedEx Corp',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('Verus Securitization Trust',
#   'itrustcapital',
#   "('itrustcapital', 1) ('braintrust', 1) ('trust-will', 1) ('safetrust', 1) ('trustarc', 1)"),
#  ('30 Year Standalone Fixed 2nd',
#   'myyearbook',
#   "('myyearbook', 1) ('freshbooks-2ndsite', 1) ('lightyear', 1)"),
#  ('Dominion Energy Inc', None, ''),
#  ('OCCIDENTAL PETROLEUM CORP',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('Duke Energy Corp',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('NVIDIA Corp',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('GENERAL MOTORS CO',
#   'generally-intelligent',
#   "('generally-intelligent', 2) ('general-assembly', 2) ('colossyan', 1) ('cognata', 1) ('orderco', 1)"),
#  ('Starbucks Corp',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('Vodafone Group PLC', None, ''),
#  ('US BANCORP',
#   'cumulus-networks',
#   "('cumulus-networks', 2) ('customer-io', 2) ('attralus', 2) ('itrustcapital', 2) ('rhombus-systems', 2)"),
#  ('Royal Bank of Canada',
#   'royalty-exchange',
#   "('royalty-exchange', 2) ('royal-markets', 2)"),
#  ('WESTPAC BANKING CORP',
#   'wave-computing',
#   "('wave-computing', 1) ('chainguard', 1) ('helsing', 1) ('atom-computing', 1) ('singular', 1)"),
#  ('COMCAST CORPORATION', None, ''),
#  ('Humana Inc', None, ''),
#  ('NEW YORK STOCK EXCHANGE',
#   'renew-financial',
#   "('renew-financial', 2) ('new-relic', 2) ('new-age-eats', 2) ('knewton', 2) ('newlight-technologies', 2)"),
#  ('Synchrony Financial', None, ''),
#  ('MIZUHO FINANCIAL GROUP', None, ''),
#  ('DIAMONDBACK ENERGY INC', None, ''),
#  ('Texas Instruments Inc',
#   'virtual-instruments',
#   "('virtual-instruments', 1)"),
#  ('ASML Holding NV',
#   'conviva',
#   "('conviva', 1) ('envoy-global', 1) ('invisible-technologies', 1) ('aws-convergence-technologies', 1) ('unison-home-ownership-investors', 1)"),
#  ('Bank of America N.A.',
#   'american-gene-technologies-international',
#   "('american-gene-technologies-international', 3) ('electrify-america', 2) ('renovate-america', 2) ('american-well', 2) ('cognata', 1)"),
#  ('DISCOVERY COMMUNICATIONS', None, ''),
#  ('Lockheed Martin Corp',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('Zoetis Inc', None, ''),
#  ('Exelon Corp',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('Eversource Energy', None, ''),
#  ('MSCI INC', 'platform-science', "('platform-science', 5)"),
#  ('EQT CORP',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('Constellation Brands Inc',
#   'before-brands',
#   "('before-brands', 1) ('d1-brands', 1) ('forum-brands', 1) ('elevate-brands', 1) ('berlin-brands-group', 1)"),
#  ('IRS',
#   'vets-first-choice',
#   "('vets-first-choice', 5) ('birst', 5) ('airship', 5) ('virsec', 5) ('airspace-technologies-1', 5)"),
#  ('EDISON INTERNATIONAL',
#   'c3-international',
#   "('c3-international', 1) ('zipline-international', 1) ('branch-international', 1) ('american-gene-technologies-international', 1)"),
#  ('Procter & Gamble Co/The', None, ''),
#  ('Thermo Fisher Scientific Inc',
#   'star-scientific',
#   "('star-scientific', 1) ('response-scientific', 1)"),
#  ('Norfolk Southern Corp',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('KROGER CO',
#   'colossyan',
#   "('colossyan', 1) ('cognata', 1) ('orderco', 1) ('cotopaxi', 1) ('pyxis-oncology', 1)"),
#  ('State of Connecticut',
#   'finite-state',
#   "('finite-state', 2) ('statespace', 2) ('states-title', 2)"),
#  ('WELLS FARGO and CO',
#   'wellsaid-labs',
#   "('wellsaid-labs', 2) ('colossyan', 1) ('cognata', 1) ('orderco', 1) ('cotopaxi', 1)"),
#  ('CARRIER GLOBAL CORP',
#   'utility-global',
#   "('utility-global', 1) ('envoy-global', 1) ('rubicon-global', 1) ('thrive-global', 1) ('hashicorp', 1)"),
#  ('SIRIUS XM RADIO INC',
#   'mbx-memebox',
#   "('mbx-memebox', 1) ('flixmobility', 1) ('xmtp', 1)"),
#  ('United States Treasury Notes',
#   'unitedmasters',
#   "('unitedmasters', 2) ('kitchen-united', 2) ('modern-treasury', 1) ('statespace', 1) ('treasury-prime', 1)"),
#  ('SHELL INTERNATIONAL FIN',
#   'coreshell',
#   "('coreshell', 2) ('infinite-reality', 1) ('finite-state', 1) ('infinidat', 1) ('property-finder', 1)"),
#  ('SERVICE PROPERTIES TRUST',
#   'camunda-services',
#   "('camunda-services', 2) ('elevate-services', 2) ('serviceaide', 2) ('servicemax', 2) ('servicetitan', 2)"),
#  ('Freddie Mac - SCRT',
#   'chromacode',
#   "('chromacode', 1) ('humacyte', 1) ('alto-pharmacy', 1) ('thought-machine', 1) ('karmacheck', 1)"),
#  ('GLP CAPITAL LP / FIN II',
#   'equiam-master-fund-iii-lp',
#   "('equiam-master-fund-iii-lp', 2) ('trialpay', 1) ('infinite-reality', 1) ('hawaiian-bros', 1) ('delphinus-medical-technologies', 1)"),
#  ('FREEPORT-MCMORAN INC', None, ''),
#  ('QUALCOMM INC', None, ''),
#  ('ASTRAZENECA PLC', None, ''),
#  ('Danaher Corp',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('EQUINOR ASA',
#   'wasabi-technologies',
#   "('wasabi-technologies', 1) ('ultra-safe-nuclear', 1) ('asapp', 1) ('akasa', 1) ('casana', 1)"),
#  ('FORD MOTOR CREDIT COMPANY LLC',
#   'nikola-motor-company',
#   "('nikola-motor-company', 2) ('the-browser-company', 1) ('aptera-motors', 1) ('companycam', 1) ('accompany-health', 1)"),
#  ('SAP SE',
#   'sapience-therapeutics',
#   "('sapience-therapeutics', 2) ('preset', 1) ('metabase', 1) ('securiti-ai', 1) ('sense-talent-labs', 1)"),
#  ('ConocoPhillips', None, ''),
#  ('WESTERN MIDSTREAM OPERAT', None, ''),
#  ('FORD MOTOR COMPANY',
#   'nikola-motor-company',
#   "('nikola-motor-company', 2) ('the-browser-company', 1) ('aptera-motors', 1) ('companycam', 1) ('accompany-health', 1)"),
#  ('Conagra Brands Inc',
#   'before-brands',
#   "('before-brands', 1) ('d1-brands', 1) ('forum-brands', 1) ('elevate-brands', 1) ('berlin-brands-group', 1)"),
#  ('NATIONAL RURAL UTIL COOP',
#   'c3-international',
#   "('c3-international', 2) ('zipline-international', 2) ('branch-international', 2) ('american-gene-technologies-international', 2) ('utility-global', 1)"),
#  ('DELL INT LLC / EMC CORP',
#   'integrate',
#   "('integrate', 1) ('tintri', 1) ('intercom', 1) ('urbint', 1) ('vinted', 1)"),
#  ('Credit Suisse Group AG',
#   'nova-credit',
#   "('nova-credit', 2) ('credit-sesame', 2) ('credit-karma', 2) ('tomocredit', 2) ('biz2credit', 2)"),
#  ('Freddie Mac Multifamily Structured Pass Through Certificates',
#   'chromacode',
#   "('chromacode', 1) ('humacyte', 1) ('cloudpassage', 1) ('moviepass', 1) ('alto-pharmacy', 1)"),
#  ('PHILLIPS 66', '1366-technologies', "('1366-technologies', 1)"),
#  ('Walt Disney Co/The',
#   'waltonchain-foundation',
#   "('waltonchain-foundation', 2)"),
#  ('EVERSOURCE ENERGY', None, ''),
#  ('ALLY FINANCIAL INC',
#   'generally-intelligent',
#   "('generally-intelligent', 5) ('kallyope', 5) ('musical-ly', 5) ('finally', 5) ('ally-technologies', 5)"),
#  ('NIKE Inc', None, ''),
#  ('PNC FINANCIAL SERVICES',
#   'camunda-services',
#   "('camunda-services', 1) ('elevate-services', 1) ('xenex-disinfection-services', 1) ('internet-of-services-foundation', 1)"),
#  ('University of California', None, ''),
#  ('REALTY INCOME CORP',
#   'realtytrac',
#   "('realtytrac', 2) ('realty-mogul', 2) ('realtyshares', 2) ('customer-io', 1) ('flyhomes', 1)"),
#  ('Port Authority of New York & New Jersey',
#   'renew-financial',
#   "('renew-financial', 2) ('new-relic', 2) ('portalone', 2) ('new-age-eats', 2) ('knewton', 2)"),
#  ('Citigroup Commercial Mortgage Trust',
#   'citizen',
#   "('citizen', 2) ('itrustcapital', 1) ('braintrust', 1) ('trust-will', 1) ('safetrust', 1)"),
#  ('FEDERAL NAT MTG ASN GTD REM PA',
#   'cognata',
#   "('cognata', 1) ('opal', 1) ('parry-labs', 1) ('trialpay', 1) ('cotopaxi', 1)"),
#  ('Hess Corp',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('Fifth Third Bancorp',
#   'third-arc-bio',
#   "('third-arc-bio', 1) ('third-pole-therapeutics', 1) ('parkway-bancorp', 1) ('thirdlove', 1)"),
#  ('NISOURCE INC', None, ''),
#  ('Tencent Holdings Ltd', 'tencent', "('tencent', 2)"),
#  ('Stryker Corp',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('Sempra Energy', 'insempra', "('insempra', 5)"),
#  ('Phillips 66', '1366-technologies', "('1366-technologies', 1)"),
#  ('Booking Holdings Inc', None, ''),
#  ('LOCKHEED MARTIN CORP',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('Goldman Sachs Bank USA',
#   'nusano',
#   "('nusano', 1) ('profusa', 1) ('equitusai', 1) ('usa-rare-earth', 1) ('abacus-ai', 1)"),
#  ('FIRSTENERGY CORP',
#   'vets-first-choice',
#   "('vets-first-choice', 2) ('firstp2p', 2) ('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1)"),
#  ('MARSH & MCLENNAN COS INC',
#   'marshmallow',
#   "('marshmallow', 2) ('theracos', 1) ('arccos-golf', 1) ('mark-cuban-cost-plus-drug-company', 1) ('sarcos-robotics', 1)"),
#  ('State of Washington',
#   'finite-state',
#   "('finite-state', 2) ('statespace', 2) ('states-title', 2)"),
#  ('Equinor ASA',
#   'wasabi-technologies',
#   "('wasabi-technologies', 1) ('ultra-safe-nuclear', 1) ('asapp', 1) ('akasa', 1) ('casana', 1)"),
#  ('UNITEDHEALTH GROUP INCORPORATED', None, ''),
#  ('Coca-Cola Co/The', None, ''),
#  ('DOMINION ENERGY INC', None, ''),
#  ('GENERAL ELECTRIC CO',
#   'generally-intelligent',
#   "('generally-intelligent', 2) ('general-assembly', 2) ('colossyan', 1) ('cognata', 1) ('orderco', 1)"),
#  ('Commonwealth of Massachusetts',
#   'commonwealth-fusion',
#   "('commonwealth-fusion', 2)"),
#  ('Banco Santander SA',
#   'mark-cuban-cost-plus-drug-company',
#   "('mark-cuban-cost-plus-drug-company', 2) ('bancor', 2) ('parkway-bancorp', 2) ('sahara-ai', 1) ('wasabi-technologies', 1)"),
#  ('NORTHROP GRUMMAN CORP',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('Illinois Finance Authority',
#   'parallel-finance',
#   "('parallel-finance', 1) ('possible-finance', 1) ('point-digital-finance', 1) ('m1-finance', 1) ('zestfinance', 1)"),
#  ('CISCO SYSTEMS INC', None, ''),
#  ('ADOBE INC', None, ''),
#  ('CONSTELLATION BRANDS INC',
#   'before-brands',
#   "('before-brands', 1) ('d1-brands', 1) ('forum-brands', 1) ('elevate-brands', 1) ('berlin-brands-group', 1)"),
#  ('THE GOLDMAN SACHS GROUP, INC.', None, ''),
#  ('VIRGINIA ELEC & POWER CO',
#   'colossyan',
#   "('colossyan', 1) ('cognata', 1) ('orderco', 1) ('cotopaxi', 1) ('pyxis-oncology', 1)"),
#  ('ING Groep NV',
#   'ledger-investing',
#   "('ledger-investing', 3) ('envy-gaming', 3) ('halo-investing', 3) ('invisible-urban-charging', 3) ('wave-computing', 2)"),
#  ('INTL BK RECON & DEVELOP',
#   'cour-pharmaceuticals-development',
#   "('cour-pharmaceuticals-development', 1) ('webkinz', 1)"),
#  ('JP MORGAN CHASE BANK', 'capchase', "('capchase', 1)"),
#  ('Boston Scientific Corp',
#   'boston-dynamics',
#   "('boston-dynamics', 2) ('bostongene', 2) ('boston-metal', 2) ('star-scientific', 1) ('hashicorp', 1)"),
#  ('Alibaba Group Holding Ltd', 'alibaba', "('alibaba', 2)"),
#  ('BANK OF MONTREAL', None, ''),
#  ('STARBUCKS CORP',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('Citigroup Inc.', 'citizen', "('citizen', 2)"),
#  ('Public Finance Authority',
#   'republic',
#   "('republic', 2) ('trade-republic', 2) ('public-com', 2) ('the-public-health-company', 2) ('parallel-finance', 1)"),
#  ('ROPER TECHNOLOGIES INC',
#   'property-finder',
#   "('property-finder', 5) ('mynd-property-management', 5) ('propertyroomcom', 5)"),
#  ('Angel Oak Mortgage Trust',
#   'angellist',
#   "('angellist', 2) ('vidangel', 2) ('itrustcapital', 1) ('oaknorth-bank', 1) ('braintrust', 1)"),
#  ('GILEAD SCIENCES INC',
#   'trisalus-life-sciences',
#   "('trisalus-life-sciences', 1) ('epic-sciences', 1) ('caris-life-sciences', 1) ('elevance-renewable-sciences', 1) ('truvian-sciences', 1)"),
#  ('KINDER MORGAN INC', None, ''),
#  ('LendingClub Corp. - LCX',
#   'lendingclub',
#   "('lendingclub', 2) ('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1)"),
#  ('FIFTH THIRD BANCORP',
#   'third-arc-bio',
#   "('third-arc-bio', 1) ('third-pole-therapeutics', 1) ('parkway-bancorp', 1) ('thirdlove', 1)"),
#  ('AMERICAN HONDA FINANCE',
#   'american-well',
#   "('american-well', 2) ('american-gene-technologies-international', 2) ('parallel-finance', 1) ('possible-finance', 1) ('point-digital-finance', 1)"),
#  ('Citigroup Global Markets Inc.',
#   'citizen',
#   "('citizen', 2) ('utility-global', 1) ('envoy-global', 1) ('rubicon-global', 1) ('thrive-global', 1)"),
#  ('WARNERMEDIA HOLDINGS INC', None, ''),
#  ('ONCOR ELECTRIC DELIVERY',
#   'oncorus',
#   "('oncorus', 2) ('concord', 2) ('highland-electric-transportation', 1) ('delivery-hero', 1) ('electric-ai', 1)"),
#  ('NXP BV/NXP FDG/NXP USA',
#   'nusano',
#   "('nusano', 1) ('profusa', 1) ('equitusai', 1) ('usa-rare-earth', 1) ('abacus-ai', 1)"),
#  ('POST HOLDINGS INC',
#   'easypost',
#   "('easypost', 5) ('postmates-inc', 5) ('sharespost', 5) ('huffington-post', 5) ('posthog', 5)"),
#  ('TRAVELERS COS INC',
#   'theracos',
#   "('theracos', 1) ('arccos-golf', 1) ('mark-cuban-cost-plus-drug-company', 1) ('sarcos-robotics', 1) ('ecosense', 1)"),
#  ('Lam Research Corp',
#   'glam-media',
#   "('glam-media', 2) ('lambda', 2) ('nikola-motor-company', 2) ('lambdatest', 2) ('clearflame-engines', 2)"),
#  ('Novartis AG',
#   'voyage-ai',
#   "('voyage-ai', 1) ('moengage', 1) ('halo-diagnostics', 1) ('digital-diagnostics', 1) ('agility-robotics', 1)"),
#  ('STANDARD CHARTERED PLC', 'standard-cognition', "('standard-cognition', 2)"),
#  ('ROMANIA', None, ''),
#  ('BAUSCH HEALTH COS INC',
#   'happy-health',
#   "('happy-health', 1) ('theracos', 1) ('flo-health', 1) ('iris-telehealth', 1) ('vida-health', 1)"),
#  ('IRON MOUNTAIN INC',
#   'ironplanet',
#   "('ironplanet', 2) ('mobileiron', 2) ('niron-magnetics', 2) ('ironscales', 2) ('ironnet-cybersecurity', 2)"),
#  ('Credit Suisse International',
#   'nova-credit',
#   "('nova-credit', 2) ('credit-sesame', 2) ('credit-karma', 2) ('tomocredit', 2) ('biz2credit', 2)"),
#  ('JOHNSON & JOHNSON', None, ''),
#  ('WF-RBS Commercial Mortgage Trust',
#   'itrustcapital',
#   "('itrustcapital', 1) ('braintrust', 1) ('trust-will', 1) ('safetrust', 1) ('trustarc', 1)"),
#  ('DUKE ENERGY CAROLINAS', None, ''),
#  ('Charles Schwab Corp/The', None, ''),
#  ('BOSTON SCIENTIFIC CORP',
#   'boston-dynamics',
#   "('boston-dynamics', 2) ('bostongene', 2) ('boston-metal', 2) ('star-scientific', 1) ('hashicorp', 1)"),
#  ('RAYTHEON TECH CORP',
#   'arrivetech',
#   "('arrivetech', 1) ('tissuetech', 1) ('qliktech', 1) ('hashicorp', 1) ('techstyle', 1)"),
#  ('INTERCONTINENTALEXCHANGE', None, ''),
#  ('BlackRock Funds III',
#   'equiam-master-fund-iii-lp',
#   "('equiam-master-fund-iii-lp', 1)"),
#  ('GOLDMAN SACHS', None, ''),
#  ('INTUIT INC',
#   'intuition-robotics',
#   "('intuition-robotics', 5) ('applied-intuition', 5)"),
#  ('Public Storage',
#   'republic',
#   "('republic', 2) ('trade-republic', 2) ('public-com', 2) ('the-public-health-company', 2) ('nimble-storage', 1)"),
#  ('Navient Student Loan Trust',
#   'itrustcapital',
#   "('itrustcapital', 1) ('braintrust', 1) ('trust-will', 1) ('safetrust', 1) ('trustarc', 1)"),
#  ('DANAHER CORP',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('EURO',
#   'neurona-therapeutics',
#   "('neurona-therapeutics', 5) ('impel-neuropharma', 5) ('precision-neuroscience', 5) ('neurogene', 5) ('neuron23', 5)"),
#  ('Fannie Mae or Freddie Mac',
#   'chromacode',
#   "('chromacode', 1) ('zunum-aero', 1) ('panorama-education', 1) ('humacyte', 1) ('alto-pharmacy', 1)"),
#  ('Eli Lilly & Co',
#   'corelight',
#   "('corelight', 3) ('elixir-medical', 2) ('ophelia', 2) ('relievant-medsystems', 2) ('new-relic', 2)"),
#  ('PAYPAL HOLDINGS INC', None, ''),
#  ('MICROCHIP TECHNOLOGY INC', None, ''),
#  ('Target Corp',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('New Jersey Economic Development Authority',
#   'renew-financial',
#   "('renew-financial', 2) ('new-relic', 2) ('new-age-eats', 2) ('knewton', 2) ('newlight-technologies', 2)"),
#  ("Lowe's Cos Inc",
#   'theracos',
# ...
#   "('c3-international', 1) ('zipline-international', 1) ('branch-international', 1) ('american-gene-technologies-international', 1)"),
#  ('INTUITIVE SURGICAL INC',
#   'auris-surgical-robotics',
#   "('auris-surgical-robotics', 1) ('cmr-surgical', 1) ('think-surgical', 1)"),
#  ('REGAL REXNORD CORP',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('Otis Worldwide Corp',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('TE Connectivity Ltd',
#   'character-ai',
#   "('character-ai', 2) ('great-expectations', 2) ('integrate', 2) ('gosite', 2) ('tekion', 2)"),
#  ('United Mexican States',
#   'unitedmasters',
#   "('unitedmasters', 2) ('kitchen-united', 2) ('statespace', 1) ('states-title', 1)"),
#  ('ROSS STORES INC',
#   'crossborder-solutions',
#   "('crossborder-solutions', 2) ('rossum', 2) ('cross-river-bank', 2) ('crossbeam', 2) ('premier-lacrosse-league', 2)"),
#  ('APTIV PLC',
#   'redaptive',
#   "('redaptive', 2) ('adaptive-planning', 2) ('adaptive-insights', 2) ('captivateiq', 2) ('adaptive-biotechnologies', 2)"),
#  ('Lululemon Athletica Inc', None, ''),
#  ('Camden Property Trust',
#   'itrustcapital',
#   "('itrustcapital', 1) ('braintrust', 1) ('property-finder', 1) ('trust-will', 1) ('safetrust', 1)"),
#  ('Raytheon Technologies Corp',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('Duke Energy Progress LLC', None, ''),
#  ('Atmos Energy Corp',
#   'atmosphere',
#   "('atmosphere', 2) ('atmosic', 2) ('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1)"),
#  ('PacifiCorp', None, ''),
#  ('DOLLAR TREE INC',
#   'peerstreet',
#   "('peerstreet', 1) ('main-street-hub', 1) ('mainstreet', 1) ('quinstreet', 1) ('eatstreet', 1)"),
#  ('CALPINE CORP',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('Goldman Sachs', None, ''),
#  ('Amazon.com, Inc.', None, ''),
#  ('Amphenol Corp',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('American Homes 4 Rent',
#   'american-well',
#   "('american-well', 2) ('american-gene-technologies-international', 2) ('bittorrent', 1) ('4d-molecular-therapeutics-4dmt', 1) ('flyhomes', 1)"),
#  ('Microchip Technology Inc', None, ''),
#  ('EOG RESOURCES INC',
#   'ideogram-ai',
#   "('ideogram-ai', 2) ('neogene-therapeutics', 2) ('jetti-resources', 1) ('applied-medical-resources', 1)"),
#  ('ENERGY TRANSFER OPERATNG',
#   'transferwise',
#   "('transferwise', 2) ('transfermate', 2)"),
#  ('CHICAGO MERCANTILE EXCHANGE INC.',
#   'stack-exchange',
#   "('stack-exchange', 1) ('royalty-exchange', 1) ('science-exchange', 1) ('openexchange', 1)"),
#  ('METLIFE INC', None, ''),
#  ('COSTCO WHOLESALE CORP',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('CME GROUP INC.', 'disc-medicine', "('disc-medicine', 2)"),
#  ('Airbus SE',
#   'preset',
#   "('preset', 1) ('metabase', 1) ('securiti-ai', 1) ('sense-talent-labs', 1) ('camunda-services', 1)"),
#  ('SOUTHWESTERN ENERGY CO',
#   'colossyan',
#   "('colossyan', 1) ('cognata', 1) ('orderco', 1) ('cotopaxi', 1) ('pyxis-oncology', 1)"),
#  ('Synopsys Inc', None, ''),
#  ('T-Mobile USA, Inc.',
#   'nusano',
#   "('nusano', 1) ('profusa', 1) ('equitusai', 1) ('usa-rare-earth', 1) ('abacus-ai', 1)"),
#  ('UNIFORM MBS', None, ''),
#  ('ARES CAPITAL CORP',
#   'teamshares',
#   "('teamshares', 2) ('sharespost', 2) ('cellares', 2) ('caresyntax', 2) ('linksquares', 2)"),
#  ('Suncor Energy Inc', None, ''),
#  ('CHENIERE ENERGY INC', None, ''),
#  ('Southern Co/The', None, ''),
#  ('BLACKROCK INC', None, ''),
#  ('Teleflex Inc', None, ''),
#  ('ICON PLC',
#   'rubicon-global',
#   "('rubicon-global', 2) ('alif-semiconductor', 2) ('icon', 2) ('peregrine-semiconductor', 2) ('esilicon', 2)"),
#  ('Neuberger Berman CLO Ltd',
#   'spycloud',
#   "('spycloud', 1) ('cloudleaf', 1) ('carecloud', 1) ('ciphercloud', 1) ('cloudflare', 1)"),
#  ('Cummins Inc', None, ''),
#  ('HILTON DOMESTIC OPERATIN', None, ''),
#  ('Occidental Petroleum Corp',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('MCDONALDS CORP',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('APACHE CORP',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('Orange SA',
#   'sahara-ai',
#   "('sahara-ai', 1) ('wasabi-technologies', 1) ('trisalus-life-sciences', 1) ('messari', 1) ('recursal-ai', 1)"),
#  ('CPS Auto Trust',
#   'itrustcapital',
#   "('itrustcapital', 1) ('autoleadstar', 1) ('automation-anywhere', 1) ('voyage-auto', 1) ('braintrust', 1)"),
#  ('Zimmer Biomet Holdings Inc', None, ''),
#  ('FRONTIER COMMUNICATIONS',
#   'frontier-car-group',
#   "('frontier-car-group', 5) ('frontier-medicines', 5) ('efficient-frontier', 5)"),
#  ('PROSUS NV',
#   'conviva',
#   "('conviva', 1) ('envoy-global', 1) ('invisible-technologies', 1) ('aws-convergence-technologies', 1) ('unison-home-ownership-investors', 1)"),
#  ('Masco Corp',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('UK CLEARING HOUSE LIMITED',
#   'conduktor',
#   "('conduktor', 2) ('lukka', 2) ('suki', 2) ('glaukos-corporation', 2) ('bukalapak', 2)"),
#  ('Kroger Co/The', None, ''),
#  ('PulteGroup Inc', None, ''),
#  ('SAUDI INTERNATIONAL BOND',
#   'commonbond',
#   "('commonbond', 1) ('c3-international', 1) ('zipline-international', 1) ('branch-international', 1) ('carbon-direct', 1)"),
#  ('Chicago Board of Education',
#   'guild-education',
#   "('guild-education', 1) ('panorama-education', 1) ('auditboard', 1) ('podium-education', 1) ('clipboard-health', 1)"),
#  ('Molina Healthcare Inc', None, ''),
#  ('DCP MIDSTREAM OPERATING', None, ''),
#  ('L3HARRIS TECH INC',
#   'arrivetech',
#   "('arrivetech', 1) ('tissuetech', 1) ('qliktech', 1) ('techstyle', 1) ('nanotech-energy', 1)"),
#  ('CarMax Auto Owner Trust',
#   'itrustcapital',
#   "('itrustcapital', 1) ('autoleadstar', 1) ('automation-anywhere', 1) ('voyage-auto', 1) ('unison-home-ownership-investors', 1)"),
#  ('Drive Auto Receivables Trust',
#   'smartdrive-systems',
#   "('smartdrive-systems', 2) ('hopskipdrive', 2) ('drivewealth', 2) ('drivezy', 2) ('pipedrive', 2)"),
#  ('BECTON DICKINSON AND CO',
#   'colossyan',
#   "('colossyan', 1) ('cognata', 1) ('orderco', 1) ('cotopaxi', 1) ('pyxis-oncology', 1)"),
#  ('Carvana Auto Receivables Trust',
#   'itrustcapital',
#   "('itrustcapital', 1) ('autoleadstar', 1) ('automation-anywhere', 1) ('voyage-auto', 1) ('braintrust', 1)"),
#  ('American International Group Inc',
#   'american-gene-technologies-international',
#   "('american-gene-technologies-international', 3) ('american-well', 2) ('c3-international', 1) ('zipline-international', 1) ('branch-international', 1)"),
#  ('REPUBLIC OF INDONESIA',
#   'republic',
#   "('republic', 2) ('trade-republic', 2)"),
#  ('State of Wisconsin',
#   'finite-state',
#   "('finite-state', 2) ('statespace', 2) ('states-title', 2)"),
#  ('FNMA/FHLG TBA ISSUER',
#   'owlet-baby-care',
#   "('owlet-baby-care', 1) ('benefitbay', 1) ('onefootball', 1) ('toca-football', 1) ('at-bay', 1)"),
#  ('BlackRock Inc', None, ''),
#  ('MSCI Inc', 'platform-science', "('platform-science', 5)"),
#  ('LUMEN TECHNOLOGIES INC', 'nanolumens', "('nanolumens', 5)"),
#  ('Northern Trust Corp',
#   'itrustcapital',
#   "('itrustcapital', 1) ('hashicorp', 1) ('braintrust', 1) ('trust-will', 1) ('safetrust', 1)"),
#  ('MercadoLibre Inc', None, ''),
#  ('Westlake Automobile Receivables Trust',
#   'itrustcapital',
#   "('itrustcapital', 1) ('braintrust', 1) ('trust-will', 1) ('safetrust', 1) ('trustarc', 1)"),
#  ('Monolithic Power Systems Inc',
#   'terrapower',
#   "('terrapower', 1) ('rad-power-bikes', 1) ('empower', 1) ('sunpower', 1) ('achates-power', 1)"),
#  ('ENEL FINANCE INTL NV',
#   'conviva',
#   "('conviva', 1) ('envoy-global', 1) ('invisible-technologies', 1) ('aws-convergence-technologies', 1) ('unison-home-ownership-investors', 1)"),
#  ('General Motors Financial Co Inc',
#   'generally-intelligent',
#   "('generally-intelligent', 2) ('general-assembly', 2) ('colossyan', 1) ('cognata', 1) ('orderco', 1)"),
#  ('Iron Mountain Inc',
#   'ironplanet',
#   "('ironplanet', 2) ('mobileiron', 2) ('niron-magnetics', 2) ('ironscales', 2) ('ironnet-cybersecurity', 2)"),
#  ('Campbell Soup Co',
#   'colossyan',
#   "('colossyan', 1) ('cognata', 1) ('orderco', 1) ('cotopaxi', 1) ('pyxis-oncology', 1)"),
#  ('Atlas Copco AB',
#   'atlas',
#   "('atlas', 2) ('atlassian', 2) ('world-labs', 1) ('metabase', 1) ('parry-labs', 1)"),
#  ('Republic of Indonesia',
#   'republic',
#   "('republic', 2) ('trade-republic', 2)"),
#  ('ANTHEM INC', None, ''),
#  ('BIOGEN INC', None, ''),
#  ('CHEVRON CORP',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('Asian Development Bank',
#   'cour-pharmaceuticals-development',
#   "('cour-pharmaceuticals-development', 1)"),
#  ('Ventas Realty LP',
#   'trialpay',
#   "('trialpay', 1) ('delphinus-medical-technologies', 1) ('yelp', 1) ('cool-planet-energy-systems', 1) ('realtytrac', 1)"),
#  ('GATX Corp',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('Municipal Electric Authority of Georgia',
#   'highland-electric-transportation',
#   "('highland-electric-transportation', 1) ('electric-ai', 1) ('infinitum-electric', 1) ('electric-hydrogen', 1)"),
#  ('CHUBB LTD', None, ''),
#  ('Chipotle Mexican Grill Inc', None, ''),
#  ('PARKER-HANNIFIN CORP',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('AMERICAN ELECTRIC POWER',
#   'american-well',
#   "('american-well', 2) ('american-gene-technologies-international', 2) ('terrapower', 1) ('rad-power-bikes', 1) ('empower', 1)"),
#  ('Automatic Data Processing Inc',
#   'gooddata',
#   "('gooddata', 1) ('yipitdata', 1) ('datami', 1) ('pavilion-data', 1) ('datagrail', 1)"),
#  ('Kellogg Co',
#   'colossyan',
#   "('colossyan', 1) ('cognata', 1) ('orderco', 1) ('cotopaxi', 1) ('pyxis-oncology', 1)"),
#  ('PG and E CORP',
#   'deepgram',
#   "('deepgram', 3) ('deepgreen-metals', 3) ('upgrade-inc', 3) ('topgolf', 2) ('pgp', 2)"),
#  ('UST BILLS',
#   'customer-io',
#   "('customer-io', 2) ('itrustcapital', 2) ('gusto', 2) ('dust-identity', 2) ('braintrust', 2)"),
#  ('Paramount Global',
#   'utility-global',
#   "('utility-global', 1) ('envoy-global', 1) ('rubicon-global', 1) ('thrive-global', 1) ('forge-global', 1)"),
#  ('Aon PLC',
#   'mariana-oncology',
#   "('mariana-oncology', 2) ('strata-oncology', 2) ('ninjaone', 2) ('gaia-online', 2)"),
#  ('IDEXX Laboratories Inc',
#   'colossal-laboratories-biosciences',
#   "('colossal-laboratories-biosciences', 1)"),
#  ('CIM Trust',
#   'icims',
#   "('icims', 2) ('xcimer-energy', 2) ('itrustcapital', 1) ('braintrust', 1) ('trust-will', 1)"),
#  ('AES CORP',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('Alphabet Inc.', None, ''),
#  ('DTE ENERGY CO',
#   'dtex',
#   "('dtex', 2) ('colossyan', 1) ('cognata', 1) ('orderco', 1) ('cotopaxi', 1)"),
#  ('Republic of Colombia', 'republic', "('republic', 2) ('trade-republic', 2)"),
#  ('MGM RESORTS INTERNATIONAL',
#   'c3-international',
#   "('c3-international', 1) ('zipline-international', 1) ('branch-international', 1) ('american-gene-technologies-international', 1)"),
#  ('Nasdaq Inc', 'nasdaq-private-market', "('nasdaq-private-market', 5)"),
#  ('Voya Financial Inc',
#   'voyage-ai',
#   "('voyage-ai', 5) ('voyage-auto', 5) ('voyager-space-holdings', 5) ('bluevoyant', 5)"),
#  ('Align Technology Inc', None, ''),
#  ('EPR Properties',
#   'cafepress',
#   "('cafepress', 2) ('reprise', 2) ('injective-protocol', 2)"),
#  ('Infineon Technologies AG',
#   'voyage-ai',
#   "('voyage-ai', 1) ('moengage', 1) ('halo-diagnostics', 1) ('digital-diagnostics', 1) ('agility-robotics', 1)"),
#  ('RAYTHEON TECHNOLOGIES CORP',
#   'hashicorp',
#   "('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1) ('cincor-pharma', 1) ('scorpion-therapeutics', 1)"),
#  ('Commonwealth of Puerto Rico',
#   'commonwealth-fusion',
#   "('commonwealth-fusion', 2)"),
#  ('Emerson Electric Co',
#   'colossyan',
#   "('colossyan', 1) ('cognata', 1) ('orderco', 1) ('cotopaxi', 1) ('pyxis-oncology', 1)"),
#  ('PTC Inc', None, ''),
#  ('AMAZON.COM, INC.', None, ''),
#  ('Cadence Design Systems Inc',
#   'circadence',
#   "('circadence', 2) ('cadence-solutions', 2) ('ecovative-design', 1) ('redesign-health', 1) ('99designs', 1)"),
#  ('Southwest Airlines Co',
#   'colossyan',
#   "('colossyan', 1) ('cognata', 1) ('orderco', 1) ('cotopaxi', 1) ('pyxis-oncology', 1)"),
#  ('MORGAN STANLEY & CO. INTERNATIONAL',
#   'colossyan',
#   "('colossyan', 1) ('cognata', 1) ('orderco', 1) ('cotopaxi', 1) ('pyxis-oncology', 1)"),
#  ('COCA COLA CO',
#   'accolade',
#   "('accolade', 2) ('percolate-industries', 2) ('digital-chocolate', 2) ('colossyan', 1) ('cognata', 1)"),
#  ('AvalonBay Communities Inc', None, ''),
#  ('UDR Inc', 'mudrex', "('mudrex', 5)"),
#  ('Diageo PLC', None, ''),
#  ('Equity Residential', 'equitybee', "('equitybee', 2)"),
#  ('ARAB REPUBLIC OF EGYPT',
#   'clarabridge',
#   "('clarabridge', 2) ('republic', 1) ('trade-republic', 1)"),
#  ('MARSH and MCLENNAN COS INC',
#   'marshmallow',
#   "('marshmallow', 2) ('theracos', 1) ('arccos-golf', 1) ('mark-cuban-cost-plus-drug-company', 1) ('sarcos-robotics', 1)"),
#  ('BASF SE',
#   'preset',
#   "('preset', 1) ('metabase', 1) ('securiti-ai', 1) ('sense-talent-labs', 1) ('camunda-services', 1)"),
#  ('VERTEX PHARMACEUTICALS INC', None, ''),
#  ('Simon Property Group Inc',
#   'simon',
#   "('simon', 2) ('property-finder', 1) ('mynd-property-management', 1) ('propertyroomcom', 1)"),
#  ('BRISTOL-MYERS SQUIBB COMPANY',
#   'the-browser-company',
#   "('the-browser-company', 1) ('companycam', 1) ('accompany-health', 1) ('nikola-motor-company', 1) ('mark-cuban-cost-plus-drug-company', 1)"),
#  ('GLENCORE FUNDING LLC', 'funding-circle', "('funding-circle', 1)"),
#  ('MATTEL INC', None, ''),
#  ('Keysight Technologies Inc', None, ''),
#  ('WASTE MANAGEMENT INC',
#   'mynd-property-management',
#   "('mynd-property-management', 1)"),
#  ('E.ON SE',
#   'nexteon-technologies',
#   "('nexteon-technologies', 2) ('pantheon', 2) ('eon', 2) ('alzheon', 2) ('reonomy', 2)"),
#  ('BLOCK INC',
#   'blockfi',
#   "('blockfi', 5) ('blockstream', 5) ('blockchain-capital', 5) ('autoblocks-ai', 5) ('cityblock-health', 5)"),
#  ('BERKSHIRE HATHAWAY FIN',
#   'infinite-reality',
#   "('infinite-reality', 1) ('finite-state', 1) ('infinidat', 1) ('property-finder', 1) ('finagraph', 1)"),
#  ('NatWest Group PLC', None, ''),
#  ('Citigroup Mortgage Loan Trust Inc',
#   'citizen',
#   "('citizen', 2) ('itrustcapital', 1) ('braintrust', 1) ('trust-will', 1) ('safetrust', 1)"),
#  ('SERVICENOW INC', None, ''),
#  ('Marlette Funding Trust',
#   'itrustcapital',
#   "('itrustcapital', 1) ('braintrust', 1) ('trust-will', 1) ('safetrust', 1) ('trustarc', 1)"),
#  ('Alexandria Real Estate Equities Inc',
#   'infinite-reality',
#   "('infinite-reality', 1) ('real', 1) ('realm', 1) ('finite-state', 1) ('realtytrac', 1)"),
#  ('J.P. Morgan Securities LLC', None, ''),
#  ('WELLTOWER INC', None, ''),
#  ('Bayerische Motoren Werke AG',
#   'voyage-ai',
#   "('voyage-ai', 1) ('moengage', 1) ('halo-diagnostics', 1) ('digital-diagnostics', 1) ('agility-robotics', 1)"),
#  ('Vulcan Materials Co',
#   'vulcanforms',
#   "('vulcanforms', 2) ('colossyan', 1) ('cognata', 1) ('orderco', 1) ('cotopaxi', 1)"),
#  ('FirstEnergy Corp',
#   'vets-first-choice',
#   "('vets-first-choice', 2) ('firstp2p', 2) ('hashicorp', 1) ('avidbots-corp', 1) ('brain-corp', 1)"),
#  ('Northrop Grumman Corporation', None, ''),
#  ('Etsy Inc', 'etsy', "('etsy', 5)"),
#  ('Expedia Group Inc', None, ''),
#  ('Hershey Co/The', None, ''),
#  ...]

# %%
all_matches_df = pd.DataFrame(all_matches, columns=['nport_name', 'first_matched_company', 'all_matches'])
all_matches_df.to_csv('MFM names/perfect_matched.csv', index=False)

# %%
correct_first_match = 0
partial_matches = 0
total_items = len(not_matched_slugs)

unmatched_items = []
partial_matched_items = []
matched_items = []
df_rows = []

for t in not_matched_slugs:
    not_matched_slug = t[1]  # slug
    not_matched_nport_issuer_name = t[0]  # nport_issuer_name
    
    # Get ranked matches
    matches = find_matches_with_weights(not_matched_nport_issuer_name, word_list)
    
    ranked_matches = [match for match in matches if match[1] > 0]
    ranked_matches_str = ', '.join([f"('{item[0]}', {item[1]})" for item in ranked_matches])
    
    match_status = ""
    
    if ranked_matches:
        # Check the first match
        first_match = ranked_matches[0][0]
        
        if first_match == not_matched_slug:
            # Exact match in the first position
            correct_first_match += 1
            match_status = "Matched"
            # add t[0], t[1], ranked_matches to list
            matched_items.append((t[0], t[1], ranked_matches[0]))
        else:
            # If second itme exists in the rest of the ranked matches
            if any(match[0] == not_matched_slug for match in ranked_matches[1:]):
                partial_matches += 1
                partial_matched_items.append((t[0], t[1], ranked_matches))
                match_status = "Partial Match"
            else:
                unmatched_items.append((t[0], t[1], ranked_matches))
                match_status = "Not Matched"
    else:
        unmatched_items.append(t)
        match_status = "Not Ranked - Not Matched"

#     df_rows.append([not_matched_slug, not_matched_nport_issuer_name, ranked_matches_str, match_status])

# _df = pd.DataFrame(df_rows, columns=['not_matched_slug', 'not_matched_nport_issuer_name', 'Ranked Matches', 'Match Status'])

# _df.to_csv('data/output.csv', index=False)

first_match_accuracy = correct_first_match / total_items if total_items > 0 else 0
overall_match_accuracy = (correct_first_match + partial_matches) / total_items if total_items > 0 else 0

print(f"First Match Accuracy: {first_match_accuracy:.2f}")
print(f"Overall Match Accuracy (including partial matches): {overall_match_accuracy:.2f}")
print("Unmatched items:", len(unmatched_items))
# Out:
# First Match Accuracy: 0.22
# Overall Match Accuracy (including partial matches): 0.52
# Unmatched items: 108

# %%
matched_items_df = pd.DataFrame(matched_items, columns=['nport_issuer_name', 'slug', 'rankings'])
matched_items_df.to_csv('data/_test.csv', index=False)

# %%
# create a df out of _df where match status is Partial Match
partial_matched_df = pd.DataFrame(partial_matched_items, columns=['nport_issuer_name', 'slug', 'rankings'])
partial_matched_df
# Out:
#                                     nport_issuer_name                slug  \
# 0                  Life Healthcare Group Holdings Ltd    1life-healthcare
# 1                                    Ant Group Co Ltd       ant-financial
# 2                       Ant International Co. Limited       ant-financial
# 3        Ant International Co. Limited Class C Shares       ant-financial
# 4                                      AppLovin Corp.            applovin
# ..                                                ...                 ...
# 61  TEBRA TECHNOLOGIES, INC. (F.K.A. KAREO, INC.) ...               tebra
# 62                            The Honest Company Inc.  the-honest-company
# 63                           The Honest Company, Inc.  the-honest-company
# 64                             THE HONEST COMPANY INC  the-honest-company
# 65                        THE HONEST COMPANY SERIES D  the-honest-company
#
#                                              rankings
# 0   [(caris-life-sciences, 20), (1life-healthcare,...
# 1   [(palantir, 26), (convoy, 15), (ant-financial,...
# 2   [(palantir, 26), (convoy, 15), (ant-financial,...
# 3   [(convoy, 30), (palantir, 26), (databricks, 21...
# 4   [(hashicorp, 10), (applovin, 8), (brain-corp, ...
# ..                                                ...
# 61          [(kareo, 4), (tebra, 4), (commonbond, 2)]
# 62  [(the-honest-company-inc, 12), (the-honest-com...
# 63  [(the-honest-company-inc, 12), (the-honest-com...
# 64  [(the-honest-company-inc, 12), (the-honest-com...
# 65  [(the-honest-company-inc, 12), (the-honest-com...
#
# [66 rows x 3 columns]

# %%
# Apply the filtering to create a new column with filtered matches in partial_matched
filtered_partial_matched = [
    (row['nport_issuer_name'], row['slug'], row['rankings'], filter_unique_matches(row['rankings']))
    for _, row in partial_matched_df.iterrows()
]
filtered_partial_matched_df = pd.DataFrame(filtered_partial_matched, columns=['nport_issuer_name', 'slug', 'rankings', 'filtered_rankings'])
filtered_partial_matched_df['method'] = 'perfect_matched'
filtered_partial_matched_df.to_csv('data/partial_matched_perfect.csv', index=False)

# %%
# create a pd dataframe of the unmatched items
_not_matched_list = []
for t in unmatched_items:
    _not_matched_list.append([t[1], t[0]])

_df_not_matched = pd.DataFrame(_not_matched_list, columns=['slug', 'nport_issuer_name'])
print(_df_not_matched.head())
_df_not_matched.to_csv('data/unmatched_perfect.csv', index=False)
# Out:
#            slug                 nport_issuer_name
# 0        byju-s        Think & Learn Private Ltd.
# 1  warby-parker                          JAND INC
# 2   3d-robotics           Nauticus Robotics, Inc.
# 3        adroll  NEXTROLL, INC. COMMON SHARES   /
# 4        adroll        NEXTROLL COMMON SHARES   /

# %%
not_matched_list = []
for t in unmatched_items:
    not_matched_list.append([t[0], t[1]])
for t in partial_matched_items:
    not_matched_list.append((t[0], t[1]))

df_not_matched = pd.DataFrame(not_matched_list, columns=['nport_issuer_name','slug'])

# %%
df_forge_price = pd.read_csv('data/forge_price_sample.csv')
df_funding_rounds = pd.read_csv('data/funding-rounds.csv')
df_issuers = pd.read_csv('data/issuers.csv')
df_trade_facts = pd.read_csv('data/trade_facts.csv')


df_merged_result = df_issuers.merge(df_forge_price, on='ISSUER_SLUG', how='left') \
            .merge(df_funding_rounds, on='ISSUER_SLUG', how='left') \
            .merge(df_trade_facts, on='ISSUER_SLUG', how='left')
# df_merged_result.to_csv('data/merged_result.csv', index=False)
df_merged_result = df_merged_result.rename(columns={'ISSUER_SLUG': 'slug'})

# join df_not_matched with df_merged_result on left join where df_not_matched.slug = df_merged_result.ISSUER_SLUG 
df_joined_unmatched_merged_result = df_not_matched.merge(df_merged_result, how='left')

print(df_joined_unmatched_merged_result.head())

df_joined_unmatched_merged_result.to_csv('data/joined_unmatched_merged_result.csv', index=False)

# %%
# Weight functions

from datetime import datetime

def weight_domicile_country_code(code):
    return 1 if code == 'US' else 0

def weight_domicile_state_code(code):
    return 1 if code == 'DE' else 0


funding_round_ranking = {
    'seed': 0,
    'series a': 1,
    'series b': 2,
    'series c': 3,
    'series d': 4,
    'series e': 5,
    'series f': 6,
    'series g': 7,
    'series h': 8,
    'series i': 9
}
def normalize_and_weight_series(series_types):  
    if pd.isna(series_types) or not series_types:  # Handle NaN or empty lists
        return 0  # Neutral weight for missing values or empty lists

    normalized_weights = []
    
    for series in series_types:
        series_lower = series.lower().strip()
        
        match = re.search(r'series [a-z]', series_lower)
        if match:
            normalized_type = match.group()
            weight = funding_round_ranking.get(normalized_type, 0)
            normalized_weights.append(weight)
        else:
            # Fallback for unrecognized series types (neutral)
            normalized_weights.append(0)  
    
    return max(normalized_weights)  # Return the highest weight in the list


def weight_recency(funding_dates_str):
    if pd.isna(funding_dates_str) or not funding_dates_str: # Handle NaN or empty lists
        return -99999  # Lowest weight for missing or empty values
    
    funding_dates_clean = re.findall(r'\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2}\.\d{3}', funding_dates_str)
    funding_dates = [datetime.strptime(date, '%Y-%m-%d %H:%M:%S.%f') for date in funding_dates_clean]
    most_recent_date = max(funding_dates)
    now = datetime.now()
    recency_weight = (now - most_recent_date).days
    return -recency_weight  # More recent = higher weight (less days, more weight)


def weight_price_source(price_source):
    if pd.isna(price_source):  # Handle NaN or missing values
        return -0.1  # Assign negative weight to missing values
    price_source_lower = price_source.lower().strip()
    
    if re.search(r'vwap', price_source_lower):
        return 1  
    elif re.search(r'iois', price_source_lower):
        return 0.5  
    elif re.search(r'primary', price_source_lower):
        return 0.2  
    else:
        return -0.1  # Negative weight for other or unrecognized types

def weight_price_issuer_tier(tier):
    if pd.isna(tier):  # Handle NaN or missing values
        return 0  # Neutral weight for missing
    tier_lower = tier.lower().strip()
    if tier_lower == 'tier_1':
        return 1  # Highest weight for TIER_1
    else:
        return 0.5  # Neutral or medium weight for other tiers


def weight_price(price):
    if pd.isna(price):  # Handle NaN or missing values
        return 0  # Neutral weight for missing values
    return price  # Higher value means higher weight

def weight_implied_valuation(valuation):
    if pd.isna(valuation):  # Handle NaN or missing values
        return 0  # Neutral weight for missing values
    return valuation  # Higher value means higher weight

#create weight functions for HAS_IOIS, if true less weight, if false more weight
def weight_has_iois(has_iois):
    return 0 if has_iois else 1

# create weight functions for NUM_TRADES, if more trades, higher weight
def weight_num_trades(num_trades):
    return num_trades if num_trades else 0

# create weight functions for LAST_CLOSED_TRADE_DATE, if more recent, higher weight
def weight_last_closed_trade_date(last_closed_trade_date):
    if pd.isna(last_closed_trade_date) or not last_closed_trade_date:  # Handle NaN or missing values
        return -99999  # Lowest weight for missing values
    last_closed_trade_date = datetime.strptime(last_closed_trade_date, '%m/%d/%y')
    now = datetime.now()
    recency_weight = (now - last_closed_trade_date).days
    return -recency_weight  # More recent = higher weight (less days, more weight)

# create weight functions for LAST_PENDING_TRADE_DATE, if more recent, higher weight
def weight_last_pending_trade_date(last_pending_trade_date):
    if pd.isna(last_pending_trade_date) or not last_pending_trade_date:  # Handle NaN or missing values
        return -99999  # Lowest weight for missing values
    last_pending_trade_date = datetime.strptime(last_pending_trade_date, '%m/%d/%y')
    now = datetime.now()
    recency_weight = (now - last_pending_trade_date).days
    return -recency_weight  # More recent = higher weight (less days, more weight)

# create weight functions for ARCHIVEDAT, if present, lower weight
def weight_archived_at(archived_at):
    return 0 if pd.isna(archived_at) else 1


# output_columns += [
#     'YEARFOUNDED',
#     'CITY'
# ]

# %%
# words_to_find = df_mfm_mappings['nport_name']
# word_list = df_merged_result['slug']

df_words_to_find = pd.DataFrame(words_to_find, columns=['nport_issuer_name'])

# %%
# Normalize 'words_to_find_2' if necessary
words_to_find = df_mfm_mappings['nport_name']
word_list = df_merged_result['slug']
print(len(word_list), len(words_to_find))

words_to_find_2 = [normalize_name(str(word)) for word in words_to_find]
# Out:
# 5296 1000

# %%
# Process 'df_not_matched_2'
df_not_matched_2 = df_merged_result.copy()

# Combine text columns into 'combined_output'
output_columns = [
    'slug',
    'NAME',
    'LEGALENTITYNAME',
    'SEARCHALIASES',
    'DESCRIPTION',
    'STRUCTURED_DESCRIPTION',
    'LIFECYCLESTATUS',
    'BANNERMESSAGE',	
    'SUB_SECTOR',
    'SECTOR',
    'WEBSITE',
    'CRUNCHBASEURL'
]

def combine_output_columns(row):
    texts = []
    for col in output_columns:
        if col in row and pd.notnull(row[col]):
            texts.append(clean_text(str(row[col])))
    combined_text = ' '.join(texts)
    return combined_text

df_not_matched_2['combined_output'] = df_not_matched_2.apply(combine_output_columns, axis=1)
word_list = df_not_matched_2['combined_output'].tolist()

# Initialize the model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Compute embeddings
embeddings_to_find = model.encode(words_to_find_2, convert_to_numpy=True, normalize_embeddings=True)
embeddings_list = model.encode(word_list, convert_to_numpy=True, normalize_embeddings=True)

# Apply the weight functions to 'df_not_matched_2'
df_not_matched_2['DOMICILECOUNTRYCODE_WEIGHT'] = df_not_matched_2['DOMICILECOUNTRYCODE'].apply(weight_domicile_country_code)
df_not_matched_2['DOMICILESTATECODE_WEIGHT'] = df_not_matched_2['DOMICILESTATECODE'].apply(weight_domicile_state_code)
df_not_matched_2['SHARE_TYPE_WEIGHT'] = df_not_matched_2['ARRAY_AGG(FR.SHARE_TYPE)'].apply(normalize_and_weight_series)
df_not_matched_2['FUNDING_DATE_WEIGHT'] = df_not_matched_2['ARRAY_AGG(FUNDING_DATE)'].apply(weight_recency)
df_not_matched_2['FORGE_PRICE_SOURCE_WEIGHT'] = df_not_matched_2['FORGE_PRICE_SOURCE_EXTERNAL'].apply(weight_price_source)
df_not_matched_2['FORGE_PRICE_ISSUER_TIER_WEIGHT'] = df_not_matched_2['FORGE_PRICE_ISSUER_TIER'].apply(weight_price_issuer_tier)
df_not_matched_2['FORGE_PRICE_WEIGHT'] = df_not_matched_2['FORGE_PRICE'].apply(weight_price)
df_not_matched_2['FORGE_IMPLIED_VALUATION_WEIGHT'] = df_not_matched_2['FORGE_IMPLIED_VALUATION'].apply(weight_implied_valuation)
df_not_matched_2['HAS_IOIS_WEIGHT'] = df_not_matched_2['HAS_IOIS'].apply(weight_has_iois)
df_not_matched_2['NUM_TRADES_WEIGHT'] = df_not_matched_2['NUM_TRADES'].apply(weight_num_trades)
df_not_matched_2['LAST_CLOSED_TRADE_DATE_WEIGHT'] = df_not_matched_2['LAST_CLOSED_TRADE_DATE'].apply(weight_last_closed_trade_date)
df_not_matched_2['LAST_PENDING_TRADE_DATE_WEIGHT'] = df_not_matched_2['LAST_PENDING_TRADE_DATE'].apply(weight_last_pending_trade_date)

# Select and normalize the weighted features
weighted_feature_columns = [
    'DOMICILECOUNTRYCODE_WEIGHT',
    'DOMICILESTATECODE_WEIGHT',
    'SHARE_TYPE_WEIGHT',
    'FUNDING_DATE_WEIGHT',
    'FORGE_PRICE_SOURCE_WEIGHT',
    'FORGE_PRICE_ISSUER_TIER_WEIGHT',
    'FORGE_PRICE_WEIGHT',
    'FORGE_IMPLIED_VALUATION_WEIGHT',
    'HAS_IOIS_WEIGHT',
    'NUM_TRADES_WEIGHT',
    'LAST_CLOSED_TRADE_DATE_WEIGHT',
    'LAST_PENDING_TRADE_DATE_WEIGHT'
]

# Fill NaN values with zeros
df_not_matched_2[weighted_feature_columns] = df_not_matched_2[weighted_feature_columns].fillna(0.0)

# Ensure the data types are numeric
df_not_matched_2[weighted_feature_columns] = df_not_matched_2[weighted_feature_columns].apply(pd.to_numeric, errors='coerce')

# Replace any remaining NaNs with zeros
df_not_matched_2[weighted_feature_columns] = df_not_matched_2[weighted_feature_columns].fillna(0.0)

# Normalize the weighted features
scaler = MinMaxScaler()
weighted_features = scaler.fit_transform(df_not_matched_2[weighted_feature_columns])

# Compute a single weighted score per candidate
weighted_scores = weighted_features.sum(axis=1)  # Sum across features
weighted_scores = weighted_scores.reshape(-1, 1)  # Shape (number_of_candidates, 1)

# Compute cosine similarity matrix
cosine_sim_matrix = cosine_similarity(embeddings_to_find, embeddings_list)

# Adjust the cosine similarity scores using weighted scores
beta = 1.0  
adjusted_cosine_sim_matrix = cosine_sim_matrix * (1 + beta * weighted_scores.T)

# Find top matches for each word in 'words_to_find_2'
results_data = []

for idx, (word, scores) in enumerate(zip(words_to_find_2, adjusted_cosine_sim_matrix)):
    current_npot_issuer_name = words_to_find[idx]

    # Get indices sorted by score in descending order
    top_indices = scores.argsort()[::-1]
    matches = []
    seen_slugs = set()
    for index in top_indices:
        matched_row = df_not_matched_2.iloc[index]
        match_slug = matched_row.get('slug', '')
        match_score = scores[index]
        if match_slug not in seen_slugs:
            seen_slugs.add(match_slug)
            # Append the tuple (match_slug, score)
            matches.append((match_slug, match_score))
        # Stop if we have collected 5 matches
        if len(matches) >= 5:
            break
    # Prepare the result for this word
    nport_name = word
    if matches:
        first_matched_company = matches[0][0]  # First match's slug
    else:
        first_matched_company = ''
    # Format matches as list of tuples (match_slug, score)
    matches_formatted = [f"({slug}, {score:.4f})" for slug, score in matches]
    all_matches_str = ', '.join(matches_formatted)
    results_data.append({
        'nport_name': current_npot_issuer_name,
        'first_matched_company': first_matched_company,
        'all_matches': all_matches_str
    })

df_results = pd.DataFrame(results_data)

# Save the results to a CSV file
df_results.to_csv('embedding_matched.csv', index=False)

# %% [markdown]
# Additional weights for input text

# %%
words_to_find = df_mfm_mappings['nport_name']
word_list = df_merged_result['slug']
print(len(word_list), len(words_to_find))

words_to_find_3 = [normalize_name(str(word)) for word in words_to_find]
# Out:
# 5296 1000

# %%
df_not_matched_3 = df_merged_result.copy()

output_columns = [
    'slug',
    'NAME',
    'LEGALENTITYNAME',
    'SEARCHALIASES',
    'DESCRIPTION',
    'STRUCTURED_DESCRIPTION',
    'LIFECYCLESTATUS',
    'BANNERMESSAGE',
    'SUB_SECTOR',
    'SECTOR',
    'WEBSITE',
    'CRUNCHBASEURL'
]

# Define weights for each output column
column_weights = {
    'slug': 1.0,
    'NAME': 2.0,
    'LEGALENTITYNAME': 2.0,
    'WEBSITE': 1.5,
    'SEARCHALIASES': 1.5,
    'DESCRIPTION': 1.0,
    'STRUCTURED_DESCRIPTION': 1.0,
    'LIFECYCLESTATUS': 1.0,
    'BANNERMESSAGE': 1.0,
    'SUB_SECTOR': 1.0,
    'SECTOR': 1.0,
    'CRUNCHBASEURL': 1.0
}

# Clean and store text for each output column
for col in output_columns:
    if col in df_not_matched_3.columns:
        df_not_matched_3[col + '_clean'] = df_not_matched_3[col].apply(
            lambda x: clean_text(x) if pd.notnull(x) else ''
        )

    else:
        df_not_matched_3[col + '_clean'] = ''


# Load the model
model = SentenceTransformer('all-MiniLM-L6-v2')
embeddings_to_find_3 = model.encode(words_to_find_3, convert_to_numpy=True, normalize_embeddings=True)
weighted_embeddings_list_3 = []

for idx, row in df_not_matched_3.iterrows():
    combined_embedding = np.zeros(model.get_sentence_embedding_dimension())
    total_weight = 0.0

    for col in output_columns:
        col_clean = col + '_clean'
        text = row[col_clean]
        weight = column_weights.get(col, 1.0)
        if text:
            embedding = model.encode([text], convert_to_numpy=True, normalize_embeddings=True)[0]
            combined_embedding += weight * embedding
            total_weight += weight

    if total_weight > 0:
        combined_embedding /= total_weight  # Normalize by total weight
    weighted_embeddings_list_3.append(combined_embedding)

embeddings_list_3 = np.array(weighted_embeddings_list_3)

# Now, proceed to include weighted features as before
# Apply the weight functions to the DataFrame
df_not_matched_3['DOMICILECOUNTRYCODE_WEIGHT'] = df_not_matched_3['DOMICILECOUNTRYCODE'].apply(weight_domicile_country_code)
df_not_matched_3['DOMICILESTATECODE_WEIGHT'] = df_not_matched_3['DOMICILESTATECODE'].apply(weight_domicile_state_code)
df_not_matched_3['SHARE_TYPE_WEIGHT'] = df_not_matched_3['ARRAY_AGG(FR.SHARE_TYPE)'].apply(normalize_and_weight_series)
df_not_matched_3['FUNDING_DATE_WEIGHT'] = df_not_matched_3['ARRAY_AGG(FUNDING_DATE)'].apply(weight_recency)
df_not_matched_3['FORGE_PRICE_SOURCE_WEIGHT'] = df_not_matched_3['FORGE_PRICE_SOURCE_EXTERNAL'].apply(weight_price_source)
df_not_matched_3['FORGE_PRICE_ISSUER_TIER_WEIGHT'] = df_not_matched_3['FORGE_PRICE_ISSUER_TIER'].apply(weight_price_issuer_tier)
df_not_matched_3['FORGE_PRICE_WEIGHT'] = df_not_matched_3['FORGE_PRICE'].apply(weight_price)
df_not_matched_3['FORGE_IMPLIED_VALUATION_WEIGHT'] = df_not_matched_3['FORGE_IMPLIED_VALUATION'].apply(weight_implied_valuation)
df_not_matched_3['HAS_IOIS_WEIGHT'] = df_not_matched_3['HAS_IOIS'].apply(weight_has_iois)
df_not_matched_3['NUM_TRADES_WEIGHT'] = df_not_matched_3['NUM_TRADES'].apply(weight_num_trades)
df_not_matched_3['LAST_CLOSED_TRADE_DATE_WEIGHT'] = df_not_matched_3['LAST_CLOSED_TRADE_DATE'].apply(weight_last_closed_trade_date)
df_not_matched_3['LAST_PENDING_TRADE_DATE_WEIGHT'] = df_not_matched_3['LAST_PENDING_TRADE_DATE'].apply(weight_last_pending_trade_date)

# Select and normalize the weighted features
weighted_feature_columns = [
    'DOMICILECOUNTRYCODE_WEIGHT',
    'DOMICILESTATECODE_WEIGHT',
    'SHARE_TYPE_WEIGHT',
    'FUNDING_DATE_WEIGHT',
    'FORGE_PRICE_SOURCE_WEIGHT',
    'FORGE_PRICE_ISSUER_TIER_WEIGHT',
    'FORGE_PRICE_WEIGHT',
    'FORGE_IMPLIED_VALUATION_WEIGHT',
    'HAS_IOIS_WEIGHT',
    'NUM_TRADES_WEIGHT',
    'LAST_CLOSED_TRADE_DATE_WEIGHT',
    'LAST_PENDING_TRADE_DATE_WEIGHT'
]

# Fill NaN values with zeros
df_not_matched_3[weighted_feature_columns] = df_not_matched_3[weighted_feature_columns].fillna(0.0)

# Ensure the data types are numeric
df_not_matched_3[weighted_feature_columns] = df_not_matched_3[weighted_feature_columns].apply(pd.to_numeric, errors='coerce')

# Replace any remaining NaNs with zeros
df_not_matched_3[weighted_feature_columns] = df_not_matched_3[weighted_feature_columns].fillna(0.0)


# Normalize the weighted features
scaler = MinMaxScaler()
weighted_features = scaler.fit_transform(df_not_matched_3[weighted_feature_columns])

# # Combine embeddings with weighted features
# combined_embeddings_to_find_3 = np.hstack((embeddings_to_find_3, weighted_features))
# combined_embeddings_list_3 = np.hstack((embeddings_list_3, weighted_features))

# # Compute cosine similarity matrix
# cosine_sim_matrix_3 = cosine_similarity(combined_embeddings_to_find_3, combined_embeddings_list_3)

# Compute a single weighted score per candidate
weighted_scores = weighted_features.sum(axis=1)  # Sum across features
weighted_scores = weighted_scores.reshape(-1, 1)  # Shape (number_of_candidates, 1)

# Compute cosine similarity matrix
cosine_sim_matrix = cosine_similarity(embeddings_to_find_3, embeddings_list_3)

# Adjust the cosine similarity scores using weighted scores
beta = 1.0  
adjusted_cosine_sim_matrix = cosine_sim_matrix * (1 + beta * weighted_scores.T)

results_data = []

for idx, (word, scores) in enumerate(zip(words_to_find_3, adjusted_cosine_sim_matrix)):
    current_npot_issuer_name = words_to_find[idx]

    # Get indices sorted by score in descending order
    top_indices = scores.argsort()[::-1]
    matches = []
    seen_slugs = set()
    for index in top_indices:
        matched_row = df_not_matched_2.iloc[index]
        match_slug = matched_row.get('slug', '')
        match_score = scores[index]
        if match_slug not in seen_slugs:
            seen_slugs.add(match_slug)
            # Append the tuple (match_slug, score)
            matches.append((match_slug, match_score))
        # Stop if we have collected 5 matches
        if len(matches) >= 5:
            break
    # Prepare the result for this word
    nport_name = word
    if matches:
        first_matched_company = matches[0][0]  # First match's slug
    else:
        first_matched_company = ''
    # Format matches as list of tuples (match_slug, score)
    matches_formatted = [f"({slug}, {score:.4f})" for slug, score in matches]
    all_matches_str = ', '.join(matches_formatted)
    results_data.append({
        'nport_name': current_npot_issuer_name,
        'first_matched_company': first_matched_company,
        'all_matches': all_matches_str
    })

df_results = pd.DataFrame(results_data)

# Save the results to a CSV file
df_results.to_csv('weighted_embedding_matched.csv', index=False)

# %%
partial_matched_results_df = pd.DataFrame(partial_matched_results)
partial_matched_results_df['method'] = 'embedding_matched'

partial_matched_results_df.to_csv('data/_test.csv', index=False)

# %%
exact_matxches_results_df = pd.DataFrame(exact_matches)
exact_matxches_results_df.to_csv('data/_test_exact.csv', index=False)
