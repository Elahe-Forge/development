# %%
import pandas as pd
import string
from nltk.corpus import stopwords
from fuzzywuzzy import fuzz, process
import re
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics.pairwise import cosine_similarity
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
df_mfm_mappings = pd.read_csv('issuer-mfm-mappings.csv')

# %%
stop_words_normalized = [
        "healthcare",
        "technologies",
        "therapeutics",
        "financial",
        "software",
        "holdings",
        "transportation",
        "pharmaceuticals",
        "capital",
        "copper",
        "communications",
        "biotechnology",
        "biopharmaceuticals",
        "group",
        "technology",
        "media",
        "energy",
        "industries",
        "biotherapeutics",
        "solution",
        "bioscience",
        "industries",
        "corporation",
        "systems",
        "enterprises",
        "robotics",
        "bank",
        "inc",
        "llc",
        "pp",
        "series a",
        "series seed",
        "series b",
        "series c",
        "series d",
        "series e",
        "series f",
        "series g",
        "series h",
        "series i"
    ]

def normalize_name(name):
    name = name.lower() 
    for word in stop_words_normalized:
        name = name.replace(word, '')
    return name.strip()


stop_words = set(stopwords.words('english'))
def remove_stop_words(sentence):
    words = sentence.split()
    filtered_sentence = [w for w in words if not w.lower() in stop_words]
    return ' '.join(filtered_sentence)


def remove_punctuation(sentence):
    return sentence.translate(str.maketrans('', '', string.punctuation))


def clean_text(word_to_find):
    word_to_find_normalzed = normalize_name(word_to_find)

    word_to_find_no_stop_word = remove_stop_words(word_to_find_normalzed)

    word_to_find_no_punc = remove_punctuation(word_to_find_no_stop_word)

    return word_to_find_no_punc

# %%
words_to_find = df_mfm_mappings.apply(lambda row: row['nport_issuer_name'] if pd.notna(row['nport_issuer_name']) else row['nport_security_name'], axis=1)
word_list = df_mfm_mappings['slug']

# %%
def match_company(name, master_list, top_n=5):
    name = normalize_name(name)
    
    # Extract the top N matches along with their scores
    ranked_matches = process.extract(name, master_list, scorer=fuzz.token_set_ratio, limit=top_n)
    return ranked_matches if ranked_matches else []

matched_companies = [match_company(c, word_list) for c in words_to_find]

# %%
matched_companies_full_record = [(c, word_to_find) for c, word_to_find in zip(matched_companies, words_to_find)]

# %%
x = zip(matched_companies_full_record, word_list)
f = list(x)[1]
f[0][1]
for ranked_match_list, expected in zip(matched_companies_full_record, word_list):
    print(ranked_match_list[1], ranked_match_list[0], expected)
# Out:
# Arcellx, Inc.,, [('arcellx', 100, 0), ('arcellx', 100, 242), ('arcellx', 100, 243), ('arcellx', 100, 244), ('arcellx', 100, 245)] arcellx
# BOMBAS LLC [('bombas', 100, 1), ('compass', 62, 716), ('compass', 62, 717), ('compass', 62, 718), ('compass', 62, 719)] bombas
# Bright Health Group, Inc. [('bright-health', 100, 2), ('bright-health', 100, 449), ('bright-health', 100, 450), ('bright-health', 100, 451), ('bright-health', 100, 452)] bright-health
# Think & Learn Private Ltd. [('clear-street', 46, 659), ('clear-street', 46, 660), ('clear-street', 46, 661), ('lanzatech', 44, 1587), ('lanzatech', 44, 1588)] byju-s
# C3Ai Inc [('c3-iot', 60, 4), ('c3-iot', 60, 480), ('c3-iot', 60, 481), ('c3-iot', 60, 482), ('care', 50, 533)] c3-iot
# CARESYNTAX INC C3 [('caresyntax', 100, 5), ('caresyntax', 100, 539), ('caresyntax', 100, 540), ('caresyntax', 100, 541), ('c3-iot', 50, 4)] caresyntax
# Carmot Therapeutics, Inc. [('carmot-therapeutics', 100, 6), ('clearmotion', 71, 662), ('clearmotion', 71, 663), ('clearmotion', 71, 664), ('clearmotion', 71, 665)] carmot-therapeutics
# Centrexion Therapeutics,,,, [('centrexion-therapeutics', 100, 7), ('centrexion-therapeutics', 100, 596), ('centrexion-therapeutics', 100, 597), ('centrexion-therapeutics', 100, 598), ('centrexion-therapeutics', 100, 599)] centrexion-therapeutics
# Cepton Inc [('cepton-technologies', 100, 8), ('cepton-technologies', 100, 9), ('cepton-technologies', 100, 601), ('cepton-technologies', 100, 602), ('celonis', 62, 583)] cepton-technologies
# Cepton, Inc. [('cepton-technologies', 100, 8), ('cepton-technologies', 100, 9), ('cepton-technologies', 100, 601), ('cepton-technologies', 100, 602), ('celonis', 62, 583)] cepton-technologies
# Checkmate Pharmaceuticals, Inc.,, [('checkmate-pharmaceuticals', 100, 10), ('checkmate-pharmaceuticals', 100, 611), ('checkmate-pharmaceuticals', 100, 612), ('checkmate-pharmaceuticals', 100, 613), ('checkmate-pharmaceuticals', 100, 614)] checkmate-pharmaceuticals
# Clarus Corporation [('clarus-therapeutics', 100, 11), ('clarus-therapeutics', 100, 655), ('clarus-therapeutics', 100, 656), ('cruise', 67, 796), ('cruise', 67, 797)] clarus-therapeutics
# Couchbase, Inc. [('couchbase', 100, 12), ('couchbase', 100, 753), ('couchbase', 100, 754), ('coinbase', 71, 700), ('coinbase', 71, 701)] couchbase
# DATABRICKS INC PP,,, [('databricks', 100, 13), ('databricks', 100, 825), ('databricks', 100, 826), ('databricks', 100, 827), ('databricks', 100, 828)] databricks
# DOOR DASH [('honor', 57, 1411), ('honor', 57, 1412), ('honor', 57, 1413), ('honor', 57, 1414), ('honor', 57, 1415)] doordash
# Entrada Therapeutics, Inc. [('entrada-therapeutics', 100, 15), ('entrada-therapeutics', 100, 1053), ('entrada-therapeutics', 100, 1054), ('entrada-therapeutics', 100, 1055), ('erasca', 62, 1074)] entrada-therapeutics
# EVOZYNE LLC [('evozyne', 100, 16), ('bluevoyant', 59, 414), ('evernote', 53, 1090), ('evernote', 53, 1091), ('evernote', 53, 1092)] evozyne
# GENESIS THERAPEUTICS INC [('genesis-therapeutics', 100, 17), ('gelesis', 86, 1233), ('gelesis', 86, 1234), ('genapsys', 67, 1236), ('genapsys', 67, 1237)] genesis-therapeutics
# GINGKO BIOWORKS HOLDINGS [('ginkgo-bioworks', 93, 18), ('ginkgo-bioworks', 93, 1252), ('ginkgo-bioworks', 93, 1253), ('ginkgo-bioworks', 93, 1254), ('ginkgo-bioworks', 93, 1255)] ginkgo-bioworks
# Intarcia Therapeutics, Inc. [('intarcia-therapeutics', 100, 19), ('intarcia-therapeutics', 100, 1504), ('intarcia-therapeutics', 100, 1505), ('inrix', 62, 1468), ('inrix', 62, 1469)] intarcia-therapeutics
# KARTOS THERAPEUTICS INC [('kartos-therapeutics', 100, 20), ('kareo', 73, 1549), ('kareo', 73, 1550), ('kareo', 73, 1551), ('kareo', 73, 1552)] kartos-therapeutics
# LENDINGCLUB CORPORATION [('lendingclub', 100, 21), ('blend-labs', 57, 392), ('blend-labs', 57, 393), ('blend-labs', 57, 394), ('blend-labs', 57, 395)] lendingclub
# LINE Corporation [('line-corporation', 100, 22), ('lime', 75, 1624), ('lime', 75, 1625), ('lime', 75, 1626), ('lime', 75, 1627)] line-corporation
# MAGIC LEAP,,, [('magic-leap', 100, 23), ('magic-leap', 100, 1666), ('magic-leap', 100, 1667), ('magic-leap', 100, 1668), ('magic-leap', 100, 1669)] magic-leap
# NEOGEN CORPORATION [('neurogene', 80, 1812), ('neurogene', 80, 1813), ('neurogene', 80, 1814), ('heliogen', 71, 1401), ('heliogen', 71, 1402)] neogene-therapeutics
# ORIC PHARMACEUTICALS INC [('oric-pharmaceuticals', 100, 25), ('oric-pharmaceuticals', 100, 26), ('oric-pharmaceuticals', 100, 1942), ('oric-pharmaceuticals', 100, 1943), ('oric-pharmaceuticals', 100, 1944)] oric-pharmaceuticals
# ORIC Pharmaceuticals, Inc. [('oric-pharmaceuticals', 100, 25), ('oric-pharmaceuticals', 100, 26), ('oric-pharmaceuticals', 100, 1942), ('oric-pharmaceuticals', 100, 1943), ('oric-pharmaceuticals', 100, 1944)] oric-pharmaceuticals
# Phathom Pharmaceuticals Inc [('phantom', 86, 27), ('phantom', 86, 28), ('phantom', 86, 29), ('omada-health', 63, 1908), ('omada-health', 63, 1909)] phantom
# Phathom Pharmaceuticals Inc. [('phantom', 86, 27), ('phantom', 86, 28), ('phantom', 86, 29), ('omada-health', 63, 1908), ('omada-health', 63, 1909)] phantom
# Phathom Pharmaceuticals, Inc. [('phantom', 86, 27), ('phantom', 86, 28), ('phantom', 86, 29), ('omada-health', 63, 1908), ('omada-health', 63, 1909)] phantom
# PMV Pharmaceuticals, Inc. [('pmv-pharma', 100, 30), ('pmv-pharma', 100, 31), ('pmv-pharma', 100, 2086), ('asimov', 44, 262), ('phantom', 40, 27)] pmv-pharma
# PMV Pharmaceuticals Inc. [('pmv-pharma', 100, 30), ('pmv-pharma', 100, 31), ('pmv-pharma', 100, 2086), ('asimov', 44, 262), ('phantom', 40, 27)] pmv-pharma
# PYXIS ONCOLOGY, INC. [('pyxis-oncology', 100, 32), ('pyxis-oncology', 100, 2150), ('pyxis-oncology', 100, 2151), ('nautilus-biotechnology', 56, 1792), ('nautilus-biotechnology', 56, 1793)] pyxis-oncology
# RAPPORT THERAPEUTICS INC [('rover', 60, 2323), ('rover', 60, 2324), ('rover', 60, 2325), ('rover', 60, 2326), ('rover', 60, 2327)] rapport-therapeutics
# Recursion Pharmaceuticals, Inc. [('recursion-pharmaceuticals', 100, 34), ('recursion-pharmaceuticals', 100, 2196), ('recursion-pharmaceuticals', 100, 2197), ('recursion-pharmaceuticals', 100, 2198), ('recursion-pharmaceuticals', 100, 2199)] recursion-pharmaceuticals
# SERVICETITAN INC PP,,, [('servicetitan', 100, 35), ('servicetitan', 100, 2403), ('servicetitan', 100, 2404), ('servicetitan', 100, 2405), ('servicetitan', 100, 2406)] servicetitan
# Tenable Holdings Inc [('tenable-network-security', 100, 36), ('tenable-network-security', 100, 37), ('tenable-network-security', 100, 38), ('airtable', 67, 145), ('airtable', 67, 146)] tenable-network-security
# Tenable Holdings Inc. [('tenable-network-security', 100, 36), ('tenable-network-security', 100, 37), ('tenable-network-security', 100, 38), ('airtable', 67, 145), ('airtable', 67, 146)] tenable-network-security
# TENABLE HOLDINGS, INC. [('tenable-network-security', 100, 36), ('tenable-network-security', 100, 37), ('tenable-network-security', 100, 38), ('airtable', 67, 145), ('airtable', 67, 146)] tenable-network-security
# Honest Company Inc [('the-honest-company-inc', 100, 39), ('the-honest-company', 100, 2738), ('the-honest-company', 100, 2739), ('the-honest-company', 100, 2740), ('the-honest-company', 100, 2741)] the-honest-company-inc
# Theseus Pharmaceuticals, Inc. [('theseus-pharmaceuticals', 100, 40), ('theseus-pharmaceuticals', 100, 2751), ('theseus-pharmaceuticals', 100, 2752), ('tempus', 62, 2700), ('tempus', 62, 2701)] theseus-pharmaceuticals
# TriSalus Life Sciences, Inc.,, [('trisalus-life-sciences', 100, 41), ('trisalus-life-sciences', 100, 2792), ('caris-life-sciences', 83, 546), ('caris-life-sciences', 83, 547), ('caris-life-sciences', 83, 548)] trisalus-life-sciences
# Udemy, Inc. [('udemy', 100, 42), ('udemy', 100, 2831), ('udemy', 100, 2832), ('udemy', 100, 2833), ('udemy', 100, 2834)] udemy
# Verge Genomics [('verge-genomics', 100, 43), ('10x-genomics-inc', 73, 48), ('10x-genomics-inc', 73, 49), ('10x-genomics-inc', 73, 50), ('bluestar-genomics', 73, 413)] verge-genomics
# VERILY LIFE SCIENCES LLC [('verily-life-sciences', 100, 44), ('caris-life-sciences', 82, 546), ('caris-life-sciences', 82, 547), ('caris-life-sciences', 82, 548), ('caris-life-sciences', 82, 549)] verily-life-sciences
# JAND INC [('xad', 57, 3001), ('23andme', 55, 59), ('23andme', 55, 60), ('23andme', 55, 61), ('23andme', 55, 62)] warby-parker
# Zuora, Inc. [('zuora', 100, 46), ('zuora', 100, 47), ('zuora', 100, 3095), ('zuora', 100, 3096), ('zuora', 100, 3097)] zuora
# Zuora Inc [('zuora', 100, 46), ('zuora', 100, 47), ('zuora', 100, 3095), ('zuora', 100, 3096), ('zuora', 100, 3097)] zuora
# 10X GENOMICS INC [('10x-genomics-inc', 100, 48), ('10x-genomics-inc', 100, 49), ('10x-genomics-inc', 100, 50), ('verge-genomics', 80, 43), ('bluestar-genomics', 80, 413)] 10x-genomics-inc
# 10X Genomics, Inc. [('10x-genomics-inc', 100, 48), ('10x-genomics-inc', 100, 49), ('10x-genomics-inc', 100, 50), ('verge-genomics', 80, 43), ('bluestar-genomics', 80, 413)] 10x-genomics-inc
# 10x Genomics Inc. [('10x-genomics-inc', 100, 48), ('10x-genomics-inc', 100, 49), ('10x-genomics-inc', 100, 50), ('verge-genomics', 80, 43), ('bluestar-genomics', 80, 413)] 10x-genomics-inc
# 1life Healthcare Inc [('1life-healthcare', 100, 51), ('1life-healthcare', 100, 52), ('1life-healthcare', 100, 53), ('1life-healthcare', 100, 54), ('1life-healthcare', 100, 55)] 1life-healthcare
# Life Healthcare Group Holdings Ltd [('trisalus-life-sciences', 67, 41), ('verily-life-sciences', 67, 44), ('caris-life-sciences', 67, 546), ('caris-life-sciences', 67, 547), ('caris-life-sciences', 67, 548)] 1life-healthcare
# 1Life Healthcare, Inc. [('1life-healthcare', 100, 51), ('1life-healthcare', 100, 52), ('1life-healthcare', 100, 53), ('1life-healthcare', 100, 54), ('1life-healthcare', 100, 55)] 1life-healthcare
# 1Life Healthcare Inc. [('1life-healthcare', 100, 51), ('1life-healthcare', 100, 52), ('1life-healthcare', 100, 53), ('1life-healthcare', 100, 54), ('1life-healthcare', 100, 55)] 1life-healthcare
# 1LIFE HEALTHCARE, INC [('1life-healthcare', 100, 51), ('1life-healthcare', 100, 52), ('1life-healthcare', 100, 53), ('1life-healthcare', 100, 54), ('1life-healthcare', 100, 55)] 1life-healthcare
# 1stdibs.com Inc [('1stdibs', 100, 56), ('1stdibs', 100, 57), ('1stdibs', 100, 58), ('disco', 62, 923), ('disco', 62, 924)] 1stdibs
# 1stdibs.com Inc. [('1stdibs', 100, 56), ('1stdibs', 100, 57), ('1stdibs', 100, 58), ('disco', 62, 923), ('disco', 62, 924)] 1stdibs
# 1stdibs.com, Inc. [('1stdibs', 100, 56), ('1stdibs', 100, 57), ('1stdibs', 100, 58), ('disco', 62, 923), ('disco', 62, 924)] 1stdibs
# 23andMe Holding Co. [('23andme', 100, 59), ('23andme', 100, 60), ('23andme', 100, 61), ('23andme', 100, 62), ('23andme', 100, 63)] 23andme
# 23ANDME INC [('23andme', 100, 59), ('23andme', 100, 60), ('23andme', 100, 61), ('23andme', 100, 62), ('23andme', 100, 63)] 23andme
# 23ANDME HOLDING CO [('23andme', 100, 59), ('23andme', 100, 60), ('23andme', 100, 61), ('23andme', 100, 62), ('23andme', 100, 63)] 23andme
# 23ANDME, Inc. COMMON COMMON SHARES   / [('23andme', 100, 59), ('23andme', 100, 60), ('23andme', 100, 61), ('23andme', 100, 62), ('23andme', 100, 63)] 23andme
# 23ANDME HOLDING CO. COMMON COMMON SHARES   / [('23andme', 100, 59), ('23andme', 100, 60), ('23andme', 100, 61), ('23andme', 100, 62), ('23andme', 100, 63)] 23andme
# 23ANDME HOLDING CO -CLASS A [('23andme', 100, 59), ('23andme', 100, 60), ('23andme', 100, 61), ('23andme', 100, 62), ('23andme', 100, 63)] 23andme
# 2U Inc [('2u', 100, 65), ('2u', 100, 66), ('2u', 100, 67), ('boku', 33, 415), ('boku', 33, 416)] 2u
# 2U, INC. [('2u', 100, 65), ('2u', 100, 66), ('2u', 100, 67), ('boku', 33, 415), ('boku', 33, 416)] 2u
# 2U Inc. [('2u', 100, 65), ('2u', 100, 66), ('2u', 100, 67), ('boku', 33, 415), ('boku', 33, 416)] 2u
# Nauticus Robotics, Inc. [('fanatics', 75, 1124), ('fanatics', 75, 1125), ('fanatics', 75, 1126), ('fanatics', 75, 1127), ('fanatics', 75, 1128)] 3d-robotics
# 4D MOLECULAR THERAPEUTICS INC [('4d-molecular-therapeutics-4dmt', 100, 69), ('4d-molecular-therapeutics-4dmt', 100, 70), ('4d-molecular-therapeutics-4dmt', 100, 71), ('4d-molecular-therapeutics-4dmt', 100, 72), ('molekule', 60, 1756)] 4d-molecular-therapeutics-4dmt
# 4D Molecular Therapeutics Inc. [('4d-molecular-therapeutics-4dmt', 100, 69), ('4d-molecular-therapeutics-4dmt', 100, 70), ('4d-molecular-therapeutics-4dmt', 100, 71), ('4d-molecular-therapeutics-4dmt', 100, 72), ('molekule', 60, 1756)] 4d-molecular-therapeutics-4dmt
# 4D Molecular Therapeutics, Inc. [('4d-molecular-therapeutics-4dmt', 100, 69), ('4d-molecular-therapeutics-4dmt', 100, 70), ('4d-molecular-therapeutics-4dmt', 100, 71), ('4d-molecular-therapeutics-4dmt', 100, 72), ('molekule', 60, 1756)] 4d-molecular-therapeutics-4dmt
# 4D MOLECULAR THERAPEUTICS IN [('4d-molecular-therapeutics-4dmt', 89, 69), ('4d-molecular-therapeutics-4dmt', 89, 70), ('4d-molecular-therapeutics-4dmt', 89, 71), ('4d-molecular-therapeutics-4dmt', 89, 72), ('molekule', 52, 1756)] 4d-molecular-therapeutics-4dmt
# 8I ENTERPRIS ACQUISITI  RTS 12/31/49 [('8i', 100, 73), ('8i', 100, 74), ('8i', 100, 75), ('matterport', 36, 1700), ('matterport', 36, 1701)] 8i
# 8I ACQUISITION 2 CORP [('8i', 100, 73), ('8i', 100, 74), ('8i', 100, 75), ('brain-corp', 57, 435), ('brain-corp', 57, 436)] 8i
# 8I ENTERPRISES ACQUISITION C [('8i', 100, 73), ('8i', 100, 74), ('8i', 100, 75), ('lilac-solutions', 52, 1621), ('lilac-solutions', 52, 1622)] 8i
# 908 Devices, Inc. [('908-devices', 100, 76), ('908-devices', 100, 77), ('908-devices', 100, 78), ('epic-games', 48, 1060), ('epic-games', 48, 1061)] 908-devices
# 908 Devices Inc [('908-devices', 100, 76), ('908-devices', 100, 77), ('908-devices', 100, 78), ('epic-games', 48, 1060), ('epic-games', 48, 1061)] 908-devices
# 908 DEVICES INC. [('908-devices', 100, 76), ('908-devices', 100, 77), ('908-devices', 100, 78), ('epic-games', 48, 1060), ('epic-games', 48, 1061)] 908-devices
# A24 FILMS LLC PREFERRED UNITS [('a24-films', 100, 79), ('talaris-therapeutics', 44, 2664), ('talaris-therapeutics', 44, 2665), ('clarus-therapeutics', 41, 11), ('kartos-therapeutics', 41, 20)] a24-films
# ABL SPACABL SPACE SYSTEMS COE SYSTEMS [('abl-space-systems', 69, 80), ('abl-space-systems', 69, 81), ('abl-space-systems', 69, 82), ('abl-space-systems', 69, 83), ('abl-space-systems', 69, 84)] abl-space-systems
# ABL SPACE SYSTEMS SER B CVT PFD STOCK PP [('abl-space-systems', 69, 80), ('abl-space-systems', 69, 81), ('abl-space-systems', 69, 82), ('abl-space-systems', 69, 83), ('abl-space-systems', 69, 84)] abl-space-systems
# ABL SPACE SYSTEMS SER B CVT PFD STOCK PP,,,,, [('abl-space-systems', 69, 80), ('abl-space-systems', 69, 81), ('abl-space-systems', 69, 82), ('abl-space-systems', 69, 83), ('abl-space-systems', 69, 84)] abl-space-systems
# ABL SPACE SYSTEMS SER B-2 CVT PFD STK PP [('abl-space-systems', 69, 80), ('abl-space-systems', 69, 81), ('abl-space-systems', 69, 82), ('abl-space-systems', 69, 83), ('abl-space-systems', 69, 84)] abl-space-systems
# ABL SPACE SYSTEMS CO [('abl-space-systems', 86, 80), ('abl-space-systems', 86, 81), ('abl-space-systems', 86, 82), ('abl-space-systems', 86, 83), ('abl-space-systems', 86, 84)] abl-space-systems
# ABL SPACE SYSTEMS [('abl-space-systems', 100, 80), ('abl-space-systems', 100, 81), ('abl-space-systems', 100, 82), ('abl-space-systems', 100, 83), ('abl-space-systems', 100, 84)] abl-space-systems
# Abl Space Systems Ser B Cvt Pfd Pp [('abl-space-systems', 69, 80), ('abl-space-systems', 69, 81), ('abl-space-systems', 69, 82), ('abl-space-systems', 69, 83), ('abl-space-systems', 69, 84)] abl-space-systems
# Abl Space Systems Ser B Cvt [('abl-space-systems', 69, 80), ('abl-space-systems', 69, 81), ('abl-space-systems', 69, 82), ('abl-space-systems', 69, 83), ('abl-space-systems', 69, 84)] abl-space-systems
# ACCOLADE INC [('accolade', 100, 88), ('accolade', 100, 89), ('accolade', 100, 90), ('aledade', 67, 152), ('veracode', 62, 2888)] accolade
# Accolade, Inc. [('accolade', 100, 88), ('accolade', 100, 89), ('accolade', 100, 90), ('aledade', 67, 152), ('veracode', 62, 2888)] accolade
# Accolade Inc. [('accolade', 100, 88), ('accolade', 100, 89), ('accolade', 100, 90), ('aledade', 67, 152), ('veracode', 62, 2888)] accolade
# ACELYRIN INC [('acelyrin', 100, 91), ('acelyrin', 100, 92), ('acelyrin', 100, 93), ('cellink', 67, 578), ('cellink', 67, 579)] acelyrin
# ACELYRIN Inc. [('acelyrin', 100, 91), ('acelyrin', 100, 92), ('acelyrin', 100, 93), ('cellink', 67, 578), ('cellink', 67, 579)] acelyrin
# ACELYRIN, Inc. [('acelyrin', 100, 91), ('acelyrin', 100, 92), ('acelyrin', 100, 93), ('cellink', 67, 578), ('cellink', 67, 579)] acelyrin
# ACRONIS AG [('acronis', 100, 94), ('celonis', 59, 583), ('celonis', 59, 584), ('celonis', 59, 585), ('celonis', 59, 586)] acronis
# ACUTUS MEDICAL INC [('acutus-medical', 100, 95), ('acutus-medical', 100, 96), ('acutus-medical', 100, 97), ('acutus-medical', 100, 98), ('acutus-medical', 100, 99)] acutus-medical
# Natus Medical, Inc. [('acutus-medical', 89, 95), ('acutus-medical', 89, 96), ('acutus-medical', 89, 97), ('acutus-medical', 89, 98), ('acutus-medical', 89, 99)] acutus-medical
# Acutus Medical Inc. [('acutus-medical', 100, 95), ('acutus-medical', 100, 96), ('acutus-medical', 100, 97), ('acutus-medical', 100, 98), ('acutus-medical', 100, 99)] acutus-medical
# Acutus Medical, Inc. [('acutus-medical', 100, 95), ('acutus-medical', 100, 96), ('acutus-medical', 100, 97), ('acutus-medical', 100, 98), ('acutus-medical', 100, 99)] acutus-medical
# Natus Medical Inc [('acutus-medical', 89, 95), ('acutus-medical', 89, 96), ('acutus-medical', 89, 97), ('acutus-medical', 89, 98), ('acutus-medical', 89, 99)] acutus-medical
# ACV Auctions Inc [('acv-auctions', 100, 100), ('acv-auctions', 100, 101), ('acv-auctions', 100, 102), ('acv-auctions', 100, 103), ('acv-auctions', 100, 104)] acv-auctions
# ACV Auctions Inc. [('acv-auctions', 100, 100), ('acv-auctions', 100, 101), ('acv-auctions', 100, 102), ('acv-auctions', 100, 103), ('acv-auctions', 100, 104)] acv-auctions
# ACV Auctions, Inc. [('acv-auctions', 100, 100), ('acv-auctions', 100, 101), ('acv-auctions', 100, 102), ('acv-auctions', 100, 103), ('acv-auctions', 100, 104)] acv-auctions
# ACV AUCTIONS INC-A [('acv-auctions', 100, 100), ('acv-auctions', 100, 101), ('acv-auctions', 100, 102), ('acv-auctions', 100, 103), ('acv-auctions', 100, 104)] acv-auctions
# ACV Auctions Inc. Series E-1 Preferred Stock [('acv-auctions', 100, 100), ('acv-auctions', 100, 101), ('acv-auctions', 100, 102), ('acv-auctions', 100, 103), ('acv-auctions', 100, 104)] acv-auctions
# ACV Auctions Inc. Series A Preferred Stock [('acv-auctions', 100, 100), ('acv-auctions', 100, 101), ('acv-auctions', 100, 102), ('acv-auctions', 100, 103), ('acv-auctions', 100, 104)] acv-auctions
# ACV AUCTIONS INC A [('acv-auctions', 100, 100), ('acv-auctions', 100, 101), ('acv-auctions', 100, 102), ('acv-auctions', 100, 103), ('acv-auctions', 100, 104)] acv-auctions
# ADAPTIVE BIOTECHNOLOGIES CORP [('adaptive-biotechnologies', 68, 107), ('adaptive-biotechnologies', 68, 108), ('adaptive-biotechnologies', 68, 109), ('adaptive-biotechnologies', 68, 110), ('brain-corp', 57, 435)] adaptive-biotechnologies
# Adaptive Biotechnologies Corp. [('adaptive-biotechnologies', 68, 107), ('adaptive-biotechnologies', 68, 108), ('adaptive-biotechnologies', 68, 109), ('adaptive-biotechnologies', 68, 110), ('brain-corp', 57, 435)] adaptive-biotechnologies
# ADAPTIVE BIOTECHNOLOGIES [('adaptive-biotechnologies', 80, 107), ('adaptive-biotechnologies', 80, 108), ('adaptive-biotechnologies', 80, 109), ('adaptive-biotechnologies', 80, 110), ('adicet-bio', 64, 112)] adaptive-biotechnologies
# Adaptive Biotechnologies Corporation [('adaptive-biotechnologies', 80, 107), ('adaptive-biotechnologies', 80, 108), ('adaptive-biotechnologies', 80, 109), ('adaptive-biotechnologies', 80, 110), ('adicet-bio', 64, 112)] adaptive-biotechnologies
# ADC THERAPEUTICS SA [('adc-therapeutics', 67, 111), ('vacasa', 67, 2879), ('vacasa', 67, 2880), ('sima-ai', 62, 2446), ('asana', 55, 257)] adc-therapeutics
# Adicet Bio Inc [('adicet-bio', 100, 112), ('adicet-bio', 100, 113), ('adicet-bio', 100, 114), ('adicet-bio', 100, 115), ('goldfinch-bio', 61, 1298)] adicet-bio
# Adicet Bio, Inc. [('adicet-bio', 100, 112), ('adicet-bio', 100, 113), ('adicet-bio', 100, 114), ('adicet-bio', 100, 115), ('goldfinch-bio', 61, 1298)] adicet-bio
# Adicet Bio Inc. [('adicet-bio', 100, 112), ('adicet-bio', 100, 113), ('adicet-bio', 100, 114), ('adicet-bio', 100, 115), ('goldfinch-bio', 61, 1298)] adicet-bio
# ADICET BIO INC CVR [('adicet-bio', 100, 112), ('adicet-bio', 100, 113), ('adicet-bio', 100, 114), ('adicet-bio', 100, 115), ('beta-bionics', 54, 341)] adicet-bio
# NEXTROLL, INC. COMMON SHARES   / [('nextroll', 100, 1837), ('nextroll', 100, 1838), ('nextdoor-com', 53, 1826), ('nextdoor-com', 53, 1827), ('nextdoor-com', 53, 1828)] adroll
# NEXTROLL COMMON SHARES   / [('nextroll', 100, 1837), ('nextroll', 100, 1838), ('nextdoor-com', 53, 1826), ('nextdoor-com', 53, 1827), ('nextdoor-com', 53, 1828)] adroll
# Nextroll, Inc. Shares / [('nextroll', 100, 1837), ('nextroll', 100, 1838), ('nextracker', 56, 1833), ('nextracker', 56, 1834), ('nextracker', 56, 1835)] adroll
# Candel Therapeutics Inc. [('23andme', 62, 59), ('23andme', 62, 60), ('23andme', 62, 61), ('23andme', 62, 62), ('23andme', 62, 63)] advantagene
# CANDEL THERAPEUTICS INC [('23andme', 62, 59), ('23andme', 62, 60), ('23andme', 62, 61), ('23andme', 62, 62), ('23andme', 62, 63)] advantagene
# Adyen NV [('adyen', 100, 121), ('adyen', 100, 122), ('adyen', 100, 123), ('adyen', 100, 124), ('adyen', 100, 125)] adyen
# ADYEN NV /EUR/ [('adyen', 100, 121), ('adyen', 100, 122), ('adyen', 100, 123), ('adyen', 100, 124), ('adyen', 100, 125)] adyen
# ADYEN BV [('adyen', 100, 121), ('adyen', 100, 122), ('adyen', 100, 123), ('adyen', 100, 124), ('adyen', 100, 125)] adyen
# Adyen N.V. [('adyen', 100, 121), ('adyen', 100, 122), ('adyen', 100, 123), ('adyen', 100, 124), ('adyen', 100, 125)] adyen
# ADYEN NV UNSPON ADR [('adyen', 100, 121), ('adyen', 100, 122), ('adyen', 100, 123), ('adyen', 100, 124), ('adyen', 100, 125)] adyen
# Adyen B.V. [('adyen', 100, 121), ('adyen', 100, 122), ('adyen', 100, 123), ('adyen', 100, 124), ('adyen', 100, 125)] adyen
# Adyen NV ORD EUR 0.01 [('adyen', 100, 121), ('adyen', 100, 122), ('adyen', 100, 123), ('adyen', 100, 124), ('adyen', 100, 125)] adyen
# AEVA TECHNOLOGIES INC [('aeva', 100, 128), ('aeva', 100, 129), ('aeva', 100, 130), ('cava', 75, 563), ('cava', 75, 564)] aeva
# Aeva Technologies, Inc. [('aeva', 100, 128), ('aeva', 100, 129), ('aeva', 100, 130), ('cava', 75, 563), ('cava', 75, 564)] aeva
# Aeva Technologies Inc. [('aeva', 100, 128), ('aeva', 100, 129), ('aeva', 100, 130), ('cava', 75, 563), ('cava', 75, 564)] aeva
# AFFIRM HOLDINGS INC [('affirm', 100, 131), ('affirm', 100, 132), ('affirm', 100, 133), ('affirm', 100, 134), ('a24-films', 53, 79)] affirm
# Affirm Holdings, Inc. [('affirm', 100, 131), ('affirm', 100, 132), ('affirm', 100, 133), ('affirm', 100, 134), ('a24-films', 53, 79)] affirm
# AFFIRM INC [('affirm', 100, 131), ('affirm', 100, 132), ('affirm', 100, 133), ('affirm', 100, 134), ('a24-films', 53, 79)] affirm
# Affirm Holdings Inc. [('affirm', 100, 131), ('affirm', 100, 132), ('affirm', 100, 133), ('affirm', 100, 134), ('a24-films', 53, 79)] affirm
# AGILITY [('agility-robotics', 100, 135), ('angieslist', 71, 213), ('akili', 67, 150), ('akili', 67, 151), ('algolia', 57, 153)] agility-robotics
# AIRBNB INC [('airbnb', 100, 136), ('airbnb', 100, 137), ('airbnb', 100, 138), ('airbnb', 100, 139), ('airbnb', 100, 140)] airbnb
# AIRBNB [('airbnb', 100, 136), ('airbnb', 100, 137), ('airbnb', 100, 138), ('airbnb', 100, 139), ('airbnb', 100, 140)] airbnb
# AIRBNB INC-CLASS A [('airbnb', 100, 136), ('airbnb', 100, 137), ('airbnb', 100, 138), ('airbnb', 100, 139), ('airbnb', 100, 140)] airbnb
# Airbnb, Inc. [('airbnb', 100, 136), ('airbnb', 100, 137), ('airbnb', 100, 138), ('airbnb', 100, 139), ('airbnb', 100, 140)] airbnb
# Airbnb Inc. [('airbnb', 100, 136), ('airbnb', 100, 137), ('airbnb', 100, 138), ('airbnb', 100, 139), ('airbnb', 100, 140)] airbnb
# AIRBNB INC SERIES D CVT PFD CONVERTIBLE PRFD STOCK (PRIV P [('airbnb', 100, 136), ('airbnb', 100, 137), ('airbnb', 100, 138), ('airbnb', 100, 139), ('airbnb', 100, 140)] airbnb
# AIRBNB INC CLASS A [('airbnb', 100, 136), ('airbnb', 100, 137), ('airbnb', 100, 138), ('airbnb', 100, 139), ('airbnb', 100, 140)] airbnb
# AIRBNB, INC. SERIES E CONVERTIBLE [('airbnb', 100, 136), ('airbnb', 100, 137), ('airbnb', 100, 138), ('airbnb', 100, 139), ('airbnb', 100, 140)] airbnb
# AIRBNB INC CLASS B LOCKUP [('airbnb', 100, 136), ('airbnb', 100, 137), ('airbnb', 100, 138), ('airbnb', 100, 139), ('airbnb', 100, 140)] airbnb
# Formagrid Inc Ser F C [('coursera', 48, 776), ('coursera', 48, 777), ('coursera', 48, 778), ('workrise', 48, 3000), ('contrast-security', 47, 733)] airtable
# Formagrid Inc Ser F Cvt Pfd Pp [('caris-life-sciences', 43, 546), ('caris-life-sciences', 43, 547), ('caris-life-sciences', 43, 548), ('caris-life-sciences', 43, 549), ('caris-life-sciences', 43, 550)] airtable
# Formagrid Inc Ser F Cvt /Pfd/ [('caris-life-sciences', 43, 546), ('caris-life-sciences', 43, 547), ('caris-life-sciences', 43, 548), ('caris-life-sciences', 43, 549), ('caris-life-sciences', 43, 550)] airtable
# AIVEN SERIES D PREFERRED [('aiven', 100, 148), ('aiven', 100, 149), ('rad-power-bikes', 53, 2166), ('rad-power-bikes', 53, 2167), ('rad-power-bikes', 53, 2168)] aiven
# AIVEN COMMON [('aiven', 100, 148), ('aiven', 100, 149), ('brain-corp', 55, 435), ('brain-corp', 55, 436), ('brain-corp', 55, 437)] aiven
# AKILI INC [('akili', 100, 150), ('akili', 100, 151), ('grail', 60, 1321), ('skillz', 55, 2450), ('skillz', 55, 2451)] akili
# Akili Inc. [('akili', 100, 150), ('akili', 100, 151), ('grail', 60, 1321), ('skillz', 55, 2450), ('skillz', 55, 2451)] akili
# ALEDADE INC [('aledade', 100, 152), ('limeade', 71, 1630), ('accolade', 67, 88), ('accolade', 67, 89), ('accolade', 67, 90)] aledade
# ALGOLIA INC [('algolia', 100, 153), ('algolia', 100, 154), ('algolia', 100, 155), ('algolia', 100, 156), ('algolia', 100, 157)] algolia
# ALGOLIA SAS [('algolia', 100, 153), ('algolia', 100, 154), ('algolia', 100, 155), ('algolia', 100, 156), ('algolia', 100, 157)] algolia
# ALGOLIA, INC. COMMON SHARES   / [('algolia', 100, 153), ('algolia', 100, 154), ('algolia', 100, 155), ('algolia', 100, 156), ('algolia', 100, 157)] algolia
# ALGOLIA  COMMON SHARES   / [('algolia', 100, 153), ('algolia', 100, 154), ('algolia', 100, 155), ('algolia', 100, 156), ('algolia', 100, 157)] algolia
# Algolia, Inc. Shares / [('algolia', 100, 153), ('algolia', 100, 154), ('algolia', 100, 155), ('algolia', 100, 156), ('algolia', 100, 157)] algolia
# ALIBABA GROUP HOLDING LTD [('alibaba', 100, 158), ('alibaba', 100, 159), ('alibaba', 100, 160), ('alibaba', 100, 161), ('alibaba', 100, 162)] alibaba
# Alibaba Group Holding Ltd. [('alibaba', 100, 158), ('alibaba', 100, 159), ('alibaba', 100, 160), ('alibaba', 100, 161), ('alibaba', 100, 162)] alibaba
# ALIBABA GROUP HOLDING-SP ADR [('alibaba', 100, 158), ('alibaba', 100, 159), ('alibaba', 100, 160), ('alibaba', 100, 161), ('alibaba', 100, 162)] alibaba
# ALIBABA HEALTH INFORMATION TECHNOLOGY LTD [('alibaba', 100, 158), ('alibaba', 100, 159), ('alibaba', 100, 160), ('alibaba', 100, 161), ('alibaba', 100, 162)] alibaba
# Alibaba Group Holding Limited [('alibaba', 100, 158), ('alibaba', 100, 159), ('alibaba', 100, 160), ('alibaba', 100, 161), ('alibaba', 100, 162)] alibaba
# ALIBABA HEALTH INFORMATION TECHNOLOGY LIMITED [('alibaba', 100, 158), ('alibaba', 100, 159), ('alibaba', 100, 160), ('alibaba', 100, 161), ('alibaba', 100, 162)] alibaba
# Alibaba Pictures Group Limited [('alibaba', 100, 158), ('alibaba', 100, 159), ('alibaba', 100, 160), ('alibaba', 100, 161), ('alibaba', 100, 162)] alibaba
# ALIBABA GROUP HOLDING SP ADR [('alibaba', 100, 158), ('alibaba', 100, 159), ('alibaba', 100, 160), ('alibaba', 100, 161), ('alibaba', 100, 162)] alibaba
# ALIBABA GROUP HOLDING LTD SPONSORED ADR [('alibaba', 100, 158), ('alibaba', 100, 159), ('alibaba', 100, 160), ('alibaba', 100, 161), ('alibaba', 100, 162)] alibaba
# ALIBABA PICTURES GROUP LTD [('alibaba', 100, 158), ('alibaba', 100, 159), ('alibaba', 100, 160), ('alibaba', 100, 161), ('alibaba', 100, 162)] alibaba
# ALIBABA GROUP HOL-SP ADR CDI [('alibaba', 100, 158), ('alibaba', 100, 159), ('alibaba', 100, 160), ('alibaba', 100, 161), ('alibaba', 100, 162)] alibaba
# Alibaba Group Holding Ltd ORD HKD 0.000003125 [('alibaba', 100, 158), ('alibaba', 100, 159), ('alibaba', 100, 160), ('alibaba', 100, 161), ('alibaba', 100, 162)] alibaba
# ALIBABA HEALTH INFORMATION T [('alibaba', 100, 158), ('alibaba', 100, 159), ('alibaba', 100, 160), ('alibaba', 100, 161), ('alibaba', 100, 162)] alibaba
# ALIBABA GROUP HOLDING [('alibaba', 100, 158), ('alibaba', 100, 159), ('alibaba', 100, 160), ('alibaba', 100, 161), ('alibaba', 100, 162)] alibaba
# ALIF SEMICONDUCTOR [('alif-semiconductor', 100, 172), ('lifemine', 54, 1613), ('calix-networks', 50, 492), ('calix-networks', 50, 493), ('snorkel-ai', 50, 2477)] alif-semiconductor
# Alkami Technology Inc [('alkami-technology', 100, 173), ('alkami-technology', 100, 174), ('alkami-technology', 100, 175), ('walkme', 67, 2937), ('dataminr', 57, 845)] alkami-technology
# ALKAMI TECHNOLOGY, INC. [('alkami-technology', 100, 173), ('alkami-technology', 100, 174), ('alkami-technology', 100, 175), ('walkme', 67, 2937), ('dataminr', 57, 845)] alkami-technology
# Alkami Technology Inc. [('alkami-technology', 100, 173), ('alkami-technology', 100, 174), ('alkami-technology', 100, 175), ('walkme', 67, 2937), ('dataminr', 57, 845)] alkami-technology
# ALLBIRDS INC [('allbirds', 100, 176), ('allbirds', 100, 177), ('allbirds', 100, 178), ('allbirds', 100, 179), ('allbirds', 100, 180)] allbirds
# Allbirds Inc. [('allbirds', 100, 176), ('allbirds', 100, 177), ('allbirds', 100, 178), ('allbirds', 100, 179), ('allbirds', 100, 180)] allbirds
# ALLBIRDS [('allbirds', 100, 176), ('allbirds', 100, 177), ('allbirds', 100, 178), ('allbirds', 100, 179), ('allbirds', 100, 180)] allbirds
# ALLBIRDS SERIES E CVT PFD STOCK PP [('allbirds', 100, 176), ('allbirds', 100, 177), ('allbirds', 100, 178), ('allbirds', 100, 179), ('allbirds', 100, 180)] allbirds
# Allbirds, Inc. [('allbirds', 100, 176), ('allbirds', 100, 177), ('allbirds', 100, 178), ('allbirds', 100, 179), ('allbirds', 100, 180)] allbirds
# ALLBIRDS  INC. [('allbirds', 100, 176), ('allbirds', 100, 177), ('allbirds', 100, 178), ('allbirds', 100, 179), ('allbirds', 100, 180)] allbirds
# ALLBIRDS INC CL A [('allbirds', 100, 176), ('allbirds', 100, 177), ('allbirds', 100, 178), ('allbirds', 100, 179), ('allbirds', 100, 180)] allbirds
# ALLBIRDS INC LOCKUP SHS [('allbirds', 100, 176), ('allbirds', 100, 177), ('allbirds', 100, 178), ('allbirds', 100, 179), ('allbirds', 100, 180)] allbirds
# ALLOVIR INC [('allovir', 100, 184), ('allovir', 100, 185), ('allovir', 100, 186), ('allbirds', 67, 176), ('allbirds', 67, 177)] allovir
# Allovir Inc. [('allovir', 100, 184), ('allovir', 100, 185), ('allovir', 100, 186), ('allbirds', 67, 176), ('allbirds', 67, 177)] allovir
# Allovir, Inc. [('allovir', 100, 184), ('allovir', 100, 185), ('allovir', 100, 186), ('allbirds', 67, 176), ('allbirds', 67, 177)] allovir
# Alphasense,Inc. [('alphasense', 100, 187), ('atlassian', 53, 270), ('atlassian', 53, 271), ('atlassian', 53, 272), ('atlassian', 53, 273)] alphasense
# ALTOS LABS INC [('altos-labs', 100, 188), ('astera-labs', 67, 263), ('pax-labs', 67, 2001), ('pax-labs', 67, 2002), ('pax-labs', 67, 2003)] altos-labs
# American Well Corp [('american-well', 100, 189), ('american-well', 100, 190), ('american-well', 100, 191), ('american-well', 100, 192), ('american-well', 100, 193)] american-well
# American Well Corp. [('american-well', 100, 189), ('american-well', 100, 190), ('american-well', 100, 191), ('american-well', 100, 192), ('american-well', 100, 193)] american-well
# American Well Corporation [('american-well', 100, 189), ('american-well', 100, 190), ('american-well', 100, 191), ('american-well', 100, 192), ('american-well', 100, 193)] american-well
# AMERICAN WELL CORP CLASS A [('american-well', 100, 189), ('american-well', 100, 190), ('american-well', 100, 191), ('american-well', 100, 192), ('american-well', 100, 193)] american-well
# AMERICAN WELL CORP-CLASS A [('american-well', 100, 189), ('american-well', 100, 190), ('american-well', 100, 191), ('american-well', 100, 192), ('american-well', 100, 193)] american-well
# Amplitude Inc [('amplitude', 100, 194), ('amplitude', 100, 195), ('amplitude', 100, 196), ('amplitude', 100, 197), ('amplitude', 100, 198)] amplitude
# Amplitude, Inc. [('amplitude', 100, 194), ('amplitude', 100, 195), ('amplitude', 100, 196), ('amplitude', 100, 197), ('amplitude', 100, 198)] amplitude
# Amplitude Inc. [('amplitude', 100, 194), ('amplitude', 100, 195), ('amplitude', 100, 196), ('amplitude', 100, 197), ('amplitude', 100, 198)] amplitude
# AMPLITUDE INC-CLASS A [('amplitude', 100, 194), ('amplitude', 100, 195), ('amplitude', 100, 196), ('amplitude', 100, 197), ('amplitude', 100, 198)] amplitude
# AMPLITUDE INC CLASS A [('amplitude', 100, 194), ('amplitude', 100, 195), ('amplitude', 100, 196), ('amplitude', 100, 197), ('amplitude', 100, 198)] amplitude
# Amprius Technologies Inc [('amprius', 100, 199), ('amprius', 100, 200), ('amprius', 100, 201), ('amprius', 100, 202), ('amyris', 77, 206)] amprius
# Amprius Technologies, Inc. [('amprius', 100, 199), ('amprius', 100, 200), ('amprius', 100, 201), ('amprius', 100, 202), ('amyris', 77, 206)] amprius
# Amprius Technologies Inc - Warrants [('amprius', 100, 199), ('amprius', 100, 200), ('amprius', 100, 201), ('amprius', 100, 202), ('arista-networks', 52, 251)] amprius
# Amprius Technologies Inc. [('amprius', 100, 199), ('amprius', 100, 200), ('amprius', 100, 201), ('amprius', 100, 202), ('amyris', 77, 206)] amprius
# Amylyx Pharmaceuticals Inc. [('amylyx', 100, 203), ('amylyx', 100, 204), ('amylyx', 100, 205), ('oatly', 55, 1880), ('oatly', 55, 1881)] amylyx
# Amylyx Pharmaceuticals Inc [('amylyx', 100, 203), ('amylyx', 100, 204), ('amylyx', 100, 205), ('oatly', 55, 1880), ('oatly', 55, 1881)] amylyx
# Amylyx Pharmaceuticals, Inc. [('amylyx', 100, 203), ('amylyx', 100, 204), ('amylyx', 100, 205), ('oatly', 55, 1880), ('oatly', 55, 1881)] amylyx
# Amyris Inc [('amyris', 100, 206), ('amyris', 100, 207), ('amyris', 100, 208), ('amprius', 77, 199), ('amprius', 77, 200)] amyris
# Amyris Inc. [('amyris', 100, 206), ('amyris', 100, 207), ('amyris', 100, 208), ('amprius', 77, 199), ('amprius', 77, 200)] amyris
# AMYRIS, INC. [('amyris', 100, 206), ('amyris', 100, 207), ('amyris', 100, 208), ('amprius', 77, 199), ('amprius', 77, 200)] amyris
# ANAPLAN, INC. [('anaplan', 100, 209), ('anaplan', 100, 210), ('anaplan', 100, 211), ('planet', 62, 2061), ('planet', 62, 2062)] anaplan
# ANAPLAN INC [('anaplan', 100, 209), ('anaplan', 100, 210), ('anaplan', 100, 211), ('planet', 62, 2061), ('planet', 62, 2062)] anaplan
# Anaplan Inc. [('anaplan', 100, 209), ('anaplan', 100, 210), ('anaplan', 100, 211), ('planet', 62, 2061), ('planet', 62, 2062)] anaplan
# Anchor Labs Inc [('anchorage', 70, 212), ('altos-labs', 67, 188), ('clear-labs', 67, 657), ('clear-labs', 67, 658), ('pax-labs', 67, 2001)] anchorage
# Angie's List Inc [('angieslist', 82, 213), ('apartment-list', 54, 226), ('apartment-list', 54, 227), ('apartment-list', 54, 228), ('gelesis', 53, 1233)] angieslist
# Annexon Inc [('annexon-biosciences', 100, 214), ('annexon-biosciences', 100, 215), ('annexon-biosciences', 100, 216), ('annexon-biosciences', 100, 217), ('exo', 60, 1107)] annexon-biosciences
# Annexon Inc. [('annexon-biosciences', 100, 214), ('annexon-biosciences', 100, 215), ('annexon-biosciences', 100, 216), ('annexon-biosciences', 100, 217), ('exo', 60, 1107)] annexon-biosciences
# Annexon, Inc. [('annexon-biosciences', 100, 214), ('annexon-biosciences', 100, 215), ('annexon-biosciences', 100, 216), ('annexon-biosciences', 100, 217), ('exo', 60, 1107)] annexon-biosciences
# ANNEXON [('annexon-biosciences', 100, 214), ('annexon-biosciences', 100, 215), ('annexon-biosciences', 100, 216), ('annexon-biosciences', 100, 217), ('exo', 60, 1107)] annexon-biosciences
# Ant Group Co Ltd [('accolade', 56, 88), ('accolade', 56, 89), ('accolade', 56, 90), ('voltron-data', 55, 2919), ('voltron-data', 55, 2920)] ant-financial
# Ant Financial [('ant-financial', 100, 218), ('ant-financial', 100, 219), ('ant-financial', 100, 220), ('ant-financial', 100, 221), ('ant-financial', 100, 222)] ant-financial
# Ant International Co [('zipline-international', 79, 3069), ('zipline-international', 79, 3070), ('ant-financial', 61, 218), ('ant-financial', 61, 219), ('ant-financial', 61, 220)] ant-financial
# Ant Group Co [('ant-financial', 67, 218), ('ant-financial', 67, 219), ('ant-financial', 67, 220), ('ant-financial', 67, 221), ('ant-financial', 67, 222)] ant-financial
# Ant International [('zipline-international', 87, 3069), ('zipline-international', 87, 3070), ('ant-financial', 67, 218), ('ant-financial', 67, 219), ('ant-financial', 67, 220)] ant-financial
# Ant International Co. Limited [('zipline-international', 76, 3069), ('zipline-international', 76, 3070), ('line-corporation', 55, 22), ('integral-ad-science', 51, 1506), ('integral-ad-science', 51, 1507)] ant-financial
# Ant International Co. Limited Class C Shares [('zipline-international', 76, 3069), ('zipline-international', 76, 3070), ('bark-co', 44, 333), ('bark-co', 44, 334), ('integral-ad-science', 42, 1506)] ant-financial
# Anyroad Inc [('anyroad', 100, 225), ('applyboard', 59, 239), ('laronde', 57, 1589), ('laronde', 57, 1590), ('laronde', 57, 1591)] anyroad
# Apartment List Inc. Series D Preferred Stock [('apartment-list', 100, 226), ('apartment-list', 100, 227), ('apartment-list', 100, 228), ('mynd-property-management', 48, 1778), ('mynd-property-management', 48, 1779)] apartment-list
# Apartment List Inc. Series D [('apartment-list', 100, 226), ('apartment-list', 100, 227), ('apartment-list', 100, 228), ('paymentus', 61, 2005), ('paymentus', 61, 2006)] apartment-list
# Apartment List Inc [('apartment-list', 100, 226), ('apartment-list', 100, 227), ('apartment-list', 100, 228), ('paymentus', 61, 2005), ('paymentus', 61, 2006)] apartment-list
# APEXIGEN INC [('apexigen', 100, 229), ('apexigen', 100, 230), ('aiven', 62, 148), ('aiven', 62, 149), ('heliogen', 62, 1401)] apexigen
# Apexigen Inc. [('apexigen', 100, 229), ('apexigen', 100, 230), ('aiven', 62, 148), ('aiven', 62, 149), ('heliogen', 62, 1401)] apexigen
# APNIMED INC [('apnimed', 100, 231), ('tanium', 62, 2673), ('tanium', 62, 2674), ('tanium', 62, 2675), ('tanium', 62, 2676)] apnimed
# APOGEE THERAPEUTICS [('apogee-therapeutics', 100, 232), ('apexigen', 57, 229), ('apexigen', 57, 230), ('payoneer', 57, 2009), ('payoneer', 57, 2010)] apogee-therapeutics
# APPHARVEST INC [('appharvest', 89, 233), ('appharvest', 89, 234), ('caresyntax', 56, 5), ('alphasense', 56, 187), ('caresyntax', 56, 539)] appharvest
# AppHarvest Inc. [('appharvest', 89, 233), ('appharvest', 89, 234), ('caresyntax', 56, 5), ('alphasense', 56, 187), ('caresyntax', 56, 539)] appharvest
# AppLovin Corp. [('brain-corp', 76, 435), ('brain-corp', 76, 436), ('brain-corp', 76, 437), ('brain-corp', 76, 438), ('brain-corp', 76, 439)] applovin
# APPLOVIN CORP [('brain-corp', 76, 435), ('brain-corp', 76, 436), ('brain-corp', 76, 437), ('brain-corp', 76, 438), ('brain-corp', 76, 439)] applovin
# APPLOVIN CORPORATION [('applovin', 86, 235), ('applovin', 86, 236), ('applovin', 86, 237), ('applovin', 86, 238), ('allovir', 77, 184)] applovin
# APPLOVIN CORP-CLASS A [('brain-corp', 57, 435), ('brain-corp', 57, 436), ('brain-corp', 57, 437), ('brain-corp', 57, 438), ('brain-corp', 57, 439)] applovin
# APPLYBOARD [('applyboard', 89, 239), ('anyroad', 67, 225), ('allbirds', 62, 176), ('allbirds', 62, 177), ('allbirds', 62, 178)] applyboard
# APPNEXUS INC [('appnexus', 86, 240), ('onetrust', 57, 1923), ('paymentus', 53, 2005), ('paymentus', 53, 2006), ('paymentus', 53, 2007)] appnexus
# Arbor Biotechnologies [('arbor-biotechnologies', 71, 241), ('korro-bio', 67, 1571), ('kronos-bio', 63, 1579), ('kronos-bio', 63, 1580), ('kronos-bio', 63, 1581)] arbor-biotechnologies
# Arcellx Inc [('arcellx', 100, 0), ('arcellx', 100, 242), ('arcellx', 100, 243), ('arcellx', 100, 244), ('arcellx', 100, 245)] arcellx
# Arcellx, Inc.,,, [('arcellx', 100, 0), ('arcellx', 100, 242), ('arcellx', 100, 243), ('arcellx', 100, 244), ('arcellx', 100, 245)] arcellx
# Arcellx, Inc. [('arcellx', 100, 0), ('arcellx', 100, 242), ('arcellx', 100, 243), ('arcellx', 100, 244), ('arcellx', 100, 245)] arcellx
# Arcellx Inc. [('arcellx', 100, 0), ('arcellx', 100, 242), ('arcellx', 100, 243), ('arcellx', 100, 244), ('arcellx', 100, 245)] arcellx
# ARCTIC WOLF NETWORKS INC COMMO [('arctic-wolf', 100, 246), ('arctic-wolf', 100, 247), ('arctic-wolf', 100, 248), ('arctic-wolf', 100, 249), ('arctic-wolf', 100, 250)] arctic-wolf
# ARCTIC WOLF NETWORKS, INC. COMMON SHARES   / [('arctic-wolf', 100, 246), ('arctic-wolf', 100, 247), ('arctic-wolf', 100, 248), ('arctic-wolf', 100, 249), ('arctic-wolf', 100, 250)] arctic-wolf
# ARCTIC WOLF COMMON SHARES   / [('arctic-wolf', 100, 246), ('arctic-wolf', 100, 247), ('arctic-wolf', 100, 248), ('arctic-wolf', 100, 249), ('arctic-wolf', 100, 250)] arctic-wolf
# Arctic Wolf Networks, Inc. Shares / [('arctic-wolf', 100, 246), ('arctic-wolf', 100, 247), ('arctic-wolf', 100, 248), ('arctic-wolf', 100, 249), ('arctic-wolf', 100, 250)] arctic-wolf
# Arctic Wolf Networks Inc [('arctic-wolf', 100, 246), ('arctic-wolf', 100, 247), ('arctic-wolf', 100, 248), ('arctic-wolf', 100, 249), ('arctic-wolf', 100, 250)] arctic-wolf
# ARISTA NETWORKS INC [('arista-networks', 100, 251), ('arista-networks', 100, 252), ('arista-networks', 100, 253), ('calix-networks', 76, 492), ('calix-networks', 76, 493)] arista-networks
# ARISTA NETWORKS, INC. [('arista-networks', 100, 251), ('arista-networks', 100, 252), ('arista-networks', 100, 253), ('calix-networks', 76, 492), ('calix-networks', 76, 493)] arista-networks
# Arista Networks Inc. [('arista-networks', 100, 251), ('arista-networks', 100, 252), ('arista-networks', 100, 253), ('calix-networks', 76, 492), ('calix-networks', 76, 493)] arista-networks
# ARS Pharmaceuticals, Inc. [('ars-pharmaceuticals', 100, 254), ('ars-pharmaceuticals', 100, 255), ('ars-pharmaceuticals', 100, 256), ('amyris', 67, 206), ('amyris', 67, 207)] ars-pharmaceuticals
# ARS PHARMACEUTICALS INC [('ars-pharmaceuticals', 100, 254), ('ars-pharmaceuticals', 100, 255), ('ars-pharmaceuticals', 100, 256), ('amyris', 67, 206), ('amyris', 67, 207)] ars-pharmaceuticals
# ARS Pharmaceuticals Inc. [('ars-pharmaceuticals', 100, 254), ('ars-pharmaceuticals', 100, 255), ('ars-pharmaceuticals', 100, 256), ('amyris', 67, 206), ('amyris', 67, 207)] ars-pharmaceuticals
# Asana Inc [('asana', 100, 257), ('asana', 100, 258), ('asana', 100, 259), ('asana', 100, 260), ('tarana', 73, 2684)] asana
# Asana Inc. [('asana', 100, 257), ('asana', 100, 258), ('asana', 100, 259), ('asana', 100, 260), ('tarana', 73, 2684)] asana
# Asana, Inc. [('asana', 100, 257), ('asana', 100, 258), ('asana', 100, 259), ('asana', 100, 260), ('tarana', 73, 2684)] asana
# ASANA INC   CL A [('asana', 100, 257), ('asana', 100, 258), ('asana', 100, 259), ('asana', 100, 260), ('atlassian', 53, 270)] asana
# ASAPP INC [('asana', 75, 257), ('asana', 75, 258), ('asana', 75, 259), ('asana', 75, 260), ('asapp', 75, 261)] asapp
# ASIMOV INC [('asimov', 100, 262), ('sima-ai', 62, 2446), ('thrasio', 62, 2759), ('aiven', 55, 148), ('aiven', 55, 149)] asimov
# ASTERA LABS INC [('astera-labs', 100, 263), ('dapper-labs', 73, 822), ('masterclass', 73, 1696), ('masterclass', 73, 1697), ('masterclass', 73, 1698)] astera-labs
# ASTRA SPACE INC [('astra-space', 100, 264), ('astra-space', 100, 265), ('astra-space', 100, 266), ('astra-space', 100, 267), ('sierra-space', 78, 2435)] astra-space
# Astra Space, Inc. [('astra-space', 100, 264), ('astra-space', 100, 265), ('astra-space', 100, 266), ('astra-space', 100, 267), ('sierra-space', 78, 2435)] astra-space
# Astra Space Inc. [('astra-space', 100, 264), ('astra-space', 100, 265), ('astra-space', 100, 266), ('astra-space', 100, 267), ('sierra-space', 78, 2435)] astra-space
# Astra Space [('astra-space', 100, 264), ('astra-space', 100, 265), ('astra-space', 100, 266), ('astra-space', 100, 267), ('sierra-space', 78, 2435)] astra-space
# ASTRANIS SPACE TECHNOLOGIES CORP [('astranis', 100, 268), ('astranis', 100, 269), ('astra-space', 73, 264), ('astra-space', 73, 265), ('astra-space', 73, 266)] astranis
# Astranis Space Technologies Corp, Series C [('astranis', 100, 268), ('astranis', 100, 269), ('astra-space', 73, 264), ('astra-space', 73, 265), ('astra-space', 73, 266)] astranis
# Atlassian Corp. [('atlassian', 100, 270), ('atlassian', 100, 271), ('atlassian', 100, 272), ('atlassian', 100, 273), ('atlassian', 100, 274)] atlassian
# ATLASSIAN CORPORATION [('atlassian', 100, 270), ('atlassian', 100, 271), ('atlassian', 100, 272), ('atlassian', 100, 273), ('atlassian', 100, 274)] atlassian
# ATLASSIAN CORP PLC [('atlassian', 100, 270), ('atlassian', 100, 271), ('atlassian', 100, 272), ('atlassian', 100, 273), ('atlassian', 100, 274)] atlassian
# Atlassian Corp [('atlassian', 100, 270), ('atlassian', 100, 271), ('atlassian', 100, 272), ('atlassian', 100, 273), ('atlassian', 100, 274)] atlassian
# ATLASSIAN CORPORATION PLC [('atlassian', 100, 270), ('atlassian', 100, 271), ('atlassian', 100, 272), ('atlassian', 100, 273), ('atlassian', 100, 274)] atlassian
# Atlassian Corp. plc [('atlassian', 100, 270), ('atlassian', 100, 271), ('atlassian', 100, 272), ('atlassian', 100, 273), ('atlassian', 100, 274)] atlassian
# ATLASSIAN CORP PLC-CLASS A [('atlassian', 100, 270), ('atlassian', 100, 271), ('atlassian', 100, 272), ('atlassian', 100, 273), ('atlassian', 100, 274)] atlassian
# ATLASSIAN CORP PLC CLASS A [('atlassian', 100, 270), ('atlassian', 100, 271), ('atlassian', 100, 272), ('atlassian', 100, 273), ('atlassian', 100, 274)] atlassian
# ATLASSIAN CORP CL A [('atlassian', 100, 270), ('atlassian', 100, 271), ('atlassian', 100, 272), ('atlassian', 100, 273), ('atlassian', 100, 274)] atlassian
# ATLASSIAN CORP PLC ORD USD.1 [('atlassian', 100, 270), ('atlassian', 100, 271), ('atlassian', 100, 272), ('atlassian', 100, 273), ('atlassian', 100, 274)] atlassian
# ATLASSIAN CORP-CL A [('atlassian', 100, 270), ('atlassian', 100, 271), ('atlassian', 100, 272), ('atlassian', 100, 273), ('atlassian', 100, 274)] atlassian
# ATLASSIAN CORP -CLASS A [('atlassian', 100, 270), ('atlassian', 100, 271), ('atlassian', 100, 272), ('atlassian', 100, 273), ('atlassian', 100, 274)] atlassian
# ATTENTIVE MOBILE INC COMMON [('attentive', 100, 282), ('attentive', 100, 283), ('attentive', 100, 284), ('attentive', 100, 285), ('attentive', 100, 286)] attentive
# ATTENTIVE MOBILE INC - PREFERRED B [('attentive', 100, 282), ('attentive', 100, 283), ('attentive', 100, 284), ('attentive', 100, 285), ('attentive', 100, 286)] attentive
# ATTENTIVE MOBILE INC-PREFERRED A1 [('attentive', 100, 282), ('attentive', 100, 283), ('attentive', 100, 284), ('attentive', 100, 285), ('attentive', 100, 286)] attentive
# Attentive Mobile, Inc. Preferred A1 LP [('attentive', 100, 282), ('attentive', 100, 283), ('attentive', 100, 284), ('attentive', 100, 285), ('attentive', 100, 286)] attentive
# Attentive Mobile, Inc. Preferred B LP [('attentive', 100, 282), ('attentive', 100, 283), ('attentive', 100, 284), ('attentive', 100, 285), ('attentive', 100, 286)] attentive
# Attentive Mobile Inc [('attentive', 100, 282), ('attentive', 100, 283), ('attentive', 100, 284), ('attentive', 100, 285), ('attentive', 100, 286)] attentive
# Attentive Mobile Inc- A1 [('attentive', 100, 282), ('attentive', 100, 283), ('attentive', 100, 284), ('attentive', 100, 285), ('attentive', 100, 286)] attentive
# Attentive Mobile Inc - B [('attentive', 100, 282), ('attentive', 100, 283), ('attentive', 100, 284), ('attentive', 100, 285), ('attentive', 100, 286)] attentive
# AURA BIOSCIENCES INC [('aura-biosciences', 80, 290), ('aura-biosciences', 80, 291), ('aura-biosciences', 80, 292), ('aura-biosciences', 80, 293), ('kaltura', 62, 1546)] aura-biosciences
# ...
# Xometry, Inc. [('xometry', 100, 3005), ('xometry', 100, 3006), ('xometry', 100, 3007), ('xometry', 100, 3008), ('xometry', 100, 3009)] xometry
# XOMETRY SER SEED-2 CVT PFD STOCK PP [('xometry', 100, 3005), ('xometry', 100, 3006), ('xometry', 100, 3007), ('xometry', 100, 3008), ('xometry', 100, 3009)] xometry
# XOMETRY SER B CVT PFD STOCK PP [('xometry', 100, 3005), ('xometry', 100, 3006), ('xometry', 100, 3007), ('xometry', 100, 3008), ('xometry', 100, 3009)] xometry
# XOMETRY SER C CVT PFD STOCK PP [('xometry', 100, 3005), ('xometry', 100, 3006), ('xometry', 100, 3007), ('xometry', 100, 3008), ('xometry', 100, 3009)] xometry
# Xometry Inc. [('xometry', 100, 3005), ('xometry', 100, 3006), ('xometry', 100, 3007), ('xometry', 100, 3008), ('xometry', 100, 3009)] xometry
# XOMETRY SER SEED-1 CVT PFD STOCK PP [('xometry', 100, 3005), ('xometry', 100, 3006), ('xometry', 100, 3007), ('xometry', 100, 3008), ('xometry', 100, 3009)] xometry
# XOMETRY SER E CVT PFD STOCK PP [('xometry', 100, 3005), ('xometry', 100, 3006), ('xometry', 100, 3007), ('xometry', 100, 3008), ('xometry', 100, 3009)] xometry
# Xometry Series E Preferred Stock [('xometry', 100, 3005), ('xometry', 100, 3006), ('xometry', 100, 3007), ('xometry', 100, 3008), ('xometry', 100, 3009)] xometry
# XOMETRY INC-A [('xometry', 100, 3005), ('xometry', 100, 3006), ('xometry', 100, 3007), ('xometry', 100, 3008), ('xometry', 100, 3009)] xometry
# XOMETRY SER D CVT PFD STOCK PP [('xometry', 100, 3005), ('xometry', 100, 3006), ('xometry', 100, 3007), ('xometry', 100, 3008), ('xometry', 100, 3009)] xometry
# XOMETRY SER A-2 CVT PFD STOCK PP [('xometry', 100, 3005), ('xometry', 100, 3006), ('xometry', 100, 3007), ('xometry', 100, 3008), ('xometry', 100, 3009)] xometry
# XOMETRY SER D CVT PFD STOCK PRIVATE PLACEMENT [('xometry', 100, 3005), ('xometry', 100, 3006), ('xometry', 100, 3007), ('xometry', 100, 3008), ('xometry', 100, 3009)] xometry
# Xometry Series A-2 Preferred Stock [('xometry', 100, 3005), ('xometry', 100, 3006), ('xometry', 100, 3007), ('xometry', 100, 3008), ('xometry', 100, 3009)] xometry
# Xometry Series C Preferred Stock [('xometry', 100, 3005), ('xometry', 100, 3006), ('xometry', 100, 3007), ('xometry', 100, 3008), ('xometry', 100, 3009)] xometry
# Xometry Inc. Series Seed-2 Preferred Stock [('xometry', 100, 3005), ('xometry', 100, 3006), ('xometry', 100, 3007), ('xometry', 100, 3008), ('xometry', 100, 3009)] xometry
# XOMETRY SER SEED 1 CVT PFD [('xometry', 100, 3005), ('xometry', 100, 3006), ('xometry', 100, 3007), ('xometry', 100, 3008), ('xometry', 100, 3009)] xometry
# XOMETRY SER B CVT PFD STOCK PRIVATE PLACEMENT [('xometry', 100, 3005), ('xometry', 100, 3006), ('xometry', 100, 3007), ('xometry', 100, 3008), ('xometry', 100, 3009)] xometry
# XOMETRY INC A [('xometry', 100, 3005), ('xometry', 100, 3006), ('xometry', 100, 3007), ('xometry', 100, 3008), ('xometry', 100, 3009)] xometry
# Xometry, Inc [('xometry', 100, 3005), ('xometry', 100, 3006), ('xometry', 100, 3007), ('xometry', 100, 3008), ('xometry', 100, 3009)] xometry
# Xometry Inc. Series Seed-1 Preferred Stock [('xometry', 100, 3005), ('xometry', 100, 3006), ('xometry', 100, 3007), ('xometry', 100, 3008), ('xometry', 100, 3009)] xometry
# XOMETRY INC. LOCKUP SHARES [('xometry', 100, 3005), ('xometry', 100, 3006), ('xometry', 100, 3007), ('xometry', 100, 3008), ('xometry', 100, 3009)] xometry
# XOMETRY SER SEED 2 CVT PFD [('xometry', 100, 3005), ('xometry', 100, 3006), ('xometry', 100, 3007), ('xometry', 100, 3008), ('xometry', 100, 3009)] xometry
# XOMETRY SER C CVT PFD STOCK PRIVATE PLACEMENT [('xometry', 100, 3005), ('xometry', 100, 3006), ('xometry', 100, 3007), ('xometry', 100, 3008), ('xometry', 100, 3009)] xometry
# Xometry Series D Preferred Stock [('xometry', 100, 3005), ('xometry', 100, 3006), ('xometry', 100, 3007), ('xometry', 100, 3008), ('xometry', 100, 3009)] xometry
# XOMETRY SER E CVT PFD STOCK PRIVATE PLACEMENT [('xometry', 100, 3005), ('xometry', 100, 3006), ('xometry', 100, 3007), ('xometry', 100, 3008), ('xometry', 100, 3009)] xometry
# Xometry Inc Lockup Cusip [('xometry', 100, 3005), ('xometry', 100, 3006), ('xometry', 100, 3007), ('xometry', 100, 3008), ('xometry', 100, 3009)] xometry
# XOMETRY SER A 2 CVT PFD STC [('xometry', 100, 3005), ('xometry', 100, 3006), ('xometry', 100, 3007), ('xometry', 100, 3008), ('xometry', 100, 3009)] xometry
# XPENG INC [('xpeng', 100, 3034), ('xpeng', 100, 3035), ('xpeng', 100, 3036), ('xpeng', 100, 3037), ('openx', 60, 1933)] xpeng
# XPeng Inc. [('xpeng', 100, 3034), ('xpeng', 100, 3035), ('xpeng', 100, 3036), ('xpeng', 100, 3037), ('openx', 60, 1933)] xpeng
# XPENG INC   ADR [('xpeng', 100, 3034), ('xpeng', 100, 3035), ('xpeng', 100, 3036), ('xpeng', 100, 3037), ('adyen', 57, 121)] xpeng
# XPENG INC - ADR [('xpeng', 100, 3034), ('xpeng', 100, 3035), ('xpeng', 100, 3036), ('xpeng', 100, 3037), ('adyen', 57, 121)] xpeng
# Yelp Inc. [('yelp', 100, 3038), ('yelp', 100, 3039), ('yelp', 100, 3040), ('lyell', 67, 1656), ('lyell', 67, 1657)] yelp
# YELP INC [('yelp', 100, 3038), ('yelp', 100, 3039), ('yelp', 100, 3040), ('lyell', 67, 1656), ('lyell', 67, 1657)] yelp
# YELP INC COM USD.000001 [('yelp', 100, 3038), ('yelp', 100, 3039), ('yelp', 100, 3040), ('bill-com', 55, 367), ('bill-com', 55, 368)] yelp
# YEXT INC [('yext', 100, 3041), ('yext', 100, 3042), ('exo', 57, 1107), ('exo', 57, 1108), ('nextnav', 55, 1831)] yext
# Yext Inc. [('yext', 100, 3041), ('yext', 100, 3042), ('exo', 57, 1107), ('exo', 57, 1108), ('nextnav', 55, 1831)] yext
# YOTPO LTD [('yotpo', 100, 3043), ('yotpo', 100, 3044), ('lightspeed-pos', 52, 1614), ('lightspeed-pos', 52, 1615), ('lightspeed-pos', 52, 1616)] yotpo
# Yotpo [('yotpo', 100, 3043), ('yotpo', 100, 3044), ('gopro', 60, 1304), ('gopro', 60, 1305), ('gopro', 60, 1306)] yotpo
# Brandtech Group Ltd/The [('the-realreal', 55, 2745), ('the-realreal', 55, 2746), ('the-realreal', 55, 2747), ('the-realreal', 55, 2748), ('the-realreal', 55, 2749)] you-mr-jones
# You &Amp; Mr Jones [('you-mr-jones', 100, 3045), ('you-mr-jones', 100, 3046), ('you-mr-jones', 100, 3047), ('you-mr-jones', 100, 3048), ('you-mr-jones', 100, 3049)] you-mr-jones
# You &Amp; Mr Jones [('you-mr-jones', 100, 3045), ('you-mr-jones', 100, 3046), ('you-mr-jones', 100, 3047), ('you-mr-jones', 100, 3048), ('you-mr-jones', 100, 3049)] you-mr-jones
# You &Amp; Mr Jones . [('you-mr-jones', 100, 3045), ('you-mr-jones', 100, 3046), ('you-mr-jones', 100, 3047), ('you-mr-jones', 100, 3048), ('you-mr-jones', 100, 3049)] you-mr-jones
# Brandtech Group /The [('internet-brands', 57, 1511), ('internet-brands', 57, 1512), ('internet-brands', 57, 1513), ('internet-brands', 57, 1514), ('jobandtalent', 56, 1531)] you-mr-jones
# Zalando SE [('zalando', 100, 3050), ('zalando', 100, 3051), ('zalando', 100, 3052), ('zalando', 100, 3053), ('cellanome', 53, 574)] zalando
# ZALANDO SE /EUR/ [('zalando', 100, 3050), ('zalando', 100, 3051), ('zalando', 100, 3052), ('zalando', 100, 3053), ('persado', 57, 2030)] zalando
# ZALANDO SE ORD EUR NPV 144A [('zalando', 100, 3050), ('zalando', 100, 3051), ('zalando', 100, 3052), ('zalando', 100, 3053), ('devoted-health', 39, 913)] zalando
# ZALANDO SE ORD EUR NPV [('zalando', 100, 3050), ('zalando', 100, 3051), ('zalando', 100, 3052), ('zalando', 100, 3053), ('devoted-health', 44, 913)] zalando
# Zendesk Inc [('zendesk', 100, 3054), ('zendesk', 100, 3055), ('zendesk', 100, 3056), ('zendesk', 100, 3057), ('zenefits', 67, 3058)] zendesk
# Zendesk Inc. [('zendesk', 100, 3054), ('zendesk', 100, 3055), ('zendesk', 100, 3056), ('zendesk', 100, 3057), ('zenefits', 67, 3058)] zendesk
# ZENDESK, INC. [('zendesk', 100, 3054), ('zendesk', 100, 3055), ('zendesk', 100, 3056), ('zendesk', 100, 3057), ('zenefits', 67, 3058)] zendesk
# ZENDESK INC COM USD.01 [('zendesk', 100, 3054), ('zendesk', 100, 3055), ('zendesk', 100, 3056), ('zendesk', 100, 3057), ('bill-com', 55, 367)] zendesk
# YOURPEOPLE INC [('ripple', 62, 2269), ('ripple', 62, 2270), ('openspace', 53, 1932), ('yotpo', 53, 3043), ('yotpo', 53, 3044)] zenefits
# ZeroFox Holdings Inc [('zerofox', 100, 3059), ('zerofox', 100, 3060), ('roblox', 62, 2303), ('roblox', 62, 2304), ('roblox', 62, 2305)] zerofox
# ZeroFox Holdings, Inc. [('zerofox', 100, 3059), ('zerofox', 100, 3060), ('roblox', 62, 2303), ('roblox', 62, 2304), ('roblox', 62, 2305)] zerofox
# Zillow Group Inc [('zillow', 100, 3061), ('zillow', 100, 3062), ('zillow', 100, 3063), ('zillow', 100, 3064), ('zillow', 100, 3065)] zillow
# Zillow Group, Inc. [('zillow', 100, 3061), ('zillow', 100, 3062), ('zillow', 100, 3063), ('zillow', 100, 3064), ('zillow', 100, 3065)] zillow
# ZILLOW GROUP INC   C [('zillow', 100, 3061), ('zillow', 100, 3062), ('zillow', 100, 3063), ('zillow', 100, 3064), ('zillow', 100, 3065)] zillow
# Zillow Group Inc - A Shares [('zillow', 100, 3061), ('zillow', 100, 3062), ('zillow', 100, 3063), ('zillow', 100, 3064), ('zillow', 100, 3065)] zillow
# Zillow Group Inc - C Shares [('zillow', 100, 3061), ('zillow', 100, 3062), ('zillow', 100, 3063), ('zillow', 100, 3064), ('zillow', 100, 3065)] zillow
# Zillow Group Inc. [('zillow', 100, 3061), ('zillow', 100, 3062), ('zillow', 100, 3063), ('zillow', 100, 3064), ('zillow', 100, 3065)] zillow
# ZILLOW GROUP INC - A [('zillow', 100, 3061), ('zillow', 100, 3062), ('zillow', 100, 3063), ('zillow', 100, 3064), ('zillow', 100, 3065)] zillow
# ZILLOW GROUP INC - C [('zillow', 100, 3061), ('zillow', 100, 3062), ('zillow', 100, 3063), ('zillow', 100, 3064), ('zillow', 100, 3065)] zillow
# ZIPLINE INTERNATIONAL INC [('zipline-international', 100, 3069), ('zipline-international', 100, 3070), ('line-corporation', 59, 22), ('integral-ad-science', 55, 1506), ('integral-ad-science', 55, 1507)] zipline-international
# Zipline International Inc [('zipline-international', 100, 3069), ('zipline-international', 100, 3070), ('line-corporation', 59, 22), ('integral-ad-science', 55, 1506), ('integral-ad-science', 55, 1507)] zipline-international
# ZIPRECRUITER INC [('ziprecruiter', 100, 3071), ('ziprecruiter', 100, 3072), ('ziprecruiter', 100, 3073), ('ziprecruiter', 100, 3074), ('criteo', 56, 782)] ziprecruiter
# ZipRecruiter Inc. [('ziprecruiter', 100, 3071), ('ziprecruiter', 100, 3072), ('ziprecruiter', 100, 3073), ('ziprecruiter', 100, 3074), ('criteo', 56, 782)] ziprecruiter
# ZIPRECRUITER, INC. [('ziprecruiter', 100, 3071), ('ziprecruiter', 100, 3072), ('ziprecruiter', 100, 3073), ('ziprecruiter', 100, 3074), ('criteo', 56, 782)] ziprecruiter
# ZIPRECRUITER INC-A [('ziprecruiter', 100, 3071), ('ziprecruiter', 100, 3072), ('ziprecruiter', 100, 3073), ('ziprecruiter', 100, 3074), ('sharecare', 52, 2420)] ziprecruiter
# ZOCDOC COMMON    / [('zocdoc', 100, 3075), ('zocdoc', 100, 3076), ('zocdoc', 100, 3077), ('zocdoc', 100, 3078), ('commonbond', 70, 714)] zocdoc
# ZOCDOC, INC. COMMON    / [('zocdoc', 100, 3075), ('zocdoc', 100, 3076), ('zocdoc', 100, 3077), ('zocdoc', 100, 3078), ('commonbond', 70, 714)] zocdoc
# Zocdoc / [('zocdoc', 100, 3075), ('zocdoc', 100, 3076), ('zocdoc', 100, 3077), ('zocdoc', 100, 3078), ('docker', 50, 934)] zocdoc
# Zocdoc A / [('zocdoc', 100, 3075), ('zocdoc', 100, 3076), ('zocdoc', 100, 3077), ('zocdoc', 100, 3078), ('legalzoom', 47, 1598)] zocdoc
# Zomato Ltd [('zomato', 100, 3079), ('zomato', 100, 3080), ('zomato', 100, 3081), ('zomato', 100, 3082), ('zomato', 100, 3083)] zomato
# ZOMATO PVT LTD [('zomato', 100, 3079), ('zomato', 100, 3080), ('zomato', 100, 3081), ('zomato', 100, 3082), ('zomato', 100, 3083)] zomato
# ZOMATO LTD LOCKUP 30 DAYS [('zomato', 100, 3079), ('zomato', 100, 3080), ('zomato', 100, 3081), ('zomato', 100, 3082), ('zomato', 100, 3083)] zomato
# Zomato Limited [('zomato', 100, 3079), ('zomato', 100, 3080), ('zomato', 100, 3081), ('zomato', 100, 3082), ('zomato', 100, 3083)] zomato
# ZOMATO LTD /INR/ [('zomato', 100, 3079), ('zomato', 100, 3080), ('zomato', 100, 3081), ('zomato', 100, 3082), ('zomato', 100, 3083)] zomato
# Zomato Ltd. [('zomato', 100, 3079), ('zomato', 100, 3080), ('zomato', 100, 3081), ('zomato', 100, 3082), ('zomato', 100, 3083)] zomato
# ZOOM VIDEO COMMUNICATIONS INC [('zoom-video-communications', 100, 3085), ('zoom-video-communications', 100, 3086), ('zoom-video-communications', 100, 3087), ('zoom-video-communications', 100, 3088), ('zoom-video-communications', 100, 3089)] zoom-video-communications
# Zoom Video Communications Inc. [('zoom-video-communications', 100, 3085), ('zoom-video-communications', 100, 3086), ('zoom-video-communications', 100, 3087), ('zoom-video-communications', 100, 3088), ('zoom-video-communications', 100, 3089)] zoom-video-communications
# Zoom Video Communications, Inc. [('zoom-video-communications', 100, 3085), ('zoom-video-communications', 100, 3086), ('zoom-video-communications', 100, 3087), ('zoom-video-communications', 100, 3088), ('zoom-video-communications', 100, 3089)] zoom-video-communications
# ZOOM VIDEO COMMUNICATIONS-A [('zoom-video-communications', 91, 3085), ('zoom-video-communications', 91, 3086), ('zoom-video-communications', 91, 3087), ('zoom-video-communications', 91, 3088), ('zoom-video-communications', 91, 3089)] zoom-video-communications
# ZOOM VIDEO COMMUNICATIONS A [('zoom-video-communications', 91, 3085), ('zoom-video-communications', 91, 3086), ('zoom-video-communications', 91, 3087), ('zoom-video-communications', 91, 3088), ('zoom-video-communications', 91, 3089)] zoom-video-communications
# Zoom Video Communications Inc COM USD 0.0010 CL A [('zoom-video-communications', 58, 3085), ('zoom-video-communications', 58, 3086), ('zoom-video-communications', 58, 3087), ('zoom-video-communications', 58, 3088), ('zoom-video-communications', 58, 3089)] zoom-video-communications
# Zscaler Inc [('zscaler', 100, 3091), ('zscaler', 100, 3092), ('zscaler', 100, 3093), ('zscaler', 100, 3094), ('casper', 62, 556)] zscaler
# Zscaler, Inc. [('zscaler', 100, 3091), ('zscaler', 100, 3092), ('zscaler', 100, 3093), ('zscaler', 100, 3094), ('casper', 62, 556)] zscaler
# Zscaler Inc. [('zscaler', 100, 3091), ('zscaler', 100, 3092), ('zscaler', 100, 3093), ('zscaler', 100, 3094), ('casper', 62, 556)] zscaler
# Zscaler Inc COM USD 0.0010 [('zscaler', 100, 3091), ('zscaler', 100, 3092), ('zscaler', 100, 3093), ('zscaler', 100, 3094), ('bill-com', 55, 367)] zscaler
# Zuora Inc. [('zuora', 100, 46), ('zuora', 100, 47), ('zuora', 100, 3095), ('zuora', 100, 3096), ('zuora', 100, 3097)] zuora
# ZUORA INC - CLASS A [('zuora', 100, 46), ('zuora', 100, 47), ('zuora', 100, 3095), ('zuora', 100, 3096), ('zuora', 100, 3097)] zuora
# ZUORA INC   CLASS A [('zuora', 100, 46), ('zuora', 100, 47), ('zuora', 100, 3095), ('zuora', 100, 3096), ('zuora', 100, 3097)] zuora
# ZYMERGEN INC [('zymergen', 100, 3098), ('zymergen', 100, 3099), ('zymergen', 100, 3100), ('zymergen', 100, 3101), ('zymergen', 100, 3102)] zymergen
# Zymergen Inc. [('zymergen', 100, 3098), ('zymergen', 100, 3099), ('zymergen', 100, 3100), ('zymergen', 100, 3101), ('zymergen', 100, 3102)] zymergen
# Zymergen, Inc. [('zymergen', 100, 3098), ('zymergen', 100, 3099), ('zymergen', 100, 3100), ('zymergen', 100, 3101), ('zymergen', 100, 3102)] zymergen
# ZYMERGEN INC. SERIES D PREFERRED STOCK [('zymergen', 100, 3098), ('zymergen', 100, 3099), ('zymergen', 100, 3100), ('zymergen', 100, 3101), ('zymergen', 100, 3102)] zymergen
# ZYMERGEN INC D [('zymergen', 100, 3098), ('zymergen', 100, 3099), ('zymergen', 100, 3100), ('zymergen', 100, 3101), ('zymergen', 100, 3102)] zymergen
# ZYMERGEN, INC [('zymergen', 100, 3098), ('zymergen', 100, 3099), ('zymergen', 100, 3100), ('zymergen', 100, 3101), ('zymergen', 100, 3102)] zymergen
# Zynga Inc. [('zynga', 100, 3104), ('zynga', 100, 3105), ('zynga', 100, 3106), ('zynga', 100, 3107), ('cyngn', 60, 816)] zynga
# ZYNGA INC [('zynga', 100, 3104), ('zynga', 100, 3105), ('zynga', 100, 3106), ('zynga', 100, 3107), ('cyngn', 60, 816)] zynga
# ZYNGA INC   CL A [('zynga', 100, 3104), ('zynga', 100, 3105), ('zynga', 100, 3106), ('zynga', 100, 3107), ('acelyrin', 56, 91)] zynga
# ZYNGA INC COM USD.0000062 [('zynga', 100, 3104), ('zynga', 100, 3105), ('zynga', 100, 3106), ('zynga', 100, 3107), ('bill-com', 55, 367)] zynga

# %%
# Ranked matchings
exact_matches = 0
partial_matches = 0
total_items = len(word_list)
matched = []
partial_matched = []
not_matched = []

for ranked_match_list, expected in zip(matched_companies_full_record, word_list):
    if ranked_match_list:
        first_match = ranked_match_list[0][0][0]  # Get the first-ranked match
        nport_issuer_name = ranked_match_list[1]
        

        # Exact match
        if first_match == expected:
            exact_matches += 1
            matched.append((nport_issuer_name, expected, first_match))
            
        # Partial match (i.e., the expected company appears anywhere else in the ranked list)
        elif any(match[0] == expected for match in ranked_match_list[0]):
            partial_matches += 1
            partial_matched.append((nport_issuer_name, expected, ranked_match_list[0]))
            
        else:
            not_matched.append((nport_issuer_name, expected, ranked_match_list[0]))


exact_match_accuracy = exact_matches / total_items if total_items > 0 else 0
overall_match_accuracy = (exact_matches + partial_matches) / total_items if total_items > 0 else 0


print(f"Total items: {total_items}")
print(f"Number of exact matches: {exact_matches}")
print(f"Number of partial matches: {partial_matches}")
print(f"Exact Match Accuracy: {exact_match_accuracy:.2%}")
print(f"Overall Accuracy (including partial matches): {overall_match_accuracy:.2%}")
# Out:
# Total items: 3108
# Number of exact matches: 2884
# Number of partial matches: 45
# Exact Match Accuracy: 92.79%
# Overall Accuracy (including partial matches): 94.24%

# %%
print("Partial matched items:")
for item in partial_matched:
    print(item)

partial_matched_df = pd.DataFrame(partial_matched, columns=['nport_issuer_name', 'slug', 'rankings'])
partial_matched_df['method'] = 'fuzzy_matched'
partial_matched_df.to_csv('data/partial_matched_fuzzy.csv', index=False)
# Out:
# Partial matched items:
# ('Ant International Co', 'ant-financial', [('zipline-international', 79, 3069), ('zipline-international', 79, 3070), ('ant-financial', 61, 218), ('ant-financial', 61, 219), ('ant-financial', 61, 220)])
# ('Ant International', 'ant-financial', [('zipline-international', 87, 3069), ('zipline-international', 87, 3070), ('ant-financial', 67, 218), ('ant-financial', 67, 219), ('ant-financial', 67, 220)])
# ('ASAPP INC', 'asapp', [('asana', 75, 257), ('asana', 75, 258), ('asana', 75, 259), ('asana', 75, 260), ('asapp', 75, 261)])
# ('Roku, Inc.', 'boku', [('roku', 100, 2314), ('roku', 100, 2315), ('roku', 100, 2316), ('roku', 100, 2317), ('boku', 75, 415)])
# ('Roku Inc', 'boku', [('roku', 100, 2314), ('roku', 100, 2315), ('roku', 100, 2316), ('roku', 100, 2317), ('boku', 75, 415)])
# ('BOLT BIOTHERAPEUTICS INC', 'bolt-biotherapeutics', [('bolt', 100, 418), ('bolt-biotherapeutics', 67, 419), ('bolt-biotherapeutics', 67, 420), ('bolt-biotherapeutics', 67, 421), ('bolt-financial', 67, 422)])
# ('Bolt Biotherapeutics Inc.', 'bolt-biotherapeutics', [('bolt', 100, 418), ('bolt-biotherapeutics', 67, 419), ('bolt-biotherapeutics', 67, 420), ('bolt-biotherapeutics', 67, 421), ('bolt-financial', 67, 422)])
# ('Bolt Biotherapeutics, Inc.', 'bolt-biotherapeutics', [('bolt', 100, 418), ('bolt-biotherapeutics', 67, 419), ('bolt-biotherapeutics', 67, 420), ('bolt-biotherapeutics', 67, 421), ('bolt-financial', 67, 422)])
# ('Bolt Financial Inc', 'bolt-financial', [('bolt', 100, 418), ('bolt-biotherapeutics', 100, 419), ('bolt-biotherapeutics', 100, 420), ('bolt-biotherapeutics', 100, 421), ('bolt-financial', 100, 422)])
# ('BOLT THREADS INC', 'bolt-threads', [('bolt', 100, 418), ('bolt-threads', 100, 423), ('bolt-biotherapeutics', 62, 419), ('bolt-biotherapeutics', 62, 420), ('bolt-biotherapeutics', 62, 421)])
# ('Breeze Aviation Group, Inc. SERIES B', 'breeze-airways', [('joby-aviation', 76, 1532), ('joby-aviation', 76, 1533), ('joby-aviation', 76, 1534), ('breeze-airways', 69, 446), ('breeze-airways', 69, 447)])
# ('Breeze Aviation Group, Inc., Series B', 'breeze-airways', [('joby-aviation', 76, 1532), ('joby-aviation', 76, 1533), ('joby-aviation', 76, 1534), ('breeze-airways', 69, 446), ('breeze-airways', 69, 447)])
# ('C4 THERAPEUTICS SER B CVT PF', 'c4-therapeutics', [('cross-river-bank', 45, 786), ('cross-river-bank', 45, 787), ('cross-river-bank', 45, 788), ('cross-river-bank', 45, 789), ('c4-therapeutics', 40, 483)])
# ('Carbon Black Inc', 'carbon-black', [('carbon', 100, 522), ('carbon', 100, 523), ('carbon', 100, 524), ('carbon-black', 100, 525), ('carbon-black', 100, 526)])
# ('Carbon Black Inc.', 'carbon-black', [('carbon', 100, 522), ('carbon', 100, 523), ('carbon', 100, 524), ('carbon-black', 100, 525), ('carbon-black', 100, 526)])
# ('Carbon Black, Inc.', 'carbon-black', [('carbon', 100, 522), ('carbon', 100, 523), ('carbon', 100, 524), ('carbon-black', 100, 525), ('carbon-black', 100, 526)])
# ('CARBON HEALTH TECHNOLOGIES INC', 'carbon-health', [('carbon', 100, 522), ('carbon', 100, 523), ('carbon', 100, 524), ('carbon-health', 100, 528), ('carbon-health', 100, 529)])
# ('Carbon Health Technologies Inc.', 'carbon-health', [('carbon', 100, 522), ('carbon', 100, 523), ('carbon', 100, 524), ('carbon-health', 100, 528), ('carbon-health', 100, 529)])
# ('CONTRA CINCOR PHARMA I COMMON STOCK', 'cincor-pharma', [('pmv-pharma', 75, 30), ('pmv-pharma', 75, 31), ('pmv-pharma', 75, 2086), ('pact-pharma', 71, 1966), ('cincor-pharma', 63, 644)])
# ('CIRCLE COMMON SHARES COMMON SHARES   /', 'circle-internet-financial', [('lemonade', 50, 1604), ('lemonade', 50, 1605), ('lemonade', 50, 1606), ('circle-internet-financial', 49, 649), ('circle-internet-financial', 49, 650)])
# ('COMPASS THERAPEUTICS INC', 'compass-therapeutics', [('compass', 100, 716), ('compass', 100, 717), ('compass', 100, 718), ('compass', 100, 719), ('compass-therapeutics', 100, 720)])
# ('LEARNEO, INC. (F.K.A. COURSE HERO, INC.) COMMON SHARES   /', 'couse-hero', [('course-hero', 100, 772), ('course-hero', 100, 773), ('course-hero', 100, 774), ('course-hero', 100, 775), ('couse-hero', 57, 779)])
# ('COURSE HERO, INC. COMMON SHARES   /', 'couse-hero', [('course-hero', 100, 772), ('course-hero', 100, 773), ('course-hero', 100, 774), ('course-hero', 100, 775), ('couse-hero', 57, 779)])
# ('D-WAVE QUANTUM INC', 'd-wave-systems', [('quantumscape', 69, 2157), ('quantumscape', 69, 2158), ('quantumscape', 69, 2159), ('quantumscape', 69, 2160), ('d-wave-systems', 64, 821)])
# ('DAPPER LABS INC SERIES 7', 'dapper-labs', [('pax-labs', 67, 2001), ('pax-labs', 67, 2002), ('pax-labs', 67, 2003), ('pax-labs', 67, 2004), ('dapper-labs', 62, 822)])
# ('FOG PHARMACEUTICALS INC', 'fogpharma', [('jfrog', 75, 1529), ('jfrog', 75, 1530), ('kong', 57, 1570), ('fogpharma', 50, 1189), ('fogpharma', 50, 1190)])
# ('Fog Pharmaceuticals Series C Cvt Pfd Pp', 'fogpharma', [('moda-operandi-inc', 43, 1751), ('pyxis-oncology', 40, 32), ('fogpharma', 40, 1189), ('fogpharma', 40, 1190), ('pyxis-oncology', 40, 2150)])
# ('Maplebear Inc Dba Instac /Pfd/', 'instacart', [('moda-operandi-inc', 49, 1751), ('instacart', 48, 1484), ('instacart', 48, 1485), ('instacart', 48, 1486), ('instacart', 48, 1487)])
# ('MODA OPERANDI INC', 'moda-operandi-inc', [('moda-operandi', 100, 1750), ('moda-operandi-inc', 100, 1751), ('moderna', 60, 1752), ('moderna', 60, 1753), ('moderna', 60, 1754)])
# ('OWLET BABY CARE INC', 'owlet-baby-care', [('care', 100, 533), ('care', 100, 534), ('care', 100, 535), ('owlet-baby-care', 100, 1952), ('owlet-baby-care', 100, 1953)])
# ('PDD HOLDINGS INC', 'pinduoduo', [('dstld', 50, 1023), ('pinduoduo', 50, 2039), ('pinduoduo', 50, 2040), ('pinduoduo', 50, 2041), ('pinduoduo', 50, 2042)])
# ('PDD Holdings Inc.', 'pinduoduo', [('dstld', 50, 1023), ('pinduoduo', 50, 2039), ('pinduoduo', 50, 2040), ('pinduoduo', 50, 2041), ('pinduoduo', 50, 2042)])
# ('Rappi Inc - Series E', 'rappi', [('grail', 75, 1321), ('rappi', 75, 2182), ('rappi', 75, 2183), ('rappi', 75, 2184), ('rappi', 75, 2185)])
# ('Recode Therapeutics', 'recode-therapeutics', [('ReCode Therapeutics, Inc.', 100, 2194), ('recode-therapeutics', 100, 2195), ('veracode', 71, 2888), ('veracode', 71, 2889), ('carecloud', 67, 536)])
# ('REDDIT INC', 'reddit-inc', [('reddit', 100, 2200), ('reddit-inc', 100, 2201), ('redfin', 67, 2202), ('redfin', 67, 2203), ('redfin', 67, 2204)])
# ('RING THERAPEUTICS SER C CVT PFD STK PP,,,,', 'ring-therapeutics', [('ring', 100, 2260), ('ring', 100, 2261), ('ring-therapeutics', 46, 2262), ('pinterest', 45, 2046), ('pinterest', 45, 2047)])
# ('Shift Technologies Inc', 'shift-technology', [('shift-cars', 100, 2425), ('shift-cars', 100, 2426), ('shift-cars', 100, 2427), ('shift-technology', 100, 2428), ('shopify', 67, 2429)])
# ('Spruce Power Holding Corp.', 'spruce-finance', [('romeo-power', 62, 2318), ('solid-power', 62, 2528), ('spruce-finance', 60, 2574), ('spruce-finance', 60, 2575), ('brain-corp', 57, 435)])
# ('SPRUCE POWER HOLDING CORP', 'spruce-finance', [('romeo-power', 62, 2318), ('solid-power', 62, 2528), ('spruce-finance', 60, 2574), ('spruce-finance', 60, 2575), ('brain-corp', 57, 435)])
# ('TEBRA TECHNOLOGIES, INC. (F.K.A. KAREO, INC.) SERIES SEED 2   /', 'tebra', [('kareo', 100, 1549), ('kareo', 100, 1550), ('kareo', 100, 1551), ('kareo', 100, 1552), ('tebra', 100, 2688)])
# ('TEBRA TECHNOLOGIES, INC. (F.K.A. KAREO, INC.) COMMON SHARES   /', 'tebra', [('kareo', 100, 1549), ('kareo', 100, 1550), ('kareo', 100, 1551), ('kareo', 100, 1552), ('tebra', 100, 2688)])
# ('The Honest Company Inc.', 'the-honest-company', [('the-honest-company-inc', 100, 39), ('the-honest-company', 100, 2738), ('the-honest-company', 100, 2739), ('the-honest-company', 100, 2740), ('the-honest-company', 100, 2741)])
# ('The Honest Company, Inc.', 'the-honest-company', [('the-honest-company-inc', 100, 39), ('the-honest-company', 100, 2738), ('the-honest-company', 100, 2739), ('the-honest-company', 100, 2740), ('the-honest-company', 100, 2741)])
# ('THE HONEST COMPANY INC', 'the-honest-company', [('the-honest-company-inc', 100, 39), ('the-honest-company', 100, 2738), ('the-honest-company', 100, 2739), ('the-honest-company', 100, 2740), ('the-honest-company', 100, 2741)])
# ('THE HONEST COMPANY SERIES D', 'the-honest-company', [('the-honest-company-inc', 100, 39), ('the-honest-company', 100, 2738), ('the-honest-company', 100, 2739), ('the-honest-company', 100, 2740), ('the-honest-company', 100, 2741)])
# ('Wide Orbit, Inc. Wide Orbit /', 'wideorbit', [('virgin-orbit', 67, 2901), ('virgin-orbit', 67, 2902), ('wideorbit', 53, 2976), ('criteo', 50, 782), ('criteo', 50, 783)])

# %%
# Function to filter duplicates while keeping the highest score for each unique name
def filter_unique_matches(ranked_matches):
    unique_ranked_matches = {}
    for match in ranked_matches:
        if match[0] not in unique_ranked_matches or unique_ranked_matches[match[0]][1] < match[1]:
            unique_ranked_matches[match[0]] = match
    return list(unique_ranked_matches.values())

# Apply the filtering to create a new column with filtered matches in partial_matched
filtered_partial_matches = [
    (nport_issuer_name, expected, ranked_list, filter_unique_matches(ranked_list))
    for nport_issuer_name, expected, ranked_list in partial_matched
]

# Create DataFrame with both original and filtered matches
partial_matched_df = pd.DataFrame(filtered_partial_matches, columns=['nport_issuer_name', 'slug', 'rankings', 'filtered_rankings'])
partial_matched_df['method'] = 'fuzzy_matched'
partial_matched_df.to_csv('data/partial_matched_fuzzy.csv', index=False)

# %%
print(f"Number of not matches: {len(not_matched)}")
print("Not matched items:")
for item in not_matched:
    print(item)
# Out:
# Number of not matches: 176
# Not matched items:
# ('Think & Learn Private Ltd.', 'byju-s', [('clear-street', 46, 659), ('clear-street', 46, 660), ('clear-street', 46, 661), ('lanzatech', 44, 1587), ('lanzatech', 44, 1588)])
# ('DOOR DASH', 'doordash', [('honor', 57, 1411), ('honor', 57, 1412), ('honor', 57, 1413), ('honor', 57, 1414), ('honor', 57, 1415)])
# ('NEOGEN CORPORATION', 'neogene-therapeutics', [('neurogene', 80, 1812), ('neurogene', 80, 1813), ('neurogene', 80, 1814), ('heliogen', 71, 1401), ('heliogen', 71, 1402)])
# ('RAPPORT THERAPEUTICS INC', 'rapport-therapeutics', [('rover', 60, 2323), ('rover', 60, 2324), ('rover', 60, 2325), ('rover', 60, 2326), ('rover', 60, 2327)])
# ('JAND INC', 'warby-parker', [('xad', 57, 3001), ('23andme', 55, 59), ('23andme', 55, 60), ('23andme', 55, 61), ('23andme', 55, 62)])
# ('Life Healthcare Group Holdings Ltd', '1life-healthcare', [('trisalus-life-sciences', 67, 41), ('verily-life-sciences', 67, 44), ('caris-life-sciences', 67, 546), ('caris-life-sciences', 67, 547), ('caris-life-sciences', 67, 548)])
# ('Nauticus Robotics, Inc.', '3d-robotics', [('fanatics', 75, 1124), ('fanatics', 75, 1125), ('fanatics', 75, 1126), ('fanatics', 75, 1127), ('fanatics', 75, 1128)])
# ('NEXTROLL, INC. COMMON SHARES   /', 'adroll', [('nextroll', 100, 1837), ('nextroll', 100, 1838), ('nextdoor-com', 53, 1826), ('nextdoor-com', 53, 1827), ('nextdoor-com', 53, 1828)])
# ('NEXTROLL COMMON SHARES   /', 'adroll', [('nextroll', 100, 1837), ('nextroll', 100, 1838), ('nextdoor-com', 53, 1826), ('nextdoor-com', 53, 1827), ('nextdoor-com', 53, 1828)])
# ('Nextroll, Inc. Shares /', 'adroll', [('nextroll', 100, 1837), ('nextroll', 100, 1838), ('nextracker', 56, 1833), ('nextracker', 56, 1834), ('nextracker', 56, 1835)])
# ('Candel Therapeutics Inc.', 'advantagene', [('23andme', 62, 59), ('23andme', 62, 60), ('23andme', 62, 61), ('23andme', 62, 62), ('23andme', 62, 63)])
# ('CANDEL THERAPEUTICS INC', 'advantagene', [('23andme', 62, 59), ('23andme', 62, 60), ('23andme', 62, 61), ('23andme', 62, 62), ('23andme', 62, 63)])
# ('Formagrid Inc Ser F C', 'airtable', [('coursera', 48, 776), ('coursera', 48, 777), ('coursera', 48, 778), ('workrise', 48, 3000), ('contrast-security', 47, 733)])
# ('Formagrid Inc Ser F Cvt Pfd Pp', 'airtable', [('caris-life-sciences', 43, 546), ('caris-life-sciences', 43, 547), ('caris-life-sciences', 43, 548), ('caris-life-sciences', 43, 549), ('caris-life-sciences', 43, 550)])
# ('Formagrid Inc Ser F Cvt /Pfd/', 'airtable', [('caris-life-sciences', 43, 546), ('caris-life-sciences', 43, 547), ('caris-life-sciences', 43, 548), ('caris-life-sciences', 43, 549), ('caris-life-sciences', 43, 550)])
# ('Ant Group Co Ltd', 'ant-financial', [('accolade', 56, 88), ('accolade', 56, 89), ('accolade', 56, 90), ('voltron-data', 55, 2919), ('voltron-data', 55, 2920)])
# ('Ant International Co. Limited', 'ant-financial', [('zipline-international', 76, 3069), ('zipline-international', 76, 3070), ('line-corporation', 55, 22), ('integral-ad-science', 51, 1506), ('integral-ad-science', 51, 1507)])
# ('Ant International Co. Limited Class C Shares', 'ant-financial', [('zipline-international', 76, 3069), ('zipline-international', 76, 3070), ('bark-co', 44, 333), ('bark-co', 44, 334), ('integral-ad-science', 42, 1506)])
# ('AppLovin Corp.', 'applovin', [('brain-corp', 76, 435), ('brain-corp', 76, 436), ('brain-corp', 76, 437), ('brain-corp', 76, 438), ('brain-corp', 76, 439)])
# ('APPLOVIN CORP', 'applovin', [('brain-corp', 76, 435), ('brain-corp', 76, 436), ('brain-corp', 76, 437), ('brain-corp', 76, 438), ('brain-corp', 76, 439)])
# ('APPLOVIN CORP-CLASS A', 'applovin', [('brain-corp', 57, 435), ('brain-corp', 57, 436), ('brain-corp', 57, 437), ('brain-corp', 57, 438), ('brain-corp', 57, 439)])
# ('Tyra Biosciences, Inc.', 'aura-biosciences', [('tyra-biosciences', 80, 2821), ('tyra-biosciences', 80, 2822), ('tyra-biosciences', 80, 2823), ('astranis', 57, 268), ('astranis', 57, 269)])
# ('BARKBOX, INC. RESTRICTED P', 'bark-co', [('darktrace', 48, 823), ('darktrace', 48, 824), ('starling-bank', 48, 2589), ('markforged', 47, 1683), ('markforged', 47, 1684)])
# ('PhenomeX Inc', 'berkeley-lights', [('phantom', 67, 27), ('phantom', 67, 28), ('phantom', 67, 29), ('freenome', 62, 1206), ('freenome', 62, 1207)])
# ('PhenomeX Inc.', 'berkeley-lights', [('phantom', 67, 27), ('phantom', 67, 28), ('phantom', 67, 29), ('freenome', 62, 1206), ('freenome', 62, 1207)])
# ('BETA TECHNOLOGIES INC', 'beta-technologies', [('beta-bionics', 100, 341), ('beta-bionics', 100, 342), ('beta-bionics', 100, 343), ('beta-bionics', 100, 344), ('beta-bionics', 100, 345)])
# ('BETA TECHNOLOGIES, INC. SERIES A   /', 'beta-technologies', [('beta-bionics', 100, 341), ('beta-bionics', 100, 342), ('beta-bionics', 100, 343), ('beta-bionics', 100, 344), ('beta-bionics', 100, 345)])
# ('BETA TECHNOLOGIES SERIES A   /', 'beta-technologies', [('beta-bionics', 100, 341), ('beta-bionics', 100, 342), ('beta-bionics', 100, 343), ('beta-bionics', 100, 344), ('beta-bionics', 100, 345)])
# ('BETA TECHNOLOGIES, INC. PREFERRED SERIES B   /', 'beta-technologies', [('rad-power-bikes', 55, 2166), ('rad-power-bikes', 55, 2167), ('rad-power-bikes', 55, 2168), ('rad-power-bikes', 55, 2169), ('rad-power-bikes', 55, 2170)])
# ('Beta Technologies, Inc. Series A /', 'beta-technologies', [('beta-bionics', 100, 341), ('beta-bionics', 100, 342), ('beta-bionics', 100, 343), ('beta-bionics', 100, 344), ('beta-bionics', 100, 345)])
# ('Beta Technologies, Inc. Series B /', 'beta-technologies', [('beta-bionics', 100, 341), ('beta-bionics', 100, 342), ('beta-bionics', 100, 343), ('beta-bionics', 100, 344), ('beta-bionics', 100, 345)])
# ('Blend Labs Inc', 'blend-labs', [('blend', 100, 387), ('blend', 100, 388), ('blend', 100, 389), ('blend', 100, 390), ('blend', 100, 391)])
# ('Blend Labs, Inc.', 'blend-labs', [('blend', 100, 387), ('blend', 100, 388), ('blend', 100, 389), ('blend', 100, 390), ('blend', 100, 391)])
# ('BLEND LABS COMMON SHARES   /', 'blend-labs', [('blend', 100, 387), ('blend', 100, 388), ('blend', 100, 389), ('blend', 100, 390), ('blend', 100, 391)])
# ('Blend Labs Inc.', 'blend-labs', [('blend', 100, 387), ('blend', 100, 388), ('blend', 100, 389), ('blend', 100, 390), ('blend', 100, 391)])
# ('BLEND LABS INC A', 'blend-labs', [('blend', 100, 387), ('blend', 100, 388), ('blend', 100, 389), ('blend', 100, 390), ('blend', 100, 391)])
# ('Think &Amp; Learn Sr F Cvt Cum Pref Shs Stk Pp', 'byju-s', [('clear-street', 34, 659), ('clear-street', 34, 660), ('clear-street', 34, 661), ('mynd-property-management', 34, 1778), ('mynd-property-management', 34, 1779)])
# ('4D Molecular Therapeutics, Inc.', 'c4-therapeutics', [('4d-molecular-therapeutics-4dmt', 100, 69), ('4d-molecular-therapeutics-4dmt', 100, 70), ('4d-molecular-therapeutics-4dmt', 100, 71), ('4d-molecular-therapeutics-4dmt', 100, 72), ('molekule', 60, 1756)])
# ('C4 THERAPEUTICS LOCKUP SHS', 'c4-therapeutics', [('compass', 50, 716), ('compass', 50, 717), ('compass', 50, 718), ('compass', 50, 719), ('ownbackup', 45, 1954)])
# ('HEALTH CARE', 'centrexion-therapeutics', [('care', 100, 533), ('care', 100, 534), ('care', 100, 535), ('cue-health', 86, 803), ('cue-health', 86, 804)])
# ('CIBO TECHNOLOGIES, INC. PREFERRED SERIES C   /', 'cibo-technologies', [('fireeye', 48, 1151), ('fireeye', 48, 1152), ('fireeye', 48, 1153), ('rad-power-bikes', 48, 2166), ('rad-power-bikes', 48, 2167)])
# ('CINCOR', 'cincor-pharma', [('discord', 60, 926), ('discord', 60, 927), ('discord', 60, 928), ('discord', 60, 929), ('discord', 60, 930)])
# ('THEMIS SOLUTIONS INC PP', 'clio', [('stem', 67, 2609), ('stem', 67, 2610), ('stem', 67, 2611), ('stem', 67, 2612), ('stem', 67, 2613)])
# ('Coupa Software Inc', 'coupa-software', [('coupa', 100, 755), ('coupa', 100, 756), ('coupa', 100, 757), ('coupa', 100, 758), ('coupa', 100, 759)])
# ('COUPA SOFTWARE INCORPORATED', 'coupa-software', [('coupa', 100, 755), ('coupa', 100, 756), ('coupa', 100, 757), ('coupa', 100, 758), ('coupa', 100, 759)])
# ('COUPA SOFTWARE INC COM USD.0001', 'coupa-software', [('coupa', 100, 755), ('coupa', 100, 756), ('coupa', 100, 757), ('coupa', 100, 758), ('coupa', 100, 759)])
# ('Coupa Software Inc.', 'coupa-software', [('coupa', 100, 755), ('coupa', 100, 756), ('coupa', 100, 757), ('coupa', 100, 758), ('coupa', 100, 759)])
# ('CRB Group Inc', 'cross-river-bank', [('carbon', 67, 522), ('carbon', 67, 523), ('carbon', 67, 524), ('care', 57, 533), ('care', 57, 534)])
# ('Crb Group Inc Pp', 'cross-river-bank', [('carbon', 67, 522), ('carbon', 67, 523), ('carbon', 67, 524), ('care', 57, 533), ('care', 57, 534)])
# ('Crv Group Series D Cvt Pfd Pp', 'cross-river-bank', [('acv-auctions', 43, 100), ('acv-auctions', 43, 101), ('acv-auctions', 43, 102), ('acv-auctions', 43, 103), ('acv-auctions', 43, 104)])
# ('Crb Group Series D Cvt', 'cross-river-bank', [('carbon-health', 50, 528), ('carbon-health', 50, 529), ('cvent', 50, 806), ('cvent', 50, 807), ('chartboost', 47, 610)])
# ('DATAMINR INC', 'dataminr-inc', [('dataminr', 100, 845), ('dataminr', 100, 846), ('dataminr', 100, 847), ('dataminr', 100, 848), ('dataminr', 100, 849)])
# ('DATAMINR, INC. SERIES A   /', 'dataminr-inc', [('dataminr', 100, 845), ('dataminr', 100, 846), ('dataminr', 100, 847), ('dataminr', 100, 848), ('dataminr', 100, 849)])
# ('DATAMINR, INC. COMMON SHARES   /', 'dataminr-inc', [('dataminr', 100, 845), ('dataminr', 100, 846), ('dataminr', 100, 847), ('dataminr', 100, 848), ('dataminr', 100, 849)])
# ('DATAMINR, INC. SERIES B   /', 'dataminr-inc', [('dataminr', 100, 845), ('dataminr', 100, 846), ('dataminr', 100, 847), ('dataminr', 100, 848), ('dataminr', 100, 849)])
# ('ROOFOODS LIMITED', 'deliveroo', [('lightspeed-pos', 53, 1614), ('lightspeed-pos', 53, 1615), ('lightspeed-pos', 53, 1616), ('lightspeed-pos', 53, 1617), ('lightspeed-pos', 53, 1618)])
# ('DIGITAL BRANDS GROUP INC', 'dstld', [('digital-ocean', 74, 916), ('digital-ocean', 74, 917), ('digital-ocean', 74, 918), ('proteus-digital-health', 67, 2130), ('internet-brands', 62, 1511)])
# ('Tenaya Therapeutics, Inc.', 'entrada-therapeutics', [('tenaya-therapeutics', 100, 2719), ('tenaya-therapeutics', 100, 2720), ('tenaya-therapeutics', 100, 2721), ('genapsys', 57, 1236), ('genapsys', 57, 1237)])
# ('META PLATFORMS INC', 'facebook', [('meta', 100, 1724), ('meta', 100, 1725), ('meta', 100, 1726), ('meta', 100, 1727), ('clear-labs', 50, 657)])
# ('West Realm Shires Services Inc', 'ftx-us', [('servicetitan', 47, 35), ('abl-space-systems', 47, 80), ('abl-space-systems', 47, 81), ('abl-space-systems', 47, 82), ('abl-space-systems', 47, 83)])
# ('West Realmshires Services Inc', 'ftx-us', [('american-well', 47, 189), ('american-well', 47, 190), ('american-well', 47, 191), ('american-well', 47, 192), ('american-well', 47, 193)])
# ('West Realm Shires Inc', 'ftx-us', [('the-realreal', 55, 2745), ('the-realreal', 55, 2746), ('the-realreal', 55, 2747), ('the-realreal', 55, 2748), ('the-realreal', 55, 2749)])
# ('1661, Inc.', 'goat', [('1stdibs', 18, 56), ('1stdibs', 18, 57), ('1stdibs', 18, 58), ('10x-genomics-inc', 10, 48), ('10x-genomics-inc', 10, 49)])
# ('GOBRANDS INC', 'gopuff', [('outbrain', 62, 1948), ('outbrain', 62, 1949), ('outbrain', 62, 1950), ('grand-rounds', 60, 1326), ('grand-rounds', 60, 1327)])
# ('Included Health, Inc.', 'grand-rounds', [('k-health', 86, 1544), ('k-health', 86, 1545), ('cue-health', 82, 803), ('cue-health', 82, 804), ('cue-health', 82, 805)])
# ('GROUPON INC', 'groupon', [('ionq', 67, 1515), ('ionq', 67, 1516), ('ionq', 67, 1517), ('kong', 67, 1570), ('on24', 67, 1917)])
# ('Groupon Inc.', 'groupon', [('ionq', 67, 1515), ('ionq', 67, 1516), ('ionq', 67, 1517), ('kong', 67, 1570), ('on24', 67, 1917)])
# ('GROUPON INC COMMON STOCK USD.0001', 'groupon', [('commonbond', 53, 714), ('commonbond', 53, 715), ('roofstock', 42, 2319), ('roofstock', 42, 2320), ('roofstock', 42, 2321)])
# ('GROUPON, INC.', 'groupon', [('ionq', 67, 1515), ('ionq', 67, 1516), ('ionq', 67, 1517), ('kong', 67, 1570), ('on24', 67, 1917)])
# ('ZENPAYROLL INC', 'gusto', [('adroll', 62, 116), ('adroll', 62, 117), ('adroll', 62, 118), ('nextroll', 56, 1837), ('nextroll', 56, 1838)])
# ('Zenpayroll Inc Pp', 'gusto', [('adroll', 62, 116), ('adroll', 62, 117), ('adroll', 62, 118), ('nextroll', 56, 1837), ('nextroll', 56, 1838)])
# ('Zenpayroll Inc Cvt Pfd Ser C Pp', 'gusto', [('clover-health', 43, 681), ('clover-health', 43, 682), ('clover-health', 43, 683), ('clover-health', 43, 684), ('tenable-network-security', 42, 36)])
# ('Zenpayroll Inc Ser B Cvt Pfd Pp', 'gusto', [('clover-health', 43, 681), ('clover-health', 43, 682), ('clover-health', 43, 683), ('clover-health', 43, 684), ('tenable-network-security', 42, 36)])
# ('Zenpayroll Inc Ser B-2 Cvt Pfd Pp', 'gusto', [('clover-health', 41, 681), ('clover-health', 41, 682), ('clover-health', 41, 683), ('clover-health', 41, 684), ('tenable-network-security', 40, 36)])
# ('Zenpayroll Inc Cvt Pfd Ser', 'gusto', [('clover-health', 46, 681), ('clover-health', 46, 682), ('clover-health', 46, 683), ('clover-health', 46, 684), ('couse-hero', 44, 779)])
# ('Zenpayroll Inc Ser B 2', 'gusto', [('tenable-network-security', 43, 36), ('tenable-network-security', 43, 37), ('tenable-network-security', 43, 38), ('couse-hero', 43, 779), ('couse-hero', 43, 780)])
# ('Zenpayroll Inc Ser B Cvt', 'gusto', [('clover-health', 48, 681), ('clover-health', 48, 682), ('clover-health', 48, 683), ('clover-health', 48, 684), ('couse-hero', 47, 779)])
# ('OPEN TEXT CORP (ONTARIO)', 'hightail', [('brain-corp', 57, 435), ('brain-corp', 57, 436), ('brain-corp', 57, 437), ('brain-corp', 57, 438), ('brain-corp', 57, 439)])
# ('Open Text Corp', 'hightail', [('brain-corp', 57, 435), ('brain-corp', 57, 436), ('brain-corp', 57, 437), ('brain-corp', 57, 438), ('brain-corp', 57, 439)])
# ('Open Text Corp.', 'hightail', [('brain-corp', 57, 435), ('brain-corp', 57, 436), ('brain-corp', 57, 437), ('brain-corp', 57, 438), ('brain-corp', 57, 439)])
# ('Criteo SA', 'hooklogic', [('criteo', 100, 782), ('criteo', 100, 783), ('criteo', 100, 784), ('criteo', 100, 785), ('freightos', 56, 1215)])
# ('CRITEO SA SPON ADR', 'hooklogic', [('criteo', 100, 782), ('criteo', 100, 783), ('criteo', 100, 784), ('criteo', 100, 785), ('integral-ad-science', 49, 1506)])
# ('Criteo S.A.', 'hooklogic', [('criteo', 100, 782), ('criteo', 100, 783), ('criteo', 100, 784), ('criteo', 100, 785), ('acronis', 59, 94)])
# ('Criteo S.A', 'hooklogic', [('criteo', 100, 782), ('criteo', 100, 783), ('criteo', 100, 784), ('criteo', 100, 785), ('acronis', 59, 94)])
# ('Thayer Ventures Acquisition Co', 'inspirato', [('centrexion-therapeutics', 49, 7), ('centrexion-therapeutics', 49, 596), ('centrexion-therapeutics', 49, 597), ('centrexion-therapeutics', 49, 598), ('centrexion-therapeutics', 49, 599)])
# ('MAPLEBEAR INC', 'instacart', [('applyboard', 63, 239), ('malwarebytes', 57, 1674), ('malwarebytes', 57, 1675), ('malwarebytes', 57, 1676), ('malwarebytes', 57, 1677)])
# ('Maplebear Inc. Dba Ins /Pfd/', 'instacart', [('rad-power-bikes', 50, 2166), ('rad-power-bikes', 50, 2167), ('rad-power-bikes', 50, 2168), ('rad-power-bikes', 50, 2169), ('rad-power-bikes', 50, 2170)])
# ('Mh Sub I Llc', 'internet-brands', [('MH Sub I, LLC', 100, 1738), ('MH Sub I, LLC', 100, 1739), ('hims', 50, 1410), ('icims', 46, 1441), ('mcube', 46, 1704)])
# ('Mh Sub I, Llc', 'internet-brands', [('MH Sub I, LLC', 100, 1738), ('MH Sub I, LLC', 100, 1739), ('hims', 50, 1410), ('icims', 46, 1441), ('mcube', 46, 1704)])
# ('Mh Sub I, Llc (Micro Holding Corp.)', 'internet-brands', [('MH Sub I, LLC', 80, 1738), ('MH Sub I, LLC', 80, 1739), ('brain-corp', 57, 435), ('brain-corp', 57, 436), ('brain-corp', 57, 437)])
# ('Mh Sub I Llc / Micro Holding Corp.', 'internet-brands', [('MH Sub I, LLC', 80, 1738), ('MH Sub I, LLC', 80, 1739), ('brain-corp', 57, 435), ('brain-corp', 57, 436), ('brain-corp', 57, 437)])
# ('PAX LABS INC', 'juul', [('pax-labs', 100, 2001), ('pax-labs', 100, 2002), ('pax-labs', 100, 2003), ('pax-labs', 100, 2004), ('nova-labs', 71, 1848)])
# ('Bright Health Group Inc.', 'k-health', [('bright-health', 100, 2), ('bright-health', 100, 449), ('bright-health', 100, 450), ('bright-health', 100, 451), ('bright-health', 100, 452)])
# ('Bright Health Group Inc', 'k-health', [('bright-health', 100, 2), ('bright-health', 100, 449), ('bright-health', 100, 450), ('bright-health', 100, 451), ('bright-health', 100, 452)])
# ('NEUTRON HOLDINGS INC', 'lime', [('neurogene', 75, 1812), ('neurogene', 75, 1813), ('neurogene', 75, 1814), ('nuro', 73, 1852), ('nuro', 73, 1853)])
# ('MPMLOCUS3', 'locus-robotics', [('jumpcloud', 56, 1535), ('jumpcloud', 56, 1536), ('jumpcloud', 56, 1537), ('jumpcloud', 56, 1538), ('moloco', 53, 1758)])
# ('YANKA INDUSTRIES INC', 'masterclass', [('asana', 60, 257), ('asana', 60, 258), ('asana', 60, 259), ('asana', 60, 260), ('canva', 60, 494)])
# ('Movella Holdings, Inc.', 'mcube', [('medallia', 67, 1709), ('medallia', 67, 1710), ('medallia', 67, 1711), ('medallia', 67, 1712), ('ola', 60, 1899)])
# ('MOVELLA INC', 'mcube', [('medallia', 67, 1709), ('medallia', 67, 1710), ('medallia', 67, 1711), ('medallia', 67, 1712), ('ola', 60, 1899)])
# ('MOVELLA HOLDINGS INC', 'mcube', [('medallia', 67, 1709), ('medallia', 67, 1710), ('medallia', 67, 1711), ('medallia', 67, 1712), ('ola', 60, 1899)])
# ('Movella Holdings Inc.', 'mcube', [('medallia', 67, 1709), ('medallia', 67, 1710), ('medallia', 67, 1711), ('medallia', 67, 1712), ('ola', 60, 1899)])
# ('Singlestore, Inc. Shares /', 'memsql', [('pure-storage', 53, 2145), ('pure-storage', 53, 2146), ('pure-storage', 53, 2147), ('pure-storage', 53, 2148), ('pure-storage', 53, 2149)])
# ('D2IQ, INC.  COMMON SHARES   /', 'mesosphere', [('monday-com', 57, 1762), ('monday-com', 57, 1763), ('monday-com', 57, 1764), ('code42-software', 55, 690), ('commonbond', 50, 714)])
# ('D2iQ COMMON SHARES   /', 'mesosphere', [('monday-com', 57, 1762), ('monday-com', 57, 1763), ('monday-com', 57, 1764), ('code42-software', 55, 690), ('commonbond', 50, 714)])
# ('MOBILE IRON INC', 'mobileiron', [('blue-apron', 67, 409), ('blue-apron', 67, 410), ('blue-apron', 67, 411), ('blue-apron', 67, 412), ('metromile', 60, 1734)])
# ('Zeenk Inc Pp', 'nanigans', [('zendesk', 67, 3054), ('zendesk', 67, 3055), ('zendesk', 67, 3056), ('zendesk', 67, 3057), ('zymergen', 62, 3098)])
# ('Zeenk Warrant Pp', 'nanigans', [('advantagene', 50, 119), ('advantagene', 50, 120), ('guardant-health', 50, 1355), ('guardant-health', 50, 1356), ('guardant-health', 50, 1357)])
# ('NEXTDOOR.COM PERFERRED SERIES E   /', 'nextdoor-com', [('nextdoor', 100, 1820), ('nextdoor', 100, 1821), ('nextdoor', 100, 1822), ('nextdoor', 100, 1823), ('nextdoor', 100, 1824)])
# ('NEXTDOOR.COM  PERFERRED SERIES B   /', 'nextdoor-com', [('nextdoor', 100, 1820), ('nextdoor', 100, 1821), ('nextdoor', 100, 1822), ('nextdoor', 100, 1823), ('nextdoor', 100, 1824)])
# ('NEXTDOOR.COM  PERFERRED SERIES D   /', 'nextdoor-com', [('nextdoor', 100, 1820), ('nextdoor', 100, 1821), ('nextdoor', 100, 1822), ('nextdoor', 100, 1823), ('nextdoor', 100, 1824)])
# ('NEXTDOOR.COM  PERFERRED SERIES C   /', 'nextdoor-com', [('nextdoor', 100, 1820), ('nextdoor', 100, 1821), ('nextdoor', 100, 1822), ('nextdoor', 100, 1823), ('nextdoor', 100, 1824)])
# ('NEXTDOOR.COM PERFERRED SERIES F   /', 'nextdoor-com', [('nextdoor', 100, 1820), ('nextdoor', 100, 1821), ('nextdoor', 100, 1822), ('nextdoor', 100, 1823), ('nextdoor', 100, 1824)])
# ('New York Digital Investment Group LLC', 'nydig', [('digital-ocean', 70, 916), ('digital-ocean', 70, 917), ('digital-ocean', 70, 918), ('farmer-s-business-network', 50, 1133), ('farmer-s-business-network', 50, 1134)])
# ('New York Digital  Investment Group LLC', 'nydig', [('digital-ocean', 70, 916), ('digital-ocean', 70, 917), ('digital-ocean', 70, 918), ('farmer-s-business-network', 50, 1133), ('farmer-s-business-network', 50, 1134)])
# ('ANI Technologies Pvt Ltd', 'ola', [('rani-therapeutics', 50, 2172), ('rani-therapeutics', 50, 2173), ('rani-therapeutics', 50, 2174), ('angieslist', 48, 213), ('apnimed', 44, 231)])
# ('ANI Technologies Pvt Ltd.', 'ola', [('rani-therapeutics', 50, 2172), ('rani-therapeutics', 50, 2173), ('rani-therapeutics', 50, 2174), ('angieslist', 48, 213), ('apnimed', 44, 231)])
# ('Ani Technologies Pvt', 'ola', [('mandiant', 53, 1678), ('mandiant', 53, 1679), ('mandiant', 53, 1680), ('mandiant', 53, 1681), ('attentive', 50, 282)])
# ('Ani Technologies Pvt .', 'ola', [('mandiant', 53, 1678), ('mandiant', 53, 1679), ('mandiant', 53, 1680), ('mandiant', 53, 1681), ('attentive', 50, 282)])
# ('Open Door Inc.', 'opendoor', [('openx', 57, 1933), ('openx', 57, 1934), ('green-dot', 56, 1338), ('green-dot', 56, 1339), ('green-dot', 56, 1340)])
# ('Oric Pharmaceuticals Inc Series D Preferred', 'oric-pharmaceuticals', [('verge-genomics', 50, 43), ('reddit-inc', 50, 2201), ('fireeye', 48, 1151), ('fireeye', 48, 1152), ('fireeye', 48, 1153)])
# ('ORIC Pharmaceuticals Inc COM USD.0001', 'oric-pharmaceuticals', [('bill-com', 55, 367), ('bill-com', 55, 368), ('bill-com', 55, 369), ('bill-com', 55, 370), ('bill-com', 55, 371)])
# ('PLEX SYSTEMS HOLD BACK AMOUNT PP', 'plex-systems', [('plex', 100, 2068), ('plex', 100, 2069), ('plex', 100, 2070), ('plex', 100, 2071), ('plex', 100, 2072)])
# ('Plex Systems', 'plex-systems', [('plex', 100, 2068), ('plex', 100, 2069), ('plex', 100, 2070), ('plex', 100, 2071), ('plex', 100, 2072)])
# ('PLEX SYSTEMS AMOUNT HELD IN ESCROW PP,,,,', 'plex-systems', [('plex', 100, 2068), ('plex', 100, 2069), ('plex', 100, 2070), ('plex', 100, 2071), ('plex', 100, 2072)])
# ('PPRO HOLDING GMBH', 'ppro', [('duolingo', 52, 1024), ('duolingo', 52, 1025), ('duolingo', 52, 1026), ('duolingo', 52, 1027), ('benchling', 50, 335)])
# ('PSIQUANTUM CORP', 'psiq', [('brain-corp', 57, 435), ('brain-corp', 57, 436), ('brain-corp', 57, 437), ('brain-corp', 57, 438), ('brain-corp', 57, 439)])
# ('PsiQuantum Corp.', 'psiq', [('brain-corp', 57, 435), ('brain-corp', 57, 436), ('brain-corp', 57, 437), ('brain-corp', 57, 438), ('brain-corp', 57, 439)])
# ('Psiquantum Corp, Series C', 'psiq', [('brain-corp', 57, 435), ('brain-corp', 57, 436), ('brain-corp', 57, 437), ('brain-corp', 57, 438), ('brain-corp', 57, 439)])
# ('QUINTOANDAR SERVICOS IMOBILIARIOS LTDA', 'quinto-andar', [('arista-networks', 45, 251), ('arista-networks', 45, 252), ('arista-networks', 45, 253), ('caris-life-sciences', 42, 546), ('caris-life-sciences', 42, 547)])
# ('Quintoandar', 'quinto-andar', [('instacart', 60, 1484), ('instacart', 60, 1485), ('instacart', 60, 1486), ('instacart', 60, 1487), ('instacart', 60, 1488)])
# ('RAPPI INC SER E CVT PFD PP', 'rappi', [('contrast-security', 47, 733), ('contrast-security', 47, 734), ('contrast-security', 47, 735), ('contrast-security', 47, 736), ('contrast-security', 47, 737)])
# ('RAPPI INC SER F CVT PFD PP', 'rappi', [('contrast-security', 47, 733), ('contrast-security', 47, 734), ('contrast-security', 47, 735), ('contrast-security', 47, 736), ('contrast-security', 47, 737)])
# ('RAPPI INC SER F CVT PFD PP,,,,,', 'rappi', [('contrast-security', 47, 733), ('contrast-security', 47, 734), ('contrast-security', 47, 735), ('contrast-security', 47, 736), ('contrast-security', 47, 737)])
# ('RAPPI INC SER E CVT PFD', 'rappi', [('contrast-security', 47, 733), ('contrast-security', 47, 734), ('contrast-security', 47, 735), ('contrast-security', 47, 736), ('contrast-security', 47, 737)])
# ('RAPPI INC SER F CVT', 'rappi', [('casper', 53, 556), ('casper', 53, 557), ('casper', 53, 558), ('contrast-security', 53, 733), ('contrast-security', 53, 734)])
# ('Rappi Inc /Pfd/', 'rappi', [('f45-training', 53, 1112), ('f45-training', 53, 1113), ('f45-training', 53, 1114), ('druva', 50, 1018), ('druva', 50, 1019)])
# ('WORKRISE TECHNOLOGIES INC', 'rigup', [('workrise', 100, 3000), ('cruise', 57, 796), ('cruise', 57, 797), ('cruise', 57, 798), ('cruise', 57, 799)])
# ('RIPPLE COMMON SHARES   /', 'ripple', [('noodle-partners', 55, 1843), ('noodle-partners', 55, 1844), ('noodle-partners', 55, 1845), ('monday-com', 50, 1762), ('monday-com', 50, 1763)])
# ('Ripple Labs Inc. Shares A /', 'ripple', [('pax-labs', 67, 2001), ('pax-labs', 67, 2002), ('pax-labs', 67, 2003), ('pax-labs', 67, 2004), ('clear-labs', 64, 657)])
# ('Roof , Inc. Series E Shares /', 'roofstock', [('sarcos-robotics', 62, 2357), ('sarcos-robotics', 62, 2358), ('sarcos-robotics', 62, 2359), ('sarcos-robotics', 62, 2360), ('sarcos-robotics', 62, 2361)])
# ('Sb Technology Corp', 'sandboxaq', [('brain-corp', 73, 435), ('brain-corp', 73, 436), ('brain-corp', 73, 437), ('brain-corp', 73, 438), ('brain-corp', 73, 439)])
# ('Sb Technology Series D Cvt Pfd Pp', 'sandboxaq', [('MH Sub I, LLC', 45, 1738), ('MH Sub I, LLC', 45, 1739), ('ecovadis', 44, 1034), ('adicet-bio', 40, 112), ('adicet-bio', 40, 113)])
# ('ROTOR ACQUISITION CORP', 'sarcos-robotics', [('brain-corp', 57, 435), ('brain-corp', 57, 436), ('brain-corp', 57, 437), ('brain-corp', 57, 438), ('brain-corp', 57, 439)])
# ('Sarcos Technology and Robotics Corp.', 'sarcos-robotics', [('brain-corp', 57, 435), ('brain-corp', 57, 436), ('brain-corp', 57, 437), ('brain-corp', 57, 438), ('brain-corp', 57, 439)])
# ('Sarcos Technology and Robotics Corp', 'sarcos-robotics', [('brain-corp', 57, 435), ('brain-corp', 57, 436), ('brain-corp', 57, 437), ('brain-corp', 57, 438), ('brain-corp', 57, 439)])
# ('GeneDX Holdings Corp.', 'sema4', [('openx', 62, 1933), ('openx', 62, 1934), ('brain-corp', 57, 435), ('brain-corp', 57, 436), ('brain-corp', 57, 437)])
# ('Snap, Inc.', 'snapchat', [('asana', 67, 257), ('asana', 67, 258), ('asana', 67, 259), ('asana', 67, 260), ('asapp', 67, 261)])
# ('SNAP INC.', 'snapchat', [('asana', 67, 257), ('asana', 67, 258), ('asana', 67, 259), ('asana', 67, 260), ('asapp', 67, 261)])
# ('Snap Inc', 'snapchat', [('asana', 67, 257), ('asana', 67, 258), ('asana', 67, 259), ('asana', 67, 260), ('asapp', 67, 261)])
# ('SOCIAL FINANCE INC', 'sofi', [('spruce-finance', 71, 2574), ('spruce-finance', 71, 2575), ('ant-financial', 67, 218), ('ant-financial', 67, 219), ('ant-financial', 67, 220)])
# ('SPACEX COMMON SHARES   /', 'space-exploration-technologies', [('momentus-space', 59, 1759), ('momentus-space', 59, 1760), ('momentus-space', 59, 1761), ('squarespace', 58, 2580), ('squarespace', 58, 2581)])
# ('SPACEX SERIES K CVT PFD STOCK PP', 'space-exploration-technologies', [('sierra-space', 44, 2435), ('sierra-space', 44, 2436), ('voyager-space-holdings', 43, 2921), ('caris-life-sciences', 42, 546), ('caris-life-sciences', 42, 547)])
# ('Spacex Series K Cvt Pfd Pp', 'space-exploration-technologies', [('sierra-space', 51, 2435), ('sierra-space', 51, 2436), ('astra-space', 47, 264), ('astra-space', 47, 265), ('astra-space', 47, 266)])
# ('SQZ Biotechnologies Company', 'sqz-biotech', [('the-honest-company-inc', 64, 39), ('the-honest-company', 64, 2738), ('the-honest-company', 64, 2739), ('the-honest-company', 64, 2740), ('the-honest-company', 64, 2741)])
# ('DOMA HOLDINGS INC', 'states-title', [('domo', 75, 943), ('domo', 75, 944), ('domo', 75, 945), ('domo', 75, 946), ('ooma', 75, 1924)])
# ('Doma Holdings Inc.', 'states-title', [('domo', 75, 943), ('domo', 75, 944), ('domo', 75, 945), ('domo', 75, 946), ('ooma', 75, 1924)])
# ('MNTN Digital', 'steelhouse', [('digital-ocean', 74, 916), ('digital-ocean', 74, 917), ('digital-ocean', 74, 918), ('proteus-digital-health', 74, 2130), ('dataminr', 50, 845)])
# ('MOUNTAIN DIGITAL INC', 'steelhouse', [('digital-ocean', 70, 916), ('digital-ocean', 70, 917), ('digital-ocean', 70, 918), ('proteus-digital-health', 61, 2130), ('bright-machines', 52, 454)])
# ('MNTN DIGITAL, SERIES D', 'steelhouse', [('digital-ocean', 74, 916), ('digital-ocean', 74, 917), ('digital-ocean', 74, 918), ('proteus-digital-health', 74, 2130), ('dataminr', 50, 845)])
# ('Dna Script', 'stripe', [('inscripta', 74, 1470), ('inscripta', 74, 1471), ('inscripta', 74, 1472), ('inscripta', 74, 1473), ('inscripta', 74, 1474)])
# ('Vaxcyte Inc', 'sutrovax', [('cytek', 67, 818), ('cytek', 67, 819), ('cytek', 67, 820), ('humacyte', 67, 1429), ('humacyte', 67, 1430)])
# ('Fabletics Series G Pfd', 'techstyle', [('fanatics', 57, 1124), ('fanatics', 57, 1125), ('fanatics', 57, 1126), ('fanatics', 57, 1127), ('fanatics', 57, 1128)])
# ('Verizon Communications, Inc.', 'telogis', [('vizio', 67, 2913), ('vizio', 67, 2914), ('vizio', 67, 2915), ('vizio', 67, 2916), ('verbit', 62, 2890)])
# ('VERIZON COMMUNICATIONS INC', 'telogis', [('vizio', 67, 2913), ('vizio', 67, 2914), ('vizio', 67, 2915), ('vizio', 67, 2916), ('verbit', 62, 2890)])
# ('Verizon Communications Inc.', 'telogis', [('vizio', 67, 2913), ('vizio', 67, 2914), ('vizio', 67, 2915), ('vizio', 67, 2916), ('verbit', 62, 2890)])
# ('VERIZON COMMUNICATIONS', 'telogis', [('vizio', 67, 2913), ('vizio', 67, 2914), ('vizio', 67, 2915), ('vizio', 67, 2916), ('verbit', 62, 2890)])
# ('JAND, Inc.', 'warby-parker', [('xad', 57, 3001), ('23andme', 55, 59), ('23andme', 55, 60), ('23andme', 55, 61), ('23andme', 55, 62)])
# ('Winc Inc', 'winc', [('wag', 50, 2935), ('wag', 50, 2936), ('wix', 50, 2990), ('wix', 50, 2991), ('wix', 50, 2992)])
# ('Winc, Inc.', 'winc', [('wag', 50, 2935), ('wag', 50, 2936), ('wix', 50, 2990), ('wix', 50, 2991), ('wix', 50, 2992)])
# ('CONTEXTLOGIC INC', 'wish', [('telogis', 63, 2691), ('telogis', 63, 2692), ('telogis', 63, 2693), ('telogis', 63, 2694), ('cepton-technologies', 58, 8)])
# ('ContextLogic, Inc.', 'wish', [('telogis', 63, 2691), ('telogis', 63, 2692), ('telogis', 63, 2693), ('telogis', 63, 2694), ('cepton-technologies', 58, 8)])
# ('ContextLogic Inc.', 'wish', [('telogis', 63, 2691), ('telogis', 63, 2692), ('telogis', 63, 2693), ('telogis', 63, 2694), ('cepton-technologies', 58, 8)])
# ('GROUNDTRUTH COMMON SHARES  /', 'xad', [('commonbond', 51, 714), ('commonbond', 51, 715), ('monday-com', 46, 1762), ('monday-com', 46, 1763), ('monday-com', 46, 1764)])
# ('Brandtech Group Ltd/The', 'you-mr-jones', [('the-realreal', 55, 2745), ('the-realreal', 55, 2746), ('the-realreal', 55, 2747), ('the-realreal', 55, 2748), ('the-realreal', 55, 2749)])
# ('Brandtech Group /The', 'you-mr-jones', [('internet-brands', 57, 1511), ('internet-brands', 57, 1512), ('internet-brands', 57, 1513), ('internet-brands', 57, 1514), ('jobandtalent', 56, 1531)])
# ('YOURPEOPLE INC', 'zenefits', [('ripple', 62, 2269), ('ripple', 62, 2270), ('openspace', 53, 1932), ('yotpo', 53, 3043), ('yotpo', 53, 3044)])

# %%
not_matched_slugs = not_matched + partial_matched

# %%
# Perfect matching 
def find_matches(phrase, word_list, exact_match_weight=3):
    cleaned_words = clean_text(phrase).split()
    
    # A dictionary to keep track of match scores
    match_scores = {w: 0 for w in word_list}
    
    for word in cleaned_words:
        regex_pattern = re.escape(word)
        print(regex_pattern)
        compiled_pattern = re.compile(regex_pattern, re.IGNORECASE)
        print(compiled_pattern)
        
        # Iterate through the word list and conut matches
        for list_item in word_list:
            if compiled_pattern.search(clean_text(list_item)):
                match_scores[list_item] += 1

    # Add exact match weight if the whole phrase is found
    for list_item in word_list:
        if re.search(re.escape(clean_text(phrase)), clean_text(list_item)):
            match_scores[list_item] += exact_match_weight
    
    # Rank the results based on the number of matches
    ranked_results = sorted(match_scores.items(), key=lambda x: x[1], reverse=True)
    
    return ranked_results

# %%
# match with weights on first word

def find_matches_with_weights(phrase, word_list, exact_match_weight=3, first_word_weight=2, other_word_weight=1):
    cleaned_words = clean_text(phrase).split()
    match_scores = {w: 0 for w in word_list}
    
    # Handle the first word with a higher weight
    if cleaned_words:
        first_word = cleaned_words[0]
        first_word_regex = re.escape(first_word)
        # print(first_word_regex)
        compiled_first_word_pattern = re.compile(first_word_regex, re.IGNORECASE)
        # print(compiled_first_word_pattern)
        
        # Add higher weight for first word matches
        for list_item in word_list:
            if compiled_first_word_pattern.search(clean_text(list_item)):
                match_scores[list_item] += first_word_weight
    
    # Handle other words with a standard weight
    for word in cleaned_words[1:]:  
        regex_pattern = re.escape(word)
        # print(regex_pattern)
        compiled_pattern = re.compile(regex_pattern, re.IGNORECASE)       
        # print(compiled_pattern)
        
        for list_item in word_list:
            if compiled_pattern.search(clean_text(list_item)):
                match_scores[list_item] += other_word_weight

    # Add exact match weight if the whole phrase is found
    for list_item in word_list:
        if re.search(re.escape(clean_text(phrase)), clean_text(list_item)):
            match_scores[list_item] += exact_match_weight
    
    # Rank the results based on the number of matches
    ranked_results = sorted(match_scores.items(), key=lambda x: x[1], reverse=True)
    
    return ranked_results

# %%
correct_first_match = 0
partial_matches = 0
total_items = len(not_matched_slugs)

unmatched_items = []
partial_matched_items = []
matched_items = []
df_rows = []

for t in not_matched_slugs:
    not_matched_slug = t[1]  # slug
    not_matched_nport_issuer_name = t[0]  # nport_issuer_name
    
    # Get ranked matches
    matches = find_matches_with_weights(not_matched_nport_issuer_name, word_list)
    
    ranked_matches = [match for match in matches if match[1] > 0]
    ranked_matches_str = ', '.join([f"('{item[0]}', {item[1]})" for item in ranked_matches])
    
    match_status = ""
    
    if ranked_matches:
        # Check the first match
        first_match = ranked_matches[0][0]
        
        if first_match == not_matched_slug:
            # Exact match in the first position
            correct_first_match += 1
            match_status = "Matched"
            # add t[0], t[1], ranked_matches to list
            matched_items.append((t[0], t[1], ranked_matches[0]))
        else:
            # If second itme exists in the rest of the ranked matches
            if any(match[0] == not_matched_slug for match in ranked_matches[1:]):
                partial_matches += 1
                partial_matched_items.append((t[0], t[1], ranked_matches))
                match_status = "Partial Match"
            else:
                unmatched_items.append((t[0], t[1], ranked_matches))
                match_status = "Not Matched"
    else:
        unmatched_items.append(t)
        match_status = "Not Ranked - Not Matched"

#     df_rows.append([not_matched_slug, not_matched_nport_issuer_name, ranked_matches_str, match_status])

# _df = pd.DataFrame(df_rows, columns=['not_matched_slug', 'not_matched_nport_issuer_name', 'Ranked Matches', 'Match Status'])

# _df.to_csv('data/output.csv', index=False)

first_match_accuracy = correct_first_match / total_items if total_items > 0 else 0
overall_match_accuracy = (correct_first_match + partial_matches) / total_items if total_items > 0 else 0

print(f"First Match Accuracy: {first_match_accuracy:.2f}")
print(f"Overall Match Accuracy (including partial matches): {overall_match_accuracy:.2f}")
print("Unmatched items:", len(unmatched_items))
# Out:
# First Match Accuracy: 0.22
# Overall Match Accuracy (including partial matches): 0.52
# Unmatched items: 108

# %%
matched_items_df = pd.DataFrame(matched_items, columns=['nport_issuer_name', 'slug', 'rankings'])
matched_items_df.to_csv('data/_test.csv', index=False)

# %%
# create a df out of _df where match status is Partial Match
partial_matched_df = pd.DataFrame(partial_matched_items, columns=['nport_issuer_name', 'slug', 'rankings'])
partial_matched_df
# Out:
#                                     nport_issuer_name                slug  \
# 0                  Life Healthcare Group Holdings Ltd    1life-healthcare
# 1                                    Ant Group Co Ltd       ant-financial
# 2                       Ant International Co. Limited       ant-financial
# 3        Ant International Co. Limited Class C Shares       ant-financial
# 4                                      AppLovin Corp.            applovin
# ..                                                ...                 ...
# 61  TEBRA TECHNOLOGIES, INC. (F.K.A. KAREO, INC.) ...               tebra
# 62                            The Honest Company Inc.  the-honest-company
# 63                           The Honest Company, Inc.  the-honest-company
# 64                             THE HONEST COMPANY INC  the-honest-company
# 65                        THE HONEST COMPANY SERIES D  the-honest-company
#
#                                              rankings
# 0   [(caris-life-sciences, 20), (1life-healthcare,...
# 1   [(palantir, 26), (convoy, 15), (ant-financial,...
# 2   [(palantir, 26), (convoy, 15), (ant-financial,...
# 3   [(convoy, 30), (palantir, 26), (databricks, 21...
# 4   [(hashicorp, 10), (applovin, 8), (brain-corp, ...
# ..                                                ...
# 61          [(kareo, 4), (tebra, 4), (commonbond, 2)]
# 62  [(the-honest-company-inc, 12), (the-honest-com...
# 63  [(the-honest-company-inc, 12), (the-honest-com...
# 64  [(the-honest-company-inc, 12), (the-honest-com...
# 65  [(the-honest-company-inc, 12), (the-honest-com...
#
# [66 rows x 3 columns]

# %%
# Apply the filtering to create a new column with filtered matches in partial_matched
filtered_partial_matched = [
    (row['nport_issuer_name'], row['slug'], row['rankings'], filter_unique_matches(row['rankings']))
    for _, row in partial_matched_df.iterrows()
]
filtered_partial_matched_df = pd.DataFrame(filtered_partial_matched, columns=['nport_issuer_name', 'slug', 'rankings', 'filtered_rankings'])
filtered_partial_matched_df['method'] = 'perfect_matched'
filtered_partial_matched_df.to_csv('data/partial_matched_perfect.csv', index=False)

# %%
# create a pd dataframe of the unmatched items
_not_matched_list = []
for t in unmatched_items:
    _not_matched_list.append([t[1], t[0]])

_df_not_matched = pd.DataFrame(_not_matched_list, columns=['slug', 'nport_issuer_name'])
print(_df_not_matched.head())
_df_not_matched.to_csv('data/unmatched_perfect.csv', index=False)
# Out:
#            slug                 nport_issuer_name
# 0        byju-s        Think & Learn Private Ltd.
# 1  warby-parker                          JAND INC
# 2   3d-robotics           Nauticus Robotics, Inc.
# 3        adroll  NEXTROLL, INC. COMMON SHARES   /
# 4        adroll        NEXTROLL COMMON SHARES   /

# %%
not_matched_list = []
for t in unmatched_items:
    not_matched_list.append([t[0], t[1]])
for t in partial_matched_items:
    not_matched_list.append((t[0], t[1]))

df_not_matched = pd.DataFrame(not_matched_list, columns=['nport_issuer_name','slug'])

# %%
df_forge_price = pd.read_csv('data/forge_price_sample.csv')
df_funding_rounds = pd.read_csv('data/funding-rounds.csv')
df_issuers = pd.read_csv('data/issuers.csv')
df_trade_facts = pd.read_csv('data/trade_facts.csv')


df_merged_result = df_issuers.merge(df_forge_price, on='ISSUER_SLUG', how='left') \
            .merge(df_funding_rounds, on='ISSUER_SLUG', how='left') \
            .merge(df_trade_facts, on='ISSUER_SLUG', how='left')
# df_merged_result.to_csv('data/merged_result.csv', index=False)
df_merged_result = df_merged_result.rename(columns={'ISSUER_SLUG': 'slug'})

# join df_not_matched with df_merged_result on left join where df_not_matched.slug = df_merged_result.ISSUER_SLUG 
df_joined_unmatched_merged_result = df_not_matched.merge(df_merged_result, how='left')

print(df_joined_unmatched_merged_result.head())

df_joined_unmatched_merged_result.to_csv('data/joined_unmatched_merged_result.csv', index=False)
# Out:
#                   nport_issuer_name          slug          NAME  \
# 0        Think & Learn Private Ltd.        byju-s        Byju's
# 1                          JAND INC  warby-parker  Warby Parker
# 2           Nauticus Robotics, Inc.   3d-robotics           3DR
# 3  NEXTROLL, INC. COMMON SHARES   /        adroll      NextRoll
# 4        NEXTROLL COMMON SHARES   /        adroll      NextRoll
#
#            LEGALENTITYNAME                                      SEARCHALIASES  \
# 0  Think & Learn Pvt. Ltd.        [\n  "Byjus ",\n  "BYJU'S ",\n  "byju's"\n]
# 1               Jand, Inc.                  [\n  "Jand",\n  "Warby Parker"\n]
# 2        3D Robotics, Inc.  [\n  "3DR ",\n  "3dr ",\n  "3DRobotics ",\n  "...
# 3           NextRoll, Inc.  [\n  "Adroll    ",\n  "adroll    ",\n  "Ad Rol...
# 4           NextRoll, Inc.  [\n  "Adroll    ",\n  "adroll    ",\n  "Ad Rol...
#
#                                          DESCRIPTION STRUCTURED_DESCRIPTION  \
# 0  BYJU's is an ed-tech company based in India an...                    NaN
# 1  Warby Parker is a lifestyle brand focused on o...                    NaN
# 2  3DR (also known as 3D Robotics) makes Site Sca...                    NaN
# 3  NextRoll’s machine learning technology gathers...                    NaN
# 4  NextRoll’s machine learning technology gathers...                    NaN
#
#   LIFECYCLESTATUS                                      BANNERMESSAGE  \
# 0             NaN                                                NaN
# 1             NaN  Warby Parker completed its direct listing on S...
# 2             NaN  3DR was acquired by Kitty Hawk on June 11, 202...
# 3             NaN                                                NaN
# 4             NaN                                                NaN
#
#                             SUB_SECTOR  ... FORGE_PRICE_ISSUER_TIER  \
# 0                           E-Learning  ...                     NaN
# 1  Clothing, Fashion, Beauty & Apparel  ...                     NaN
# 2                  Industrial software  ...                     NaN
# 3           Sales & Marketing / Adtech  ...                  TIER_1
# 4           Sales & Marketing / Adtech  ...                  TIER_1
#
#   FORGE_PRICE FORGE_IMPLIED_VALUATION  FORGE_PRICE_SOURCE_EXTERNAL HAS_IOIS  \
# 0         NaN                     NaN                          NaN      NaN
# 1       15.08            1.679348e+09                 Public Price    False
# 2        1.90            1.278868e+08                      Primary    False
# 3        1.68            8.584394e+07                         IOIs     True
# 4        1.68            8.584394e+07                         IOIs     True
#
#                              ARRAY_AGG(FUNDING_DATE)  \
# 0                                                NaN
# 1  [\n  "2012-09-07 07:00:00.000",\n  "2013-12-20...
# 2  [\n  "2012-11-05 00:00:00.000",\n  "2013-12-04...
# 3  [\n  "2006-06-22 07:00:00.000",\n  "2014-04-21...
# 4  [\n  "2006-06-22 07:00:00.000",\n  "2014-04-21...
#
#                             ARRAY_AGG(FR.SHARE_TYPE) NUM_TRADES  \
# 0                                                NaN        NaN
# 1  [\n  "Series B",\n  "Series C",\n  "Series AA"...        NaN
# 2  [\n  "Series A",\n  "Series B",\n  "Series C",...        NaN
# 3  [\n  "Common A & B",\n  "Series D",\n  "Series...       16.0
# 4  [\n  "Common A & B",\n  "Series D",\n  "Series...       16.0
#
#   LAST_CLOSED_TRADE_DATE  LAST_PENDING_TRADE_DATE
# 0                    NaN                      NaN
# 1                    NaN                      NaN
# 2                    NaN                      NaN
# 3                3/13/24                   2/7/24
# 4                3/13/24                   2/7/24
#
# [5 rows x 28 columns]

# %%
# Weight functions

from datetime import datetime

def weight_domicile_country_code(code):
    return 1 if code == 'US' else 0

def weight_domicile_state_code(code):
    return 1 if code == 'DE' else 0


funding_round_ranking = {
    'seed': 0,
    'series a': 1,
    'series b': 2,
    'series c': 3,
    'series d': 4,
    'series e': 5,
    'series f': 6,
    'series g': 7,
    'series h': 8,
    'series i': 9
}
def normalize_and_weight_series(series_types):  
    if pd.isna(series_types) or not series_types:  # Handle NaN or empty lists
        return 0  # Neutral weight for missing values or empty lists

    normalized_weights = []
    
    for series in series_types:
        series_lower = series.lower().strip()
        
        match = re.search(r'series [a-z]', series_lower)
        if match:
            normalized_type = match.group()
            weight = funding_round_ranking.get(normalized_type, 0)
            normalized_weights.append(weight)
        else:
            # Fallback for unrecognized series types (neutral)
            normalized_weights.append(0)  
    
    return max(normalized_weights)  # Return the highest weight in the list


def weight_recency(funding_dates_str):
    if pd.isna(funding_dates_str) or not funding_dates_str: # Handle NaN or empty lists
        return -99999  # Lowest weight for missing or empty values
    
    funding_dates_clean = re.findall(r'\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2}\.\d{3}', funding_dates_str)
    funding_dates = [datetime.strptime(date, '%Y-%m-%d %H:%M:%S.%f') for date in funding_dates_clean]
    most_recent_date = max(funding_dates)
    now = datetime.now()
    recency_weight = (now - most_recent_date).days
    return -recency_weight  # More recent = higher weight (less days, more weight)


def weight_price_source(price_source):
    if pd.isna(price_source):  # Handle NaN or missing values
        return -0.1  # Assign negative weight to missing values
    price_source_lower = price_source.lower().strip()
    
    if re.search(r'vwap', price_source_lower):
        return 1  
    elif re.search(r'iois', price_source_lower):
        return 0.5  
    elif re.search(r'primary', price_source_lower):
        return 0.2  
    else:
        return -0.1  # Negative weight for other or unrecognized types

def weight_price_issuer_tier(tier):
    if pd.isna(tier):  # Handle NaN or missing values
        return 0  # Neutral weight for missing
    tier_lower = tier.lower().strip()
    if tier_lower == 'tier_1':
        return 1  # Highest weight for TIER_1
    else:
        return 0.5  # Neutral or medium weight for other tiers


def weight_price(price):
    if pd.isna(price):  # Handle NaN or missing values
        return 0  # Neutral weight for missing values
    return price  # Higher value means higher weight

def weight_implied_valuation(valuation):
    if pd.isna(valuation):  # Handle NaN or missing values
        return 0  # Neutral weight for missing values
    return valuation  # Higher value means higher weight

#create weight functions for HAS_IOIS, if true less weight, if false more weight
def weight_has_iois(has_iois):
    return 0 if has_iois else 1

# create weight functions for NUM_TRADES, if more trades, higher weight
def weight_num_trades(num_trades):
    return num_trades if num_trades else 0

# create weight functions for LAST_CLOSED_TRADE_DATE, if more recent, higher weight
def weight_last_closed_trade_date(last_closed_trade_date):
    if pd.isna(last_closed_trade_date) or not last_closed_trade_date:  # Handle NaN or missing values
        return -99999  # Lowest weight for missing values
    last_closed_trade_date = datetime.strptime(last_closed_trade_date, '%m/%d/%y')
    now = datetime.now()
    recency_weight = (now - last_closed_trade_date).days
    return -recency_weight  # More recent = higher weight (less days, more weight)

# create weight functions for LAST_PENDING_TRADE_DATE, if more recent, higher weight
def weight_last_pending_trade_date(last_pending_trade_date):
    if pd.isna(last_pending_trade_date) or not last_pending_trade_date:  # Handle NaN or missing values
        return -99999  # Lowest weight for missing values
    last_pending_trade_date = datetime.strptime(last_pending_trade_date, '%m/%d/%y')
    now = datetime.now()
    recency_weight = (now - last_pending_trade_date).days
    return -recency_weight  # More recent = higher weight (less days, more weight)

# create weight functions for ARCHIVEDAT, if present, lower weight
def weight_archived_at(archived_at):
    return 0 if pd.isna(archived_at) else 1


# output_columns += [
#     'YEARFOUNDED',
#     'CITY'
# ]

# %%
# all-MiniLM-L6-v2

df_not_matched_2 = df_joined_unmatched_merged_result.copy()
# apply normalize_name(str(text)) to df_not_matched_2
df_not_matched_2['cleaned_nport_issuer_name'] = df_not_matched_2.apply(lambda row: normalize_name(row['nport_issuer_name']), axis=1)

output_columns = [
    'slug',
    'NAME',
    'LEGALENTITYNAME',
    'SEARCHALIASES',
    'DESCRIPTION',
    'STRUCTURED_DESCRIPTION',
    'LIFECYCLESTATUS',
    'BANNERMESSAGE',	
    'SUB_SECTOR',
    'SECTOR',
    'WEBSITE',
    'CRUNCHBASEURL'
]

def combine_output_columns(row):
    texts = []
    for col in output_columns:
        if col in row and pd.notnull(row[col]):
            texts.append(clean_text(row[col]))
    combined_text = ' '.join(texts)
    return combined_text

df_not_matched_2['combined_output'] = df_not_matched_2.apply(combine_output_columns, axis=1)

words_to_find = df_not_matched_2['cleaned_nport_issuer_name'].tolist()
word_list = df_not_matched_2['combined_output'].tolist()


model = SentenceTransformer('all-MiniLM-L6-v2')  

embeddings_to_find = model.encode(words_to_find, convert_to_numpy=True, normalize_embeddings=True)
embeddings_list = model.encode(word_list, convert_to_numpy=True, normalize_embeddings=True)


 
# Apply the weight functions to the DataFrame
df_not_matched_2['DOMICILECOUNTRYCODE_WEIGHT'] = df_not_matched_2['DOMICILECOUNTRYCODE'].apply(weight_domicile_country_code)
df_not_matched_2['DOMICILESTATECODE_WEIGHT'] = df_not_matched_2['DOMICILESTATECODE'].apply(weight_domicile_state_code)
df_not_matched_2['SHARE_TYPE_WEIGHT'] = df_not_matched_2['ARRAY_AGG(FR.SHARE_TYPE)'].apply(normalize_and_weight_series)
df_not_matched_2['FUNDING_DATE_WEIGHT'] = df_not_matched_2['ARRAY_AGG(FUNDING_DATE)'].apply(weight_recency)
df_not_matched_2['FORGE_PRICE_SOURCE_WEIGHT'] = df_not_matched_2['FORGE_PRICE_SOURCE_EXTERNAL'].apply(weight_price_source)
df_not_matched_2['FORGE_PRICE_ISSUER_TIER_WEIGHT'] = df_not_matched_2['FORGE_PRICE_ISSUER_TIER'].apply(weight_price_issuer_tier)
df_not_matched_2['FORGE_PRICE_WEIGHT'] = df_not_matched_2['FORGE_PRICE'].apply(weight_price)
df_not_matched_2['FORGE_IMPLIED_VALUATION_WEIGHT'] = df_not_matched_2['FORGE_IMPLIED_VALUATION'].apply(weight_implied_valuation)

df_not_matched_2['HAS_IOIS_WEIGHT'] = df_not_matched_2['HAS_IOIS'].apply(weight_has_iois)
df_not_matched_2['NUM_TRADES_WEIGHT'] = df_not_matched_2['NUM_TRADES'].apply(weight_num_trades)
df_not_matched_2['LAST_CLOSED_TRADE_DATE_WEIGHT'] = df_not_matched_2['LAST_CLOSED_TRADE_DATE'].apply(weight_last_closed_trade_date)
df_not_matched_2['LAST_PENDING_TRADE_DATE_WEIGHT'] = df_not_matched_2['LAST_PENDING_TRADE_DATE'].apply(weight_last_pending_trade_date)


# Select and normalize the weighted features
weighted_feature_columns = [
    'DOMICILECOUNTRYCODE_WEIGHT',
    'DOMICILESTATECODE_WEIGHT',
    'SHARE_TYPE_WEIGHT',
    'FUNDING_DATE_WEIGHT',
    'FORGE_PRICE_SOURCE_WEIGHT',
    'FORGE_PRICE_ISSUER_TIER_WEIGHT',
    'FORGE_PRICE_WEIGHT',
    'FORGE_IMPLIED_VALUATION_WEIGHT',
    'HAS_IOIS_WEIGHT',
    'NUM_TRADES_WEIGHT',
    'LAST_CLOSED_TRADE_DATE_WEIGHT',
    'LAST_PENDING_TRADE_DATE_WEIGHT'
]

# Fill NaN values with zeros
df_not_matched_2[weighted_feature_columns] = df_not_matched_2[weighted_feature_columns].fillna(0.0)

# Normalize the weighted features
scaler = MinMaxScaler()
weighted_features = scaler.fit_transform(df_not_matched_2[weighted_feature_columns])


combined_embeddings_to_find = np.hstack((embeddings_to_find, weighted_features))
combined_embeddings_list = np.hstack((embeddings_list, weighted_features))
cosine_sim_matrix = cosine_similarity(combined_embeddings_to_find, combined_embeddings_list)


correct_top1 = 0  # Correct matches at rank 1
correct_topk = 0  # Correct matches within top_k
top_k = 20 
not_matched_results = []
partial_matched_results = []
exact_matxches = []


for idx, (word, scores) in enumerate(zip(words_to_find, cosine_sim_matrix)):
    top_indices = scores.argsort()[-top_k:][::-1]  # Indices of top_k scores in descending order
    matches = []
    seen_matches = set()  # Reset seen_matches for each new word being processed
    ground_truth_found = False

    current_slug = df_not_matched_2.iloc[idx]['slug']
    current_npot_issuer_name = df_not_matched_2.iloc[idx]['nport_issuer_name']

    for rank, index in enumerate(top_indices):
        # Retrieve a concise match identifier like 'slug' or 'NAME' instead of full text
        matched_word = df_not_matched_2.iloc[index]['slug'] if 'slug' in df_not_matched_2.columns else word_list[index]
        match_score = scores[index]
        
        # Only add the match if it's not a duplicate within the current ranking list
        if matched_word not in seen_matches:
            matches.append({
                'rank': len(matches) + 1,  # Rank based on unique entries added
                'match_word': matched_word,
                'score': match_score
            })
            seen_matches.add(matched_word)  # Mark this word as seen within this record

        if index == idx:
            ground_truth_found = True
            if len(matches) == 1:
                correct_top1 += 1  # Ground truth is the top match
                exact_matxches.append({
                        'nport_issuer_name': current_npot_issuer_name, 
                        'slug': current_slug,
                        'rankings': matches
                        })
                break
            correct_topk += 1     # Ground truth is within top_k matches
            partial_matched_results.append({
                'nport_issuer_name': current_npot_issuer_name, 
                'slug': current_slug,
                'rankings': sorted(matches, key=lambda x: x['score'], reverse=True)  # Sort by score
            })

    if not ground_truth_found:
        not_matched_results.append({
            'nport_issuer_name': current_npot_issuer_name, 
            'slug': current_slug,
            'rankings': sorted(matches, key=lambda x: x['score'], reverse=True)  # Sort by score
        })


total = len(words_to_find)
top1_accuracy = correct_top1 / total
topk_accuracy = correct_topk / total

print(f"Top-1 Accuracy: {top1_accuracy:.2%}")
print(f"Top-{top_k} Accuracy: {topk_accuracy:.2%}")

# save not_matched_results to csv
df_not_matched_results = pd.DataFrame(not_matched_results)
df_not_matched_results.to_csv('data/not_matched_results.csv', index=False)
# Out:
# Top-1 Accuracy: 87.93%
# Top-20 Accuracy: 10.34%

# %%
partial_matched_results_df = pd.DataFrame(partial_matched_results)
partial_matched_results_df['method'] = 'embedding_matched'

partial_matched_results_df.to_csv('data/partial_matched_embedding.csv', index=False)
partial_matched_results_df
# Out:
#                       nport_issuer_name              slug  \
# 0               Nauticus Robotics, Inc.       3d-robotics
# 1        Formagrid Inc Ser F Cvt Pfd Pp          airtable
# 2         Formagrid Inc Ser F Cvt /Pfd/          airtable
# 3     GROUPON INC COMMON STOCK USD.0001           groupon
# 4                          Mh Sub I Llc   internet-brands
# 5    Mh Sub I Llc / Micro Holding Corp.   internet-brands
# 6              ANI Technologies Pvt Ltd               ola
# 7             ANI Technologies Pvt Ltd.               ola
# 8                  Ani Technologies Pvt               ola
# 9                Ani Technologies Pvt .               ola
# 10    Sb Technology Series D Cvt Pfd Pp         sandboxaq
# 11                 MOUNTAIN DIGITAL INC        steelhouse
# 12   Life Healthcare Group Holdings Ltd  1life-healthcare
# 13               Tyra Biosciences, Inc.  aura-biosciences
# 14                        Mh Sub I, Llc   internet-brands
# 15  Mh Sub I, Llc (Micro Holding Corp.)   internet-brands
# 16                           Winc, Inc.              winc
# 17                   Bolt Financial Inc    bolt-financial
#
#                                              rankings             method
# 0   [{'rank': 1, 'match_word': 'aura-biosciences',...  embedding_matched
# 1   [{'rank': 1, 'match_word': 'carbon-health', 's...  embedding_matched
# 2   [{'rank': 1, 'match_word': 'carbon-health', 's...  embedding_matched
# 3   [{'rank': 1, 'match_word': 'compass-therapeuti...  embedding_matched
# 4   [{'rank': 1, 'match_word': 'ant-financial', 's...  embedding_matched
# 5   [{'rank': 1, 'match_word': 'ant-financial', 's...  embedding_matched
# 6   [{'rank': 1, 'match_word': 'ant-financial', 's...  embedding_matched
# 7   [{'rank': 1, 'match_word': 'ant-financial', 's...  embedding_matched
# 8   [{'rank': 1, 'match_word': 'byju-s', 'score': ...  embedding_matched
# 9   [{'rank': 1, 'match_word': 'byju-s', 'score': ...  embedding_matched
# 10  [{'rank': 1, 'match_word': 'carbon-health', 's...  embedding_matched
# 11  [{'rank': 1, 'match_word': 'k-health', 'score'...  embedding_matched
# 12  [{'rank': 1, 'match_word': 'advantagene', 'sco...  embedding_matched
# 13  [{'rank': 1, 'match_word': 'nanigans', 'score'...  embedding_matched
# 14  [{'rank': 1, 'match_word': 'ant-financial', 's...  embedding_matched
# 15  [{'rank': 1, 'match_word': 'ant-financial', 's...  embedding_matched
# 16  [{'rank': 1, 'match_word': 'internet-brands', ...  embedding_matched
# 17  [{'rank': 1, 'match_word': 'bolt-threads', 'sc...  embedding_matched

# %%
df_not_matched_results
# Out:
#          nport_issuer_name       slug  \
# 0  THEMIS SOLUTIONS INC PP       clio
# 1         PDD HOLDINGS INC  pinduoduo
# 2        PDD Holdings Inc.  pinduoduo
#
#                                             rankings
# 0  [{'rank': 1, 'match_word': 'internet-brands', ...
# 1  [{'rank': 1, 'match_word': 'd-wave-systems', '...
# 2  [{'rank': 1, 'match_word': 'd-wave-systems', '...

# %%
exact_matxches_results_df = pd.DataFrame(exact_matxches)
exact_matxches_results_df.to_csv('data/exact_matxches_embedding.csv', index=False)

# %% [markdown]
# overal = 3108
# - matched = 2985 - (96%)
# - partial matched = 118 (3.7%)
# - unmatched = 5 - (0.16%)

# %% [markdown]
# Additional weights for input text

# %%
not_matched_plus_partial = pd.concat([df_not_matched_results, partial_matched_results_df])
not_matched_plus_partial
# Out:
#                       nport_issuer_name              slug  \
# 0               THEMIS SOLUTIONS INC PP              clio
# 1                      PDD HOLDINGS INC         pinduoduo
# 2                     PDD Holdings Inc.         pinduoduo
# 0               Nauticus Robotics, Inc.       3d-robotics
# 1        Formagrid Inc Ser F Cvt Pfd Pp          airtable
# 2         Formagrid Inc Ser F Cvt /Pfd/          airtable
# 3     GROUPON INC COMMON STOCK USD.0001           groupon
# 4                          Mh Sub I Llc   internet-brands
# 5    Mh Sub I Llc / Micro Holding Corp.   internet-brands
# 6              ANI Technologies Pvt Ltd               ola
# 7             ANI Technologies Pvt Ltd.               ola
# 8                  Ani Technologies Pvt               ola
# 9                Ani Technologies Pvt .               ola
# 10    Sb Technology Series D Cvt Pfd Pp         sandboxaq
# 11                 MOUNTAIN DIGITAL INC        steelhouse
# 12   Life Healthcare Group Holdings Ltd  1life-healthcare
# 13               Tyra Biosciences, Inc.  aura-biosciences
# 14                        Mh Sub I, Llc   internet-brands
# 15  Mh Sub I, Llc (Micro Holding Corp.)   internet-brands
# 16                           Winc, Inc.              winc
# 17                   Bolt Financial Inc    bolt-financial
#
#                                              rankings             method
# 0   [{'rank': 1, 'match_word': 'internet-brands', ...                NaN
# 1   [{'rank': 1, 'match_word': 'd-wave-systems', '...                NaN
# 2   [{'rank': 1, 'match_word': 'd-wave-systems', '...                NaN
# 0   [{'rank': 1, 'match_word': 'aura-biosciences',...  embedding_matched
# 1   [{'rank': 1, 'match_word': 'carbon-health', 's...  embedding_matched
# 2   [{'rank': 1, 'match_word': 'carbon-health', 's...  embedding_matched
# 3   [{'rank': 1, 'match_word': 'compass-therapeuti...  embedding_matched
# 4   [{'rank': 1, 'match_word': 'ant-financial', 's...  embedding_matched
# 5   [{'rank': 1, 'match_word': 'ant-financial', 's...  embedding_matched
# 6   [{'rank': 1, 'match_word': 'ant-financial', 's...  embedding_matched
# 7   [{'rank': 1, 'match_word': 'ant-financial', 's...  embedding_matched
# 8   [{'rank': 1, 'match_word': 'byju-s', 'score': ...  embedding_matched
# 9   [{'rank': 1, 'match_word': 'byju-s', 'score': ...  embedding_matched
# 10  [{'rank': 1, 'match_word': 'carbon-health', 's...  embedding_matched
# 11  [{'rank': 1, 'match_word': 'k-health', 'score'...  embedding_matched
# 12  [{'rank': 1, 'match_word': 'advantagene', 'sco...  embedding_matched
# 13  [{'rank': 1, 'match_word': 'nanigans', 'score'...  embedding_matched
# 14  [{'rank': 1, 'match_word': 'ant-financial', 's...  embedding_matched
# 15  [{'rank': 1, 'match_word': 'ant-financial', 's...  embedding_matched
# 16  [{'rank': 1, 'match_word': 'internet-brands', ...  embedding_matched
# 17  [{'rank': 1, 'match_word': 'bolt-threads', 'sc...  embedding_matched

# %%
df_joined_not_matched_plus_partial = not_matched_plus_partial.merge(df_merged_result, how='left')

print(df_joined_not_matched_plus_partial.head())

df_joined_not_matched_plus_partial.to_csv('data/_test_joined_not_matched_plus_partial.csv', index=False)
# Out:
#                 nport_issuer_name         slug  \
# 0         THEMIS SOLUTIONS INC PP         clio
# 1                PDD HOLDINGS INC    pinduoduo
# 2               PDD Holdings Inc.    pinduoduo
# 3         Nauticus Robotics, Inc.  3d-robotics
# 4  Formagrid Inc Ser F Cvt Pfd Pp     airtable
#
#                                             rankings             method  \
# 0  [{'rank': 1, 'match_word': 'internet-brands', ...                NaN
# 1  [{'rank': 1, 'match_word': 'd-wave-systems', '...                NaN
# 2  [{'rank': 1, 'match_word': 'd-wave-systems', '...                NaN
# 3  [{'rank': 1, 'match_word': 'aura-biosciences',...  embedding_matched
# 4  [{'rank': 1, 'match_word': 'carbon-health', 's...  embedding_matched
#
#         NAME                                    LEGALENTITYNAME  \
# 0       Clio                              Themis Solutions Inc.
# 1  Pinduoduo  Shanghai Xun Meng Information Technology Co., ...
# 2  Pinduoduo  Shanghai Xun Meng Information Technology Co., ...
# 3        3DR                                  3D Robotics, Inc.
# 4   Airtable                                    Formagrid, Inc.
#
#                                        SEARCHALIASES  \
# 0                         [\n  "Themis Solutions"\n]
# 1                                                 []
# 2                                                 []
# 3  [\n  "3DR ",\n  "3dr ",\n  "3DRobotics ",\n  "...
# 4  [\n  "airtable  ",\n  "Air Table  ",\n  "AIRTA...
#
#                                          DESCRIPTION STRUCTURED_DESCRIPTION  \
# 0  Clio is a cloud-based legal practice managemen...                    NaN
# 1  Pinduoduo is the developer of a mobile-only ma...                    NaN
# 2  Pinduoduo is the developer of a mobile-only ma...                    NaN
# 3  3DR (also known as 3D Robotics) makes Site Sca...                    NaN
# 4  Airtable is a SaaS provider allowing creators ...                    NaN
#
#   LIFECYCLESTATUS  ... FORGE_PRICE_ISSUER_TIER FORGE_PRICE  \
# 0             NaN  ...                     NaN         NaN
# 1             NaN  ...                     NaN         NaN
# 2             NaN  ...                     NaN         NaN
# 3             NaN  ...                     NaN         1.9
# 4             NaN  ...                  TIER_1        55.0
#
#   FORGE_IMPLIED_VALUATION FORGE_PRICE_SOURCE_EXTERNAL HAS_IOIS  \
# 0                     NaN                         NaN      NaN
# 1                     NaN                         NaN      NaN
# 2                     NaN                         NaN      NaN
# 3            1.278868e+08                     Primary    False
# 4            3.450757e+09                        IOIs     True
#
#                              ARRAY_AGG(FUNDING_DATE)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  [\n  "2012-11-05 00:00:00.000",\n  "2013-12-04...
# 4  [\n  "2018-11-15 08:00:00.000",\n  "2018-03-13...
#
#                             ARRAY_AGG(FR.SHARE_TYPE) NUM_TRADES  \
# 0                                                NaN        NaN
# 1                                                NaN        NaN
# 2                                                NaN        NaN
# 3  [\n  "Series A",\n  "Series B",\n  "Series C",...        NaN
# 4  [\n  "Series C-1",\n  "Series B-1",\n  "Series...        9.0
#
#   LAST_CLOSED_TRADE_DATE LAST_PENDING_TRADE_DATE
# 0                    NaN                     NaN
# 1                    NaN                     NaN
# 2                    NaN                     NaN
# 3                    NaN                     NaN
# 4                11/3/23                10/10/23
#
# [5 rows x 30 columns]

# %%
df_not_matched_3 = df_joined_not_matched_plus_partial.copy()

# Apply 'normalize_name' to 'nport_issuer_name'
df_not_matched_3['cleaned_nport_issuer_name'] = df_not_matched_3.apply(lambda row: normalize_name(row['nport_issuer_name']), axis=1)

output_columns = [
    'slug',
    'NAME',
    'LEGALENTITYNAME',
    'SEARCHALIASES',
    'DESCRIPTION',
    'STRUCTURED_DESCRIPTION',
    'LIFECYCLESTATUS',
    'BANNERMESSAGE',
    'SUB_SECTOR',
    'SECTOR',
    'WEBSITE',
    'CRUNCHBASEURL'
]

# Define weights for each output column
column_weights = {
    'slug': 1.0,
    'NAME': 2.0,
    'LEGALENTITYNAME': 2.0,
    'WEBSITE': 1.5,
    'SEARCHALIASES': 1.5,
    'DESCRIPTION': 1.0,
    'STRUCTURED_DESCRIPTION': 1.0,
    'LIFECYCLESTATUS': 1.0,
    'BANNERMESSAGE': 1.0,
    'SUB_SECTOR': 1.0,
    'SECTOR': 1.0,
    'CRUNCHBASEURL': 1.0
}

# Clean and store text for each output column
for col in output_columns:
    if col in df_not_matched_3.columns:
        df_not_matched_3[col + '_clean'] = df_not_matched_3[col].apply(
            lambda x: clean_text(x) if pd.notnull(x) else ''
        )

    else:
        df_not_matched_3[col + '_clean'] = ''

# Prepare 'words_to_find_3' (inputs)
words_to_find_3 = df_not_matched_3['cleaned_nport_issuer_name'].tolist()

# Load the model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Generate embeddings for the input texts
embeddings_to_find_3 = model.encode(words_to_find_3, convert_to_numpy=True, normalize_embeddings=True)

# Generate and combine embeddings for output columns with weights
weighted_embeddings_list_3 = []

for idx, row in df_not_matched_3.iterrows():
    combined_embedding = np.zeros(model.get_sentence_embedding_dimension())
    total_weight = 0.0

    for col in output_columns:
        col_clean = col + '_clean'
        text = row[col_clean]
        weight = column_weights.get(col, 1.0)
        if text:
            embedding = model.encode([text], convert_to_numpy=True, normalize_embeddings=True)[0]
            combined_embedding += weight * embedding
            total_weight += weight

    if total_weight > 0:
        combined_embedding /= total_weight  # Normalize by total weight
    weighted_embeddings_list_3.append(combined_embedding)

embeddings_list_3 = np.array(weighted_embeddings_list_3)

# Now, proceed to include weighted features as before
# Apply the weight functions to the DataFrame
df_not_matched_3['DOMICILECOUNTRYCODE_WEIGHT'] = df_not_matched_3['DOMICILECOUNTRYCODE'].apply(weight_domicile_country_code)
df_not_matched_3['DOMICILESTATECODE_WEIGHT'] = df_not_matched_3['DOMICILESTATECODE'].apply(weight_domicile_state_code)
df_not_matched_3['SHARE_TYPE_WEIGHT'] = df_not_matched_3['ARRAY_AGG(FR.SHARE_TYPE)'].apply(normalize_and_weight_series)
df_not_matched_3['FUNDING_DATE_WEIGHT'] = df_not_matched_3['ARRAY_AGG(FUNDING_DATE)'].apply(weight_recency)
df_not_matched_3['FORGE_PRICE_SOURCE_WEIGHT'] = df_not_matched_3['FORGE_PRICE_SOURCE_EXTERNAL'].apply(weight_price_source)
df_not_matched_3['FORGE_PRICE_ISSUER_TIER_WEIGHT'] = df_not_matched_3['FORGE_PRICE_ISSUER_TIER'].apply(weight_price_issuer_tier)
df_not_matched_3['FORGE_PRICE_WEIGHT'] = df_not_matched_3['FORGE_PRICE'].apply(weight_price)
df_not_matched_3['FORGE_IMPLIED_VALUATION_WEIGHT'] = df_not_matched_3['FORGE_IMPLIED_VALUATION'].apply(weight_implied_valuation)
df_not_matched_3['HAS_IOIS_WEIGHT'] = df_not_matched_3['HAS_IOIS'].apply(weight_has_iois)
df_not_matched_3['NUM_TRADES_WEIGHT'] = df_not_matched_3['NUM_TRADES'].apply(weight_num_trades)
df_not_matched_3['LAST_CLOSED_TRADE_DATE_WEIGHT'] = df_not_matched_3['LAST_CLOSED_TRADE_DATE'].apply(weight_last_closed_trade_date)
df_not_matched_3['LAST_PENDING_TRADE_DATE_WEIGHT'] = df_not_matched_3['LAST_PENDING_TRADE_DATE'].apply(weight_last_pending_trade_date)

# Select and normalize the weighted features
weighted_feature_columns = [
    'DOMICILECOUNTRYCODE_WEIGHT',
    'DOMICILESTATECODE_WEIGHT',
    'SHARE_TYPE_WEIGHT',
    'FUNDING_DATE_WEIGHT',
    'FORGE_PRICE_SOURCE_WEIGHT',
    'FORGE_PRICE_ISSUER_TIER_WEIGHT',
    'FORGE_PRICE_WEIGHT',
    'FORGE_IMPLIED_VALUATION_WEIGHT',
    'HAS_IOIS_WEIGHT',
    'NUM_TRADES_WEIGHT',
    'LAST_CLOSED_TRADE_DATE_WEIGHT',
    'LAST_PENDING_TRADE_DATE_WEIGHT'
]

# Fill NaN values with zeros
df_not_matched_3[weighted_feature_columns] = df_not_matched_3[weighted_feature_columns].fillna(0.0)

# Normalize the weighted features
scaler = MinMaxScaler()
weighted_features = scaler.fit_transform(df_not_matched_3[weighted_feature_columns])

# Combine embeddings with weighted features
combined_embeddings_to_find_3 = np.hstack((embeddings_to_find_3, weighted_features))
combined_embeddings_list_3 = np.hstack((embeddings_list_3, weighted_features))

# Compute cosine similarity matrix
cosine_sim_matrix_3 = cosine_similarity(combined_embeddings_to_find_3, combined_embeddings_list_3)

# Initialize counters for accuracy calculation
correct_top1 = 0  # Correct matches at rank 1
correct_topk = 0  # Correct matches within top_k
top_k = 20
not_matched_results = []
partial_matched_results = []
exact_matches = []

for idx, (word, scores) in enumerate(zip(words_to_find_3, cosine_sim_matrix_3)):
    top_indices = scores.argsort()[-top_k:][::-1]  # Indices of top_k scores in descending order
    matches = []
    seen_matches = set()  # Reset seen_matches for each new word being processed
    ground_truth_found = False

    current_slug = df_not_matched_3.iloc[idx]['slug']
    current_nport_issuer_name = df_not_matched_3.iloc[idx]['nport_issuer_name']

    for rank, index in enumerate(top_indices):
        # Retrieve a concise match identifier like 'slug' or 'NAME' instead of full text
        matched_word = df_not_matched_3.iloc[index]['slug'] if 'slug' in df_not_matched_3.columns else word_list[index]
        match_score = scores[index]

        # Only add the match if it's not a duplicate within the current ranking list
        if matched_word not in seen_matches:
            matches.append({
                'rank': len(matches) + 1,  # Rank based on unique entries added
                'match_word': matched_word,
                'score': match_score
            })
            seen_matches.add(matched_word)  # Mark this word as seen within this record

        if index == idx:
            ground_truth_found = True
            if len(matches) == 1:
                correct_top1 += 1  # Ground truth is the top match
                exact_matches.append({
                    'nport_issuer_name': current_nport_issuer_name,
                    'slug': current_slug,
                    'rankings': matches
                })
                break
            correct_topk += 1     # Ground truth is within top_k matches
            partial_matched_results.append({
                'nport_issuer_name': current_nport_issuer_name,
                'slug': current_slug,
                'rankings': sorted(matches, key=lambda x: x['score'], reverse=True)  # Sort by score
            })

    if not ground_truth_found:
        not_matched_results.append({
            'slug': current_slug,
            'nport_issuer_name': current_nport_issuer_name,
            'cleaned_nport_issuer_name': word,
            'matches': sorted(matches, key=lambda x: x['score'], reverse=True)  # Sort by score
        })

total = len(words_to_find_3)
top1_accuracy = correct_top1 / total
topk_accuracy = correct_topk / total

print(f"Top-1 Accuracy: {top1_accuracy:.2%}")
print(f"Top-{top_k} Accuracy: {topk_accuracy:.2%}")

# # Save not_matched_results to CSV
# df_not_matched_results = pd.DataFrame(not_matched_results)
# df_not_matched_results.to_csv('data/not_matched_results.csv', index=False)
# Out:
# Top-1 Accuracy: 80.95%
# Top-20 Accuracy: 19.05%

# %%
partial_matched_results_df = pd.DataFrame(partial_matched_results)
partial_matched_results_df['method'] = 'embedding_matched'

partial_matched_results_df.to_csv('data/_test.csv', index=False)

# %%
exact_matxches_results_df = pd.DataFrame(exact_matches)
exact_matxches_results_df.to_csv('data/_test_exact.csv', index=False)
